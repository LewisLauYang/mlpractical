# %% [markdown]
# # Coursework 2 - PyTorch based experiment framework
#
# ## Intro
# Welcome to the coursework 2 PyTorch experiment framework. Pytorch is a  modern, intuitive, highly Pythonic and very fast framework for building differentiable graphs. Neural networks, as it happens, are a type of acyclic differentiable graph, so PyTorch is a great framework to use, if you want to build  complicated deep networks fairly easily.
#
# ## MLP package vs Pytorch
# **Student**: So, why do I have to learn to use PyTorch now? I've spent all this time working on the MLP framework. Was that a waste of time?
#
# **TA**: Well, Pytorch is everything the MLP package is, but faster, cleaner and far more resourceful. Since it is one of the main deep learning frameworks being used by industry and research alike, it has been fine-tuned quite a bit, to conform to the expectation of researchers and engineers alike. What this means, is that PyTorch is now a very robust and highly flexible package, that you can use for any project you want to work on in the future, if it involves trainining differentiable graphs.
#
# In addition, MLP is written in NumPy and your time working on it has taught some low level details of NNs; PyTorch was written to look as much as possible to NumPy, so it will feel very familiar to you. The skills you have acquired are highly transferable (that is, they generalize well, so not much overfitting there...).
#
# PyTorch will almost always have all the latest and greatest implemented in it as soon as they are released as papers, and if not, give it a week or two and someone will reproduce it. If you can't wait, you can reproduce it yourself and open source it. A great way to show your skills and get github likes.
#
# In addition PyTorch has Autograd! Automatic differentiation (previously mentioned in [lectures](http://www.inf.ed.ac.uk/teaching/courses/mlp/2018-19/mlp05-learn.pdf)). "What is this?" you may ask. Remember having to write all those backprop functions? Forget about it. Automatic differentiation allows you to backprop through any PyTorch operation you have used in your graph, by simply calling backward(). This [blog-post](https://jdhao.github.io/2017/11/12/pytorch-computation-graph/) explains how Pytorch's autograd works at an intuitive level.
#
# **Student**: Why did we even have to use the MLP package? We did we even bother if such awesome frameworks are available?
#
# **TA**: The purpose of the MLP package was not to allow you to build fast deep learning systems. Instead, it was to help teach you the low level mechanics and sensitivities of building a deep learning system. It allowed you to delve deep into how one can go about building a deep learning framework from scratch. The intuitions you have gained from going through your assignments and courseworks allow you to see deeper in what makes or breaks a deep learning system, at a level few people actually have. You are no longer restricted to the higher level modules provided by Pytorch/TensorFlow.
#
# If, for example, a new project required you to build something that does not exist in PyTorch/TensorFlow, or otherwise modify existing modules in a way that requires understanding and intuitions on backpropagation and layer/optimizer/component implementation, you would be able to do it much more easily than others who did not. You are now equipped to understand differentiable graphs, the chain rule, numerical errors, debugging at the lowest level and deep learning system architecture.
#
# In addition, by trying to implement your modules in an efficient way, you have also become aware of how to optimize a system for efficiency, and gave you intuitions on how one could further improve such a system (parallelization of implementations).
#
# Finally, the slowness of CPU training has allowed you to understand just how important modern GPU acceleration is, for deep learning research and applications. By coming across a large breadth of problems and understanding their origins, you will now be able to both anticipate and solve future problems in a more comprehensive way than someone who did not go through the trouble of implementing the basics from scratch.
#
# **Student**: If we are switching to Pytorch, then why bother implementing convolutions in the MLP package for the coursework?
#
# **TA**: All your instructors, myself included, have found it greatly beneficial to implement convolutional networks from scratch. Once you implement convolutional layers, you will have a much deeper insight and understanding into how and why they work... as well as how they break. This way, you know what to do and what to avoid in the future. You might even be able to come with the next great network type yourself.
#
#
# ## Getting Started
#
# **Student**: So, how is the learning curve of Pytorch? How do I start?
#
# **TA**: You can start by using this notebook on your experiments, it should teach you quite a lot on how to properly use PyTorch for basic conv net training. You should be aware of the [official pytorch github](https://github.com/pytorch/pytorch), the [pytorch official documentation page](https://pytorch.org/docs/stable/nn.html) and the [pytorch tutorials page](https://pytorch.org/tutorials/).
#
# Over the past year, nearly all students using PyTorch and Tensorflow on MLP and on projects found it easier and faster to get up to speed with PyTorch. In fact, I was a TensorFlow user myself, and learning TensorFlow was much more challenging than PyTorch. Mainly because TensorFlow has its own way of 'thinking' about how you build a graph and execute operations - whereas PyTorch is dynamic and works like NumPy, hence is more intuitive. If you were able to work well with the MLP package, you'll be up and running in no time.
#
# **Student**: OK, so how fast is pytorch compared to MLP?
#
# **TA**: On the CPU side of things, you'll find pytorch at least 5x faster than the MLP framework (about equal for fully connected networks, but much faster for more complicated things like convolutions - unless you write extremely efficient convolutional layer code), and if you choose to use GPUs, either using MS Azure, Google Cloud or our very own MLP Cluster (available for next semester), you can expect, depending on implementation and hardware an approximate 25-70x speed ups, compared to the CPU performance of pytorch. Yes, that means an experiment that would run overnight, now would only require about 15 minutes.
#
# **Student**: Ahh, where should I go to ask more questions?
#
# **TA**: As always, start with a Google/DuckDuckGo search, then have a look at the PyTorch Github and PyTorch docs, and if you can't find the answer come to Piazza and the lab sessions. We will be there to support you.
#
#
# #### Note: The code in this jupyter notebook is to introduce you to pytorch and allow you to play around with it in an interactive manner. However, to run your experiments, you should use the Pytorch experiment framework located in ```mlp/pytorch_experiment_scripts```. Instructions on how to use it can be found in ```notes/pytorch-experiment-framework.md``` along with the comments and documentation included in the code itself.

# %%
from torch import nn
from copy import deepcopy
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torchvision
import tqdm
import os
import mlp.data_providers as data_providers
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def plot_stats_in_graph(total_losses):
    
    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in total_losses.keys():
        if "loss" in k:
            ax_1.plot(np.arange(len(total_losses[k])), total_losses[k], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    
    
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in total_losses.keys():
        if "acc" in k:
            ax_2.plot(np.arange(len(total_losses[k])), total_losses[k], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')

    plt.show()

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self, input_shape, dim_reduction_type, num_output_classes, num_filters, num_layers, use_bias=False,stride=1):
        """
        Initializes a convolutional network module object.
        :param input_shape: The shape of the inputs going in to the network.
        :param dim_reduction_type: The type of dimensionality reduction to apply after each convolutional stage, should be one of ['max_pooling', 'avg_pooling', 'strided_convolution', 'dilated_convolution']
        :param num_output_classes: The number of outputs the network should have (for classification those would be the number of classes)
        :param num_filters: Number of filters used in every conv layer, except dim reduction stages, where those are automatically infered.
        :param num_layers: Number of conv layers (excluding dim reduction stages)
        :param use_bias: Whether our convolutions will use a bias.
        """
        super(ConvolutionalNetwork, self).__init__()
        # set up class attributes useful in building the network and inference
        self.input_shape = input_shape
        self.num_filters = num_filters
        self.num_output_classes = num_output_classes
        self.use_bias = use_bias
        self.num_layers = num_layers
        self.dim_reduction_type = dim_reduction_type
        # initialize a module dict, which is effectively a dictionary that can collect layers and integrate them into pytorch
        self.layer_dict = nn.ModuleDict()
        self.stride = stride
        # build the network
        self.build_module()

    def build_module(self):
        """
        Builds network whilst automatically inferring shapes of layers.
        """
        print("Building basic block of ConvolutionalNetwork using input shape", self.input_shape)
        x = torch.zeros((self.input_shape))  # create dummy inputs to be used to infer shapes of layers

        out = x
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True)
        for i in range(self.num_layers):  # for number of layers times
            self.layer_dict['conv_{}'.format(i)] = nn.Conv2d(in_channels=out.shape[1],
                                                             # add a conv layer in the module dict
                                                             kernel_size=3,
                                                             out_channels=self.num_filters, padding=1,stride=self.stride,
                                                             bias=self.use_bias)

            out = self.layer_dict['conv_{}'.format(i)](out)  # use layer on inputs to get an output
            out = F.relu(out)  # apply relu
            print(out.shape)
            if self.dim_reduction_type == 'strided_convolution':  # if dim reduction is strided conv, then add a strided conv
                self.layer_dict['dim_reduction_strided_conv_{}'.format(i)] = nn.Conv2d(in_channels=out.shape[1],
                                                                                       kernel_size=3,
                                                                                       out_channels=out.shape[1],
                                                                                       padding=1,
                                                                                       bias=self.use_bias, stride=2,
                                                                                       dilation=1)

                out = self.layer_dict['dim_reduction_strided_conv_{}'.format(i)](
                    out)  # use strided conv to get an output
                out = F.relu(out)  # apply relu to the output
            elif self.dim_reduction_type == 'dilated_convolution':  # if dim reduction is dilated conv, then add a dilated conv, using an arbitrary dilation rate of i + 2 (so it gets smaller as we go, you can choose other dilation rates should you wish to do it.)
                self.layer_dict['dim_reduction_dilated_conv_{}'.format(i)] = nn.Conv2d(in_channels=out.shape[1],
                                                                                       kernel_size=3,
                                                                                       out_channels=out.shape[1],
                                                                                       padding=1,
                                                                                       bias=self.use_bias, stride=1,
                                                                                       dilation=i + 2)
                out = self.layer_dict['dim_reduction_dilated_conv_{}'.format(i)](
                    out)  # run dilated conv on input to get output
                out = F.relu(out)  # apply relu on output

            elif self.dim_reduction_type == 'max_pooling':
                self.layer_dict['dim_reduction_max_pool_{}'.format(i)] = nn.MaxPool2d(2, padding=1)
                out = self.layer_dict['dim_reduction_max_pool_{}'.format(i)](out)

            elif self.dim_reduction_type == 'avg_pooling':
                self.layer_dict['dim_reduction_avg_pool_{}'.format(i)] = nn.AvgPool2d(2, padding=1)
                out = self.layer_dict['dim_reduction_avg_pool_{}'.format(i)](out)

            print(out.shape)
        if out.shape[-1] != 2:
            out = F.adaptive_avg_pool2d(out, 2)  # apply adaptive pooling to make sure output of conv layers is always (2, 2) spacially (helps with comparisons).
        print('shape before final linear layer', out.shape)
        out = out.view(out.shape[0], -1)
        self.logit_linear_layer = nn.Linear(in_features=out.shape[1],  # add a linear layer
                                            out_features=self.num_output_classes,
                                            bias=self.use_bias)
        out = self.logit_linear_layer(out)  # apply linear layer on flattened inputs
        print("Block is built, output volume is", out.shape)
        return out

    def forward(self, x):
        """
        Forward propages the network given an input batch
        :param x: Inputs x (b, c, h, w)
        :return: preds (b, num_classes)
        """
        out = x
        for i in range(self.num_layers):  # for number of layers

            out = self.layer_dict['conv_{}'.format(i)](out)  # pass through conv layer indexed at i
            out = F.relu(out)  # pass conv outputs through ReLU
            if self.dim_reduction_type == 'strided_convolution':  # if strided convolution dim reduction then
                out = self.layer_dict['dim_reduction_strided_conv_{}'.format(i)](
                    out)  # pass previous outputs through a strided convolution indexed i
                out = F.relu(out)  # pass strided conv outputs through ReLU

            elif self.dim_reduction_type == 'dilated_convolution':
                out = self.layer_dict['dim_reduction_dilated_conv_{}'.format(i)](out)
                out = F.relu(out)

            elif self.dim_reduction_type == 'max_pooling':
                out = self.layer_dict['dim_reduction_max_pool_{}'.format(i)](out)

            elif self.dim_reduction_type == 'avg_pooling':
                out = self.layer_dict['dim_reduction_avg_pool_{}'.format(i)](out)

        if out.shape[-1] != 2:
            out = F.adaptive_avg_pool2d(out, 2)
        out = out.view(out.shape[0], -1)  # flatten outputs from (b, c, h, w) to (b, c*h*w)
        out = self.logit_linear_layer(out)  # pass through a linear layer to get logits/preds
        return out

    def reset_parameters(self):
        """
        Re-initialize the network parameters.
        """
        for item in self.layer_dict.children():
            try:
                item.reset_parameters()
            except:
                pass

        self.logit_linear_layer.reset_parameters()

# %%
import time
from mlp.pytorch_experiment_scripts.storage_utils import save_statistics
class ExperimentBuilder(nn.Module):
    def __init__(self, network_model, experiment_name, num_epochs, train_data, val_data,
                 test_data, weight_decay_coefficient, use_gpu, continue_from_epoch=-1):
        """
        Initializes an ExperimentBuilder object. Such an object takes care of running training and evaluation of a deep net
        on a given dataset. It also takes care of saving per epoch models and automatically inferring the best val model
        to be used for evaluating the test set metrics.
        :param network_model: A pytorch nn.Module which implements a network architecture.
        :param experiment_name: The name of the experiment. This is used mainly for keeping track of the experiment and creating and directory structure that will be used to save logs, model parameters and other.
        :param num_epochs: Total number of epochs to run the experiment
        :param train_data: An object of the DataProvider type. Contains the training set.
        :param val_data: An object of the DataProvider type. Contains the val set.
        :param test_data: An object of the DataProvider type. Contains the test set.
        :param weight_decay_coefficient: A float indicating the weight decay to use with the adam optimizer.
        :param use_gpu: A boolean indicating whether to use a GPU or not.
        :param continue_from_epoch: An int indicating whether we'll start from scrach (-1) or whether we'll reload a previously saved model of epoch 'continue_from_epoch' and continue training from there.
        """
        super(ExperimentBuilder, self).__init__()
        if torch.cuda.is_available() and use_gpu: # checks whether a cuda gpu is available and whether the gpu flag is True
            self.device = torch.device('cuda') # sets device to be cuda
            os.environ["CUDA_VISIBLE_DEVICES"] = "0" # sets the main GPU to be the one at index 0
            print("use GPU")
        else:
            print("use CPU")
            self.device = torch.device('cpu') # sets the device to be CPU

        self.experiment_name = experiment_name
        self.model = network_model
        self.model.to(self.device) # sends the model from the cpu to the gpu
        self.model.reset_parameters() # re-initialize network parameters
        self.train_data = train_data
        self.val_data = val_data
        self.test_data = test_data
        self.optimizer = optim.Adam(self.parameters(), amsgrad=False,
                                    weight_decay=weight_decay_coefficient)
        # Generate the directory names
        self.experiment_folder = os.path.abspath(experiment_name)
        self.experiment_logs = os.path.abspath(os.path.join(self.experiment_folder, "result_outputs"))
        self.experiment_saved_models = os.path.abspath(os.path.join(self.experiment_folder, "saved_models"))

        # Set best models to be at 0 since we are just starting
        self.best_val_model_idx = 0
        self.best_val_model_acc = 0.
        self.totalTime = 0
        if not os.path.exists(self.experiment_folder): # If experiment directory does not exist
            os.mkdir(self.experiment_folder) # create the experiment directory
            os.mkdir(self.experiment_logs) # create the experiment log directory
            os.mkdir(self.experiment_saved_models) # create the experiment saved models directory

        self.num_epochs = num_epochs
        self.criterion = nn.CrossEntropyLoss().to(self.device) # send the loss computation to the GPU

        if continue_from_epoch != -1: # if continue from epoch is not -1 then
            self.best_val_model_idx, self.best_val_model_acc = self.load_model(
                model_save_dir=self.experiment_saved_models, model_save_name="train_model",
                model_idx=continue_from_epoch) # reload existing model from epoch and return best val model index
                                             # and the best val acc of that model
            self.starting_epoch = continue_from_epoch
        else:
            self.starting_epoch = 0

    def run_train_iter(self, x, y):
        """
        Receives the inputs and targets for the model and runs a training iteration. Returns loss and accuracy metrics.
        :param x: The inputs to the model. A numpy array of shape batch_size, channels, height, width
        :param y: The targets for the model. A numpy array of shape batch_size, num_classes
        :return: the loss and accuracy for this batch
        """
        self.train() # sets model to training mode (in case batch normalization or other methods have different procedures for training and evaluation)
        y = np.argmax(y, axis=1) # convert one hot encoded labels to single integer labels
        x, y = torch.Tensor(x).float().to(device=self.device), torch.Tensor(y).long().to(device=self.device) # send data to device as torch tensors
        out = self.model.forward(x) # forward the data in the model
        loss = F.cross_entropy(input=out, target=y) # compute loss

        self.optimizer.zero_grad() # set all weight grads from previous training iters to 0
        loss.backward() # backpropagate to compute gradients for current iter loss

        self.optimizer.step() # update network parameters
        _, predicted = torch.max(out.data, 1) # get argmax of predictions
        accuracy = np.mean(list(predicted.eq(y.data).cpu())) # compute accuracy
        return loss.data, accuracy

    def run_evaluation_iter(self, x, y):
        """
        Receives the inputs and targets for the model and runs an evaluation iterations. Returns loss and accuracy metrics.
        :param x: The inputs to the model. A numpy array of shape batch_size, channels, height, width
        :param y: The targets for the model. A numpy array of shape batch_size, num_classes
        :return: the loss and accuracy for this batch
        """
        self.eval() # sets the system to validation mode
        y = np.argmax(y, axis=1) # convert one hot encoded labels to single integer labels
        x, y = torch.Tensor(x).float().to(device=self.device), torch.Tensor(y).long().to(device=self.device) # convert data to pytorch tensors and send to the computation device
        out = self.model.forward(x) # forward the data in the model
        loss = F.cross_entropy(out, y) # compute loss
        _, predicted = torch.max(out.data, 1) # get argmax of predictions
        accuracy = np.mean(list(predicted.eq(y.data).cpu())) # compute accuracy
        return loss.data, accuracy

    def save_model(self, model_save_dir, model_save_name, model_idx, best_validation_model_idx,
                   best_validation_model_acc):
        """
        Save the network parameter state and current best val epoch idx and best val accuracy.
        :param model_save_name: Name to use to save model without the epoch index
        :param model_idx: The index to save the model with.
        :param best_validation_model_idx: The index of the best validation model to be stored for future use.
        :param best_validation_model_acc: The best validation accuracy to be stored for use at test time.
        :param model_save_dir: The directory to store the state at.
        :param state: The dictionary containing the system state.

        """
        state = dict()
        state['network'] = self.state_dict() # save network parameter and other variables.
        state['best_val_model_idx'] = best_validation_model_idx # save current best val idx
        state['best_val_model_acc'] = best_validation_model_acc # save current best val acc
        torch.save(state, f=os.path.join(model_save_dir, "{}_{}".format(model_save_name, str(model_idx)))) # save state at prespecified filepath

    def load_model(self, model_save_dir, model_save_name, model_idx):
        """
        Load the network parameter state and the best val model idx and best val acc to be compared with the future val accuracies, in order to choose the best val model
        :param model_save_dir: The directory to store the state at.
        :param model_save_name: Name to use to save model without the epoch index
        :param model_idx: The index to save the model with.
        :return: best val idx and best val model acc, also it loads the network state into the system state without returning it
        """
        state = torch.load(f=os.path.join(model_save_dir, "{}_{}".format(model_save_name, str(model_idx))))
        self.load_state_dict(state_dict=state['network'])
        return state['best_val_model_idx'], state['best_val_model_acc']

    def run_experiment(self):
        """
        Runs experiment train and evaluation iterations, saving the model and best val model and val model accuracy after each epoch
        :return: The summary current_epoch_losses from starting epoch to total_epochs.
        """
        total_losses = {"train_acc": [], "train_loss": [], "val_acc": [], "val_loss": []} # initialize a dict to keep the per-epoch metrics
        for i, epoch_idx in enumerate(range(self.starting_epoch, self.num_epochs)):
            epoch_start_time = time.time()
            current_epoch_losses = {"train_acc": [], "train_loss": [], "val_acc": [], "val_loss": []}

            with tqdm.tqdm(total=self.train_data.num_batches) as pbar_train: # create a progress bar for training
                for idx, (x, y) in enumerate(self.train_data): # get data batches
                    loss, accuracy = self.run_train_iter(x=x, y=y) # take a training iter step
                    current_epoch_losses["train_loss"].append(loss) # add current iter loss to the train loss list
                    current_epoch_losses["train_acc"].append(accuracy) # add current iter acc to the train acc list
                    pbar_train.update(1)
                    pbar_train.set_description("loss: {:.4f}, accuracy: {:.4f}".format(loss, accuracy))

            with tqdm.tqdm(total=self.val_data.num_batches) as pbar_val: # create a progress bar for validation
                for x, y in self.val_data: # get data batches
                    loss, accuracy = self.run_evaluation_iter(x=x, y=y) # run a validation iter
                    current_epoch_losses["val_loss"].append(loss) # add current iter loss to val loss list.
                    current_epoch_losses["val_acc"].append(accuracy) # add current iter acc to val acc lst.
                    pbar_val.update(1) # add 1 step to the progress bar
                    pbar_val.set_description("loss: {:.4f}, accuracy: {:.4f}".format(loss, accuracy))

            if np.mean(current_epoch_losses['val_acc']) > self.best_val_model_acc: # if current epoch's mean val acc is greater than the saved best val acc then
                self.best_val_model_acc = np.mean(current_epoch_losses['val_acc']) # set the best val model acc to be current epoch's val accuracy
                self.best_val_model_idx = epoch_idx # set the experiment-wise best val idx to be the current epoch's idx

            for key, value in current_epoch_losses.items():
                total_losses[key].append(np.mean(value)) # get mean of all metrics of current epoch metrics dict, to get them ready for storage and output on the terminal.

            save_statistics(experiment_log_dir=self.experiment_logs, filename='summary.csv',
                            stats_dict=total_losses, current_epoch=i) # save statistics to stats file.

            # load_statistics(experiment_log_dir=self.experiment_logs, filename='summary.csv') # How to load a csv file if you need to

            out_string = "_".join(["{}_{:.4f}".format(key, np.mean(value)) for key, value in current_epoch_losses.items()])
            # create a string to use to report our epoch metrics
            epoch_elapsed_time = time.time() - epoch_start_time # calculate time taken for epoch
            self.totalTime += epoch_elapsed_time
            epoch_elapsed_time = "{:.4f}".format(epoch_elapsed_time)
            print("Epoch {}:".format(epoch_idx), out_string, "epoch time", epoch_elapsed_time, "seconds")
            seconds = self.totalTime
            m, s = divmod(seconds, 60)
            print('total time{} : {}'.format(m,s))
            self.save_model(model_save_dir=self.experiment_saved_models, # save model and best val idx and best val acc, using the model dir, model name and model idx
                            model_save_name="train_model", model_idx=epoch_idx,
                            best_validation_model_idx=self.best_val_model_idx,
                            best_validation_model_acc=self.best_val_model_acc)

        print("Generating test set evaluation metrics")
        self.load_model(model_save_dir=self.experiment_saved_models, model_idx=self.best_val_model_idx, # load best validation model
                        model_save_name="train_model")
        current_epoch_losses = {"test_acc": [], "test_loss": []} # initialize a statistics dict
        with tqdm.tqdm(total=self.test_data.num_batches) as pbar_test: # ini a progress bar
            for x, y in self.test_data: # sample batch
                loss, accuracy = self.run_evaluation_iter(x=x, y=y) # compute loss and accuracy by running an evaluation step
                current_epoch_losses["test_loss"].append(loss) # save test loss
                current_epoch_losses["test_acc"].append(accuracy) # save test accuracy
                pbar_test.update(1) # update progress bar status
                pbar_test.set_description("loss: {:.4f}, accuracy: {:.4f}".format(loss, accuracy))  # update progress bar string output

        test_losses = {key: [np.mean(value)] for key, value in current_epoch_losses.items()} # save test set metrics in dict format
        save_statistics(experiment_log_dir=self.experiment_logs, filename='test_summary.csv', # save test set metrics on disk in .csv format
                        stats_dict=test_losses, current_epoch=0)

        return total_losses, test_losses

# %%
#stride2_filter32_layer1234_type0

batch_size = 100
image_num_channels = 1
image_height = 28
image_width = 28
dim_reduction_idx = 0
dim_reduction_type = ['strided_convolution', 'dilated_convolution', 'max_pooling', 'avg_pooling']
num_filters = 32
num_layers = [1,2,3,4]
experiment_name = []
for layer in num_layers:
    experiment_name.append("stride2_filter32_layer{}_type{}".format(layer,dim_reduction_idx))
num_epochs = 100
weight_decay_coefficient = 1e-05
seed = 9112018
use_gpu = True

rng = np.random.RandomState(seed=seed)
train_data = data_providers.EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
val_data = data_providers.EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = data_providers.EMNISTDataProvider('test', batch_size=batch_size, rng=rng)

for experiment,layer in zip(experiment_name,num_layers):
    
    print(experiment)
    
    custom_conv_net = ConvolutionalNetwork(
        input_shape=(batch_size, image_num_channels, image_height, image_width),
        dim_reduction_type=dim_reduction_type[dim_reduction_idx],
        num_output_classes=47, num_filters=num_filters, num_layers=layer, use_bias=True)

    conv_experiment = ExperimentBuilder(network_model=custom_conv_net,
                                    experiment_name=experiment,
                                    num_epochs=num_epochs,
                                    weight_decay_coefficient=weight_decay_coefficient,
                                    use_gpu=use_gpu,
                                    train_data=train_data, val_data=val_data, test_data=test_data)
    print(custom_conv_net)
    total_losses = conv_experiment.run_experiment()
    print('finish')
    plot_stats_in_graph(total_losses[0])
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb5ba84a8>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb5ba8630>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb5ba8630>)
# stride2_filter32_layer1_type0
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 14, 14])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# loss: 3.8493, accuracy: 0.0200:   2%|▏         | 16/1000 [00:00<00:11, 84.65it/s]
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_strided_conv_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 1.3957, accuracy: 0.6100: 100%|██████████| 1000/1000 [00:12<00:00, 80.15it/s]
# loss: 1.2914, accuracy: 0.5900: 100%|██████████| 158/158 [00:01<00:00, 141.14it/s]
# loss: 1.4698, accuracy: 0.6000:   1%|          | 10/1000 [00:00<00:11, 87.25it/s]
# Epoch 0: train_acc_0.3901_train_loss_2.2341_val_acc_0.6204_val_loss_1.3127 epoch time 13.7356 seconds
# total time0.0 : 13.735634326934814
# loss: 0.9692, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:12<00:00, 80.94it/s]
# loss: 1.1792, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 139.80it/s]
# loss: 0.9517, accuracy: 0.6600:   2%|▏         | 16/1000 [00:00<00:11, 86.93it/s]
# Epoch 1: train_acc_0.6601_train_loss_1.1497_val_acc_0.6932_val_loss_1.0170 epoch time 13.6291 seconds
# total time0.0 : 27.364744186401367
# loss: 0.9475, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:12<00:00, 83.21it/s]
# loss: 0.9908, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 141.74it/s]
# loss: 1.1400, accuracy: 0.6400:   2%|▏         | 17/1000 [00:00<00:10, 90.79it/s]
# Epoch 2: train_acc_0.6960_train_loss_1.0076_val_acc_0.7099_val_loss_0.9596 epoch time 13.2766 seconds
# total time0.0 : 40.64129710197449
# loss: 1.0573, accuracy: 0.5900: 100%|██████████| 1000/1000 [00:11<00:00, 83.94it/s]
# loss: 0.8069, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 142.99it/s]
# loss: 0.9166, accuracy: 0.7100:   2%|▏         | 17/1000 [00:00<00:11, 88.88it/s]
# Epoch 3: train_acc_0.7123_train_loss_0.9529_val_acc_0.7245_val_loss_0.9097 epoch time 13.1609 seconds
# total time0.0 : 53.8022198677063
# loss: 0.8101, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:11<00:00, 83.82it/s]
# loss: 1.1687, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 142.01it/s]
# loss: 1.1240, accuracy: 0.6600:   2%|▏         | 17/1000 [00:00<00:10, 89.69it/s]
# Epoch 4: train_acc_0.7217_train_loss_0.9185_val_acc_0.7313_val_loss_0.8819 epoch time 13.1840 seconds
# total time1.0 : 6.9862048625946045
# loss: 0.9401, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:11<00:00, 84.77it/s]
# loss: 0.8676, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 143.38it/s]
# loss: 0.9701, accuracy: 0.7200:   2%|▏         | 18/1000 [00:00<00:10, 92.13it/s]
# Epoch 5: train_acc_0.7295_train_loss_0.8892_val_acc_0.7395_val_loss_0.8644 epoch time 13.0386 seconds
# total time1.0 : 20.024832010269165
# loss: 1.0823, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:11<00:00, 87.59it/s]
# loss: 0.6824, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 142.99it/s]
# loss: 1.2249, accuracy: 0.6000:   2%|▏         | 17/1000 [00:00<00:10, 92.77it/s]
# Epoch 6: train_acc_0.7391_train_loss_0.8572_val_acc_0.7458_val_loss_0.8393 epoch time 12.6638 seconds
# total time1.0 : 32.68862509727478
# loss: 0.9763, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:11<00:00, 85.06it/s]
# loss: 1.1893, accuracy: 0.6500: 100%|██████████| 158/158 [00:01<00:00, 143.35it/s]
# loss: 0.9314, accuracy: 0.6600:   2%|▏         | 18/1000 [00:00<00:10, 92.45it/s]
# Epoch 7: train_acc_0.7461_train_loss_0.8315_val_acc_0.7541_val_loss_0.8084 epoch time 13.0012 seconds
# total time1.0 : 45.68981432914734
# loss: 0.5640, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 85.01it/s]
# loss: 0.6946, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 142.77it/s]
# loss: 0.8337, accuracy: 0.7800:   2%|▏         | 18/1000 [00:00<00:10, 95.66it/s]
# Epoch 8: train_acc_0.7551_train_loss_0.8040_val_acc_0.7588_val_loss_0.7845 epoch time 13.0110 seconds
# total time1.0 : 58.70081043243408
# loss: 0.5814, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 85.03it/s]
# loss: 0.6375, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 144.24it/s]
# loss: 0.6779, accuracy: 0.7400:   2%|▏         | 17/1000 [00:00<00:10, 92.27it/s]
# Epoch 9: train_acc_0.7608_train_loss_0.7781_val_acc_0.7634_val_loss_0.7664 epoch time 12.9982 seconds
# total time2.0 : 11.699049234390259
# loss: 0.6484, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:11<00:00, 85.00it/s]
# loss: 0.7499, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 141.97it/s]
# loss: 0.9749, accuracy: 0.7000:   2%|▏         | 18/1000 [00:00<00:10, 92.76it/s]
# Epoch 10: train_acc_0.7656_train_loss_0.7555_val_acc_0.7817_val_loss_0.7157 epoch time 13.0182 seconds
# total time2.0 : 24.717199563980103
# loss: 0.6581, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 85.02it/s]
# loss: 0.6967, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 142.61it/s]
# loss: 0.6861, accuracy: 0.7000:   2%|▏         | 18/1000 [00:00<00:10, 94.65it/s]
# Epoch 11: train_acc_0.7729_train_loss_0.7331_val_acc_0.7777_val_loss_0.7160 epoch time 13.0100 seconds
# total time2.0 : 37.7271842956543
# loss: 0.6412, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 87.80it/s]
# loss: 0.4349, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 142.29it/s]
# loss: 0.6856, accuracy: 0.7800:   2%|▏         | 18/1000 [00:00<00:10, 92.05it/s]
# Epoch 12: train_acc_0.7785_train_loss_0.7134_val_acc_0.7819_val_loss_0.7024 epoch time 12.7708 seconds
# total time2.0 : 50.49796986579895
# loss: 0.6009, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 84.99it/s]
# loss: 0.5903, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 141.02it/s]
# loss: 0.6123, accuracy: 0.8100:   2%|▏         | 17/1000 [00:00<00:11, 88.90it/s]
# Epoch 13: train_acc_0.7844_train_loss_0.6953_val_acc_0.7930_val_loss_0.6741 epoch time 13.0292 seconds
# total time3.0 : 3.5271897315979004
# loss: 0.5314, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 85.19it/s]
# loss: 0.7448, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 142.82it/s]
# loss: 0.8009, accuracy: 0.7400:   2%|▏         | 17/1000 [00:00<00:10, 92.44it/s]
# Epoch 14: train_acc_0.7885_train_loss_0.6792_val_acc_0.7980_val_loss_0.6503 epoch time 12.9858 seconds
# total time3.0 : 16.513009786605835
# loss: 0.5319, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 85.29it/s]
# loss: 0.6879, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 142.89it/s]
# loss: 0.6255, accuracy: 0.8200:   2%|▏         | 17/1000 [00:00<00:10, 89.65it/s]
# Epoch 15: train_acc_0.7926_train_loss_0.6648_val_acc_0.7920_val_loss_0.6655 epoch time 12.9715 seconds
# total time3.0 : 29.48452353477478
# loss: 0.8598, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:11<00:00, 84.86it/s]
# loss: 0.6404, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 143.63it/s]
# loss: 0.7508, accuracy: 0.8000:   2%|▏         | 17/1000 [00:00<00:10, 90.46it/s]
# Epoch 16: train_acc_0.7953_train_loss_0.6519_val_acc_0.7985_val_loss_0.6387 epoch time 13.0281 seconds
# total time3.0 : 42.512593269348145
# loss: 0.5354, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 85.10it/s]
# loss: 0.8491, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 144.13it/s]
# loss: 0.6052, accuracy: 0.8000:   2%|▏         | 17/1000 [00:00<00:10, 91.04it/s]
# Epoch 17: train_acc_0.7995_train_loss_0.6394_val_acc_0.8049_val_loss_0.6230 epoch time 12.9890 seconds
# total time3.0 : 55.50155854225159
# loss: 0.4537, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 85.09it/s]
# loss: 0.6353, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 142.01it/s]
# loss: 0.6821, accuracy: 0.7700:   2%|▏         | 18/1000 [00:00<00:10, 92.48it/s]
# Epoch 18: train_acc_0.8019_train_loss_0.6280_val_acc_0.8082_val_loss_0.6079 epoch time 13.0104 seconds
# total time4.0 : 8.512008428573608
# loss: 0.5725, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 85.17it/s]
# loss: 0.5473, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 144.69it/s]
# loss: 0.4228, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 94.40it/s]
# Epoch 19: train_acc_0.8055_train_loss_0.6167_val_acc_0.8066_val_loss_0.5983 epoch time 12.9737 seconds
# total time4.0 : 21.485758066177368
# loss: 0.6094, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 86.58it/s]
# loss: 0.5550, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 142.62it/s]
# loss: 0.5462, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 96.21it/s]
# Epoch 20: train_acc_0.8068_train_loss_0.6074_val_acc_0.8128_val_loss_0.5871 epoch time 13.0388 seconds
# total time4.0 : 34.524563789367676
# loss: 0.4328, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 85.12it/s]
# loss: 0.5437, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 143.49it/s]
# loss: 0.7430, accuracy: 0.7600:   2%|▏         | 17/1000 [00:00<00:10, 93.42it/s]
# Epoch 21: train_acc_0.8102_train_loss_0.5985_val_acc_0.8153_val_loss_0.5844 epoch time 12.9913 seconds
# total time4.0 : 47.51584267616272
# loss: 0.6228, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:11<00:00, 85.14it/s]
# loss: 0.5247, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 144.56it/s]
# loss: 0.8567, accuracy: 0.7400:   2%|▏         | 17/1000 [00:00<00:10, 90.75it/s]
# Epoch 22: train_acc_0.8119_train_loss_0.5887_val_acc_0.8192_val_loss_0.5705 epoch time 12.9810 seconds
# total time5.0 : 0.49683666229248047
# loss: 0.5973, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 85.05it/s]
# loss: 0.6527, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 142.84it/s]
# loss: 0.8050, accuracy: 0.7800:   2%|▏         | 17/1000 [00:00<00:10, 89.74it/s]
# Epoch 23: train_acc_0.8138_train_loss_0.5824_val_acc_0.8191_val_loss_0.5639 epoch time 13.0066 seconds
# total time5.0 : 13.503472328186035
# loss: 0.8880, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 85.07it/s]
# loss: 0.4142, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 145.12it/s]
# loss: 0.7890, accuracy: 0.7200:   2%|▏         | 17/1000 [00:00<00:10, 92.47it/s]
# Epoch 24: train_acc_0.8178_train_loss_0.5733_val_acc_0.8232_val_loss_0.5535 epoch time 12.9827 seconds
# total time5.0 : 26.486170768737793
# loss: 0.4664, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 84.95it/s]
# loss: 0.6726, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 143.77it/s]
# loss: 0.5976, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:10, 89.51it/s]
# Epoch 25: train_acc_0.8188_train_loss_0.5664_val_acc_0.8222_val_loss_0.5472 epoch time 13.0139 seconds
# total time5.0 : 39.50003004074097
# loss: 0.6242, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:11<00:00, 85.20it/s]
# loss: 0.6200, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 141.59it/s]
# loss: 0.5138, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 91.42it/s]
# Epoch 26: train_acc_0.8203_train_loss_0.5601_val_acc_0.8193_val_loss_0.5509 epoch time 12.9969 seconds
# total time5.0 : 52.4968945980072
# loss: 0.4825, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 85.43it/s]
# loss: 0.6208, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 142.64it/s]
# loss: 0.6858, accuracy: 0.8200:   2%|▏         | 17/1000 [00:00<00:10, 92.58it/s]
# Epoch 27: train_acc_0.8222_train_loss_0.5546_val_acc_0.8200_val_loss_0.5561 epoch time 12.9536 seconds
# total time6.0 : 5.450475215911865
# loss: 0.5754, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 85.07it/s]
# loss: 0.4117, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 142.30it/s]
# loss: 0.4104, accuracy: 0.8400:   2%|▏         | 17/1000 [00:00<00:10, 94.26it/s]
# Epoch 28: train_acc_0.8229_train_loss_0.5492_val_acc_0.8261_val_loss_0.5468 epoch time 13.0083 seconds
# total time6.0 : 18.4587984085083
# loss: 0.7553, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 85.98it/s]
# loss: 0.3635, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 147.68it/s]
# loss: 0.4127, accuracy: 0.8700:   2%|▏         | 18/1000 [00:00<00:10, 94.38it/s]
# Epoch 29: train_acc_0.8262_train_loss_0.5428_val_acc_0.8294_val_loss_0.5311 epoch time 12.8398 seconds
# total time6.0 : 31.29859185218811
# loss: 0.4240, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.86it/s]
# loss: 0.3920, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 144.77it/s]
# loss: 0.7408, accuracy: 0.7700:   2%|▏         | 17/1000 [00:00<00:10, 91.53it/s]
# Epoch 30: train_acc_0.8266_train_loss_0.5363_val_acc_0.8277_val_loss_0.5344 epoch time 12.6161 seconds
# total time6.0 : 43.91466546058655
# loss: 0.4389, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 85.66it/s]
# loss: 0.4281, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 145.21it/s]
# loss: 0.5759, accuracy: 0.7800:   2%|▏         | 17/1000 [00:00<00:10, 90.44it/s]
# Epoch 31: train_acc_0.8285_train_loss_0.5315_val_acc_0.8337_val_loss_0.5179 epoch time 12.9034 seconds
# total time6.0 : 56.81807994842529
# loss: 0.7091, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:11<00:00, 85.28it/s]
# loss: 0.6146, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 143.92it/s]
# loss: 0.3781, accuracy: 0.8500:   2%|▏         | 17/1000 [00:00<00:10, 90.83it/s]
# Epoch 32: train_acc_0.8292_train_loss_0.5267_val_acc_0.8298_val_loss_0.5194 epoch time 12.9650 seconds
# total time7.0 : 9.783127546310425
# loss: 0.4990, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 85.17it/s]
# loss: 0.4622, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 121.89it/s]
# loss: 0.5567, accuracy: 0.8200:   2%|▏         | 17/1000 [00:00<00:10, 93.28it/s]
# Epoch 33: train_acc_0.8313_train_loss_0.5221_val_acc_0.8350_val_loss_0.5081 epoch time 13.3062 seconds
# total time7.0 : 23.08932614326477
# loss: 0.6377, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:11<00:00, 85.40it/s]
# loss: 0.4942, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 142.89it/s]
# loss: 0.6078, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 96.75it/s]
# Epoch 34: train_acc_0.8327_train_loss_0.5181_val_acc_0.8307_val_loss_0.5129 epoch time 12.9569 seconds
# total time7.0 : 36.04627442359924
# loss: 0.8668, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:11<00:00, 87.32it/s]
# loss: 0.6655, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 147.59it/s]
# loss: 0.4234, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 95.51it/s]
# Epoch 35: train_acc_0.8336_train_loss_0.5138_val_acc_0.8301_val_loss_0.5150 epoch time 12.6636 seconds
# total time7.0 : 48.709874868392944
# loss: 0.6586, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 85.91it/s]
# loss: 0.4827, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 143.62it/s]
# loss: 0.3968, accuracy: 0.9000:   2%|▏         | 17/1000 [00:00<00:10, 91.70it/s]
# Epoch 36: train_acc_0.8344_train_loss_0.5105_val_acc_0.8304_val_loss_0.5155 epoch time 12.8815 seconds
# total time8.0 : 1.591383695602417
# loss: 0.5042, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 87.48it/s]
# loss: 0.3588, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 144.65it/s]
# loss: 0.3493, accuracy: 0.9200:   2%|▏         | 18/1000 [00:00<00:10, 92.19it/s]
# Epoch 37: train_acc_0.8344_train_loss_0.5078_val_acc_0.8398_val_loss_0.5006 epoch time 12.8271 seconds
# total time8.0 : 14.418509483337402
# loss: 0.4381, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 85.97it/s]
# loss: 0.4502, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 141.64it/s]
# loss: 0.4419, accuracy: 0.8600:   2%|▏         | 17/1000 [00:00<00:10, 93.91it/s]
# Epoch 38: train_acc_0.8358_train_loss_0.5036_val_acc_0.8406_val_loss_0.4939 epoch time 12.8926 seconds
# total time8.0 : 27.31109929084778
# loss: 0.3525, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:11<00:00, 86.59it/s]
# loss: 0.4728, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 142.30it/s]
# loss: 0.4763, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 93.21it/s]
# Epoch 39: train_acc_0.8376_train_loss_0.5005_val_acc_0.8345_val_loss_0.4972 epoch time 12.8020 seconds
# total time8.0 : 40.11305904388428
# loss: 0.3188, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:11<00:00, 85.91it/s]
# loss: 0.5918, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 142.97it/s]
# loss: 0.4258, accuracy: 0.8700:   2%|▏         | 17/1000 [00:00<00:10, 91.13it/s]
# Epoch 40: train_acc_0.8387_train_loss_0.4967_val_acc_0.8373_val_loss_0.4903 epoch time 12.8862 seconds
# total time8.0 : 52.999300718307495
# loss: 0.5745, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 86.41it/s]
# loss: 0.3484, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 143.21it/s]
# loss: 0.3180, accuracy: 0.9300:   2%|▏         | 18/1000 [00:00<00:10, 93.66it/s]
# Epoch 41: train_acc_0.8400_train_loss_0.4928_val_acc_0.8416_val_loss_0.4852 epoch time 12.8160 seconds
# total time9.0 : 5.815302848815918
# loss: 0.2676, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:11<00:00, 86.05it/s]
# loss: 0.5194, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 143.84it/s]
# loss: 0.5127, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:10, 93.17it/s]
# Epoch 42: train_acc_0.8392_train_loss_0.4915_val_acc_0.8411_val_loss_0.4906 epoch time 12.8613 seconds
# total time9.0 : 18.676618099212646
# loss: 0.3431, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:11<00:00, 86.21it/s]
# loss: 0.5098, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 143.85it/s]
# loss: 0.5495, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 94.04it/s]
# Epoch 43: train_acc_0.8403_train_loss_0.4883_val_acc_0.8412_val_loss_0.4838 epoch time 12.8401 seconds
# total time9.0 : 31.51675057411194
# loss: 0.2923, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 85.97it/s]
# loss: 0.3379, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 142.68it/s]
# loss: 0.3655, accuracy: 0.8800:   2%|▏         | 17/1000 [00:00<00:10, 93.32it/s]
# Epoch 44: train_acc_0.8419_train_loss_0.4857_val_acc_0.8435_val_loss_0.4819 epoch time 12.8838 seconds
# total time9.0 : 44.400545835494995
# loss: 0.4140, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 86.26it/s]
# loss: 0.4929, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 141.78it/s]
# loss: 0.5929, accuracy: 0.7900:   2%|▏         | 18/1000 [00:00<00:10, 93.16it/s]
# Epoch 45: train_acc_0.8422_train_loss_0.4826_val_acc_0.8411_val_loss_0.4852 epoch time 12.8505 seconds
# total time9.0 : 57.25107288360596
# loss: 0.5478, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 85.85it/s]
# loss: 0.4429, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 144.03it/s]
# loss: 0.4604, accuracy: 0.8500:   2%|▏         | 17/1000 [00:00<00:10, 91.35it/s]
# Epoch 46: train_acc_0.8418_train_loss_0.4817_val_acc_0.8403_val_loss_0.4836 epoch time 12.8854 seconds
# total time10.0 : 10.136449813842773
# loss: 0.5119, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 86.41it/s]
# loss: 0.4539, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 143.01it/s]
# loss: 0.6695, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 89.57it/s]
# Epoch 47: train_acc_0.8432_train_loss_0.4790_val_acc_0.8449_val_loss_0.4718 epoch time 12.8192 seconds
# total time10.0 : 22.955695390701294
# loss: 0.2989, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:11<00:00, 85.77it/s]
# loss: 0.4613, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 142.67it/s]
# loss: 0.6225, accuracy: 0.7900:   2%|▏         | 17/1000 [00:00<00:10, 90.56it/s]
# Epoch 48: train_acc_0.8435_train_loss_0.4760_val_acc_0.8462_val_loss_0.4731 epoch time 12.9075 seconds
# total time10.0 : 35.863227128982544
# loss: 0.5148, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 86.24it/s]
# loss: 0.5517, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 142.63it/s]
# loss: 0.4824, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 94.00it/s]
# Epoch 49: train_acc_0.8442_train_loss_0.4746_val_acc_0.8441_val_loss_0.4751 epoch time 12.8441 seconds
# total time10.0 : 48.70730924606323
# loss: 0.5281, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 86.14it/s]
# loss: 0.4201, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 144.84it/s]
# loss: 0.5134, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 94.34it/s]
# Epoch 50: train_acc_0.8458_train_loss_0.4726_val_acc_0.8480_val_loss_0.4638 epoch time 12.8415 seconds
# total time11.0 : 1.5487985610961914
# loss: 0.3370, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:11<00:00, 86.79it/s]
# loss: 0.5229, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 142.03it/s]
# loss: 0.3570, accuracy: 0.9000:   2%|▏         | 18/1000 [00:00<00:10, 96.80it/s]
# Epoch 51: train_acc_0.8471_train_loss_0.4694_val_acc_0.8376_val_loss_0.4795 epoch time 12.7773 seconds
# total time11.0 : 14.326062440872192
# loss: 0.4420, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 86.51it/s]
# loss: 0.4509, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 144.07it/s]
# loss: 0.5459, accuracy: 0.8500:   2%|▏         | 18/1000 [00:00<00:10, 93.63it/s]
# Epoch 52: train_acc_0.8460_train_loss_0.4686_val_acc_0.8442_val_loss_0.4715 epoch time 12.7957 seconds
# total time11.0 : 27.121739864349365
# loss: 0.3355, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 87.00it/s]
# loss: 0.4717, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 148.87it/s]
# loss: 0.4596, accuracy: 0.8500:   2%|▏         | 18/1000 [00:00<00:10, 96.45it/s]
# Epoch 53: train_acc_0.8464_train_loss_0.4653_val_acc_0.8408_val_loss_0.4736 epoch time 12.6945 seconds
# total time11.0 : 39.81620144844055
# loss: 0.5237, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 89.92it/s]
# loss: 0.3655, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 143.23it/s]
# loss: 0.4452, accuracy: 0.8100:   2%|▏         | 18/1000 [00:00<00:10, 92.27it/s]
# Epoch 54: train_acc_0.8467_train_loss_0.4643_val_acc_0.8495_val_loss_0.4556 epoch time 12.3661 seconds
# total time11.0 : 52.182270526885986
# loss: 0.4957, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 86.62it/s]
# loss: 0.3425, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 143.54it/s]
# loss: 0.4983, accuracy: 0.9100:   2%|▏         | 18/1000 [00:00<00:10, 94.60it/s]
# Epoch 55: train_acc_0.8481_train_loss_0.4629_val_acc_0.8484_val_loss_0.4613 epoch time 12.7858 seconds
# total time12.0 : 4.968024253845215
# loss: 0.4801, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.22it/s]
# loss: 0.3347, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 145.17it/s]
# loss: 0.5137, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 92.82it/s]
# Epoch 56: train_acc_0.8484_train_loss_0.4604_val_acc_0.8496_val_loss_0.4587 epoch time 12.6974 seconds
# total time12.0 : 17.665459394454956
# loss: 0.6114, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 87.18it/s]
# loss: 0.3698, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 143.88it/s]
# loss: 0.3887, accuracy: 0.8600:   2%|▏         | 18/1000 [00:00<00:10, 96.65it/s]
# Epoch 57: train_acc_0.8485_train_loss_0.4593_val_acc_0.8464_val_loss_0.4632 epoch time 12.7121 seconds
# total time12.0 : 30.3775634765625
# loss: 0.4690, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 86.79it/s]
# loss: 0.4249, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 143.22it/s]
# loss: 0.5558, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 95.48it/s]
# Epoch 58: train_acc_0.8497_train_loss_0.4571_val_acc_0.8468_val_loss_0.4602 epoch time 12.7666 seconds
# total time12.0 : 43.14421224594116
# loss: 0.5087, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 88.66it/s]
# loss: 0.3417, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 141.80it/s]
# loss: 0.4769, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 92.99it/s]
# Epoch 59: train_acc_0.8493_train_loss_0.4561_val_acc_0.8495_val_loss_0.4532 epoch time 12.5369 seconds
# total time12.0 : 55.68107295036316
# loss: 0.8151, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 89.76it/s]
# loss: 0.3441, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 142.71it/s]
# loss: 0.3925, accuracy: 0.8700:   2%|▏         | 17/1000 [00:00<00:10, 95.03it/s]
# Epoch 60: train_acc_0.8501_train_loss_0.4537_val_acc_0.8497_val_loss_0.4599 epoch time 12.7037 seconds
# total time13.0 : 8.38481593132019
# loss: 0.4003, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:11<00:00, 86.79it/s]
# loss: 0.5541, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 145.42it/s]
# loss: 0.3660, accuracy: 0.8600:   2%|▏         | 17/1000 [00:00<00:10, 91.99it/s]
# Epoch 61: train_acc_0.8516_train_loss_0.4526_val_acc_0.8493_val_loss_0.4552 epoch time 12.7500 seconds
# total time13.0 : 21.134775400161743
# loss: 0.6498, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 86.95it/s]
# loss: 0.2834, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 144.10it/s]
# loss: 0.3470, accuracy: 0.9000:   2%|▏         | 18/1000 [00:00<00:10, 94.14it/s]
# Epoch 62: train_acc_0.8512_train_loss_0.4507_val_acc_0.8465_val_loss_0.4596 epoch time 12.7400 seconds
# total time13.0 : 33.87480688095093
# loss: 0.8985, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:11<00:00, 90.66it/s]
# loss: 0.4033, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 144.56it/s]
# loss: 0.3371, accuracy: 0.8700:   2%|▏         | 18/1000 [00:00<00:10, 93.90it/s]
# Epoch 63: train_acc_0.8512_train_loss_0.4489_val_acc_0.8470_val_loss_0.4503 epoch time 12.5807 seconds
# total time13.0 : 46.45547008514404
# loss: 0.3735, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 87.23it/s]
# loss: 0.4036, accuracy: 0.9400: 100%|██████████| 158/158 [00:01<00:00, 144.16it/s]
# loss: 0.4135, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 93.98it/s]
# Epoch 64: train_acc_0.8519_train_loss_0.4489_val_acc_0.8492_val_loss_0.4498 epoch time 12.7030 seconds
# total time13.0 : 59.158499002456665
# loss: 0.4608, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 87.75it/s]
# loss: 0.3999, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 143.82it/s]
# loss: 0.4323, accuracy: 0.8600:   2%|▏         | 18/1000 [00:00<00:10, 95.16it/s]
# Epoch 65: train_acc_0.8525_train_loss_0.4470_val_acc_0.8502_val_loss_0.4505 epoch time 12.6399 seconds
# total time14.0 : 11.798415660858154
# loss: 0.6038, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 88.36it/s]
# loss: 0.3381, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 145.44it/s]
# loss: 0.4765, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:10, 93.36it/s]
# Epoch 66: train_acc_0.8530_train_loss_0.4452_val_acc_0.8512_val_loss_0.4479 epoch time 12.5454 seconds
# total time14.0 : 24.343858242034912
# loss: 0.5001, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 88.13it/s]
# loss: 0.4985, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 143.37it/s]
# loss: 0.3821, accuracy: 0.8600:   2%|▏         | 18/1000 [00:00<00:10, 92.97it/s]
# Epoch 67: train_acc_0.8530_train_loss_0.4440_val_acc_0.8485_val_loss_0.4521 epoch time 12.6439 seconds
# total time14.0 : 36.98774242401123
# loss: 0.4756, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 87.85it/s]
# loss: 0.5192, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 143.62it/s]
# loss: 0.4416, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 94.58it/s]
# Epoch 68: train_acc_0.8531_train_loss_0.4437_val_acc_0.8513_val_loss_0.4469 epoch time 12.6248 seconds
# total time14.0 : 49.61254405975342
# loss: 0.4762, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 87.42it/s]
# loss: 0.4114, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 151.73it/s]
# loss: 0.3427, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:10, 94.78it/s]
# Epoch 69: train_acc_0.8532_train_loss_0.4418_val_acc_0.8494_val_loss_0.4457 epoch time 12.6635 seconds
# total time15.0 : 2.276031255722046
# loss: 0.6428, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 88.19it/s]
# loss: 0.4279, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 155.18it/s]
# loss: 0.4959, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:09, 98.30it/s]
# Epoch 70: train_acc_0.8533_train_loss_0.4404_val_acc_0.8561_val_loss_0.4375 epoch time 12.5497 seconds
# total time15.0 : 14.825743913650513
# loss: 0.3901, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.33it/s]
# loss: 0.6032, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 143.86it/s]
# loss: 0.3582, accuracy: 0.8700:   2%|▏         | 18/1000 [00:00<00:10, 91.74it/s]
# Epoch 71: train_acc_0.8540_train_loss_0.4393_val_acc_0.8562_val_loss_0.4430 epoch time 12.6912 seconds
# total time15.0 : 27.516955137252808
# loss: 0.4765, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 87.55it/s]
# loss: 0.4768, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 144.04it/s]
# loss: 0.3828, accuracy: 0.8700:   2%|▏         | 18/1000 [00:00<00:10, 94.31it/s]
# Epoch 72: train_acc_0.8546_train_loss_0.4376_val_acc_0.8503_val_loss_0.4423 epoch time 12.6620 seconds
# total time15.0 : 40.17894673347473
# loss: 0.5275, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 87.14it/s]
# loss: 0.6235, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 144.17it/s]
# loss: 0.5507, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 97.06it/s]
# Epoch 73: train_acc_0.8549_train_loss_0.4365_val_acc_0.8506_val_loss_0.4452 epoch time 12.7143 seconds
# total time15.0 : 52.89327001571655
# loss: 0.4344, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 86.88it/s]
# loss: 0.4001, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 141.97it/s]
# loss: 0.5390, accuracy: 0.8100:   2%|▏         | 17/1000 [00:00<00:10, 92.99it/s]
# Epoch 74: train_acc_0.8539_train_loss_0.4366_val_acc_0.8535_val_loss_0.4386 epoch time 12.7666 seconds
# total time16.0 : 5.659825086593628
# loss: 0.5028, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 87.83it/s]
# loss: 0.4979, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 142.93it/s]
# loss: 0.4285, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:10, 95.51it/s]
# Epoch 75: train_acc_0.8556_train_loss_0.4343_val_acc_0.8532_val_loss_0.4435 epoch time 12.6334 seconds
# total time16.0 : 18.293200254440308
# loss: 0.5384, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 87.15it/s]
# loss: 0.3429, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 136.88it/s]
# loss: 0.5262, accuracy: 0.8500:   2%|▏         | 17/1000 [00:00<00:10, 92.08it/s]
# Epoch 76: train_acc_0.8565_train_loss_0.4333_val_acc_0.8583_val_loss_0.4346 epoch time 12.7723 seconds
# total time16.0 : 31.065451860427856
# loss: 0.4517, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 85.57it/s]
# loss: 0.3538, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 143.11it/s]
# loss: 0.5330, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 95.05it/s]
# Epoch 77: train_acc_0.8553_train_loss_0.4331_val_acc_0.8547_val_loss_0.4344 epoch time 12.9308 seconds
# total time16.0 : 43.996256828308105
# loss: 0.3668, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 88.36it/s]
# loss: 0.5288, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 149.71it/s]
# loss: 0.3363, accuracy: 0.8800:   2%|▏         | 19/1000 [00:00<00:09, 98.69it/s]
# Epoch 78: train_acc_0.8569_train_loss_0.4310_val_acc_0.8521_val_loss_0.4418 epoch time 12.5106 seconds
# total time16.0 : 56.5068142414093
# loss: 0.4276, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.81it/s]
# loss: 0.3909, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 142.44it/s]
# loss: 0.3984, accuracy: 0.8900:   2%|▏         | 17/1000 [00:00<00:10, 93.27it/s]
# Epoch 79: train_acc_0.8557_train_loss_0.4315_val_acc_0.8544_val_loss_0.4338 epoch time 12.6393 seconds
# total time17.0 : 9.146162033081055
# loss: 0.4605, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 88.35it/s]
# loss: 0.5171, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 143.20it/s]
# loss: 0.5551, accuracy: 0.8900:   2%|▏         | 18/1000 [00:00<00:09, 99.04it/s]
# Epoch 80: train_acc_0.8569_train_loss_0.4295_val_acc_0.8558_val_loss_0.4347 epoch time 12.7086 seconds
# total time17.0 : 21.854804754257202
# loss: 0.3486, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.63it/s]
# loss: 0.4008, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 142.42it/s]
# loss: 0.4781, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:09, 99.86it/s]
# Epoch 81: train_acc_0.8562_train_loss_0.4277_val_acc_0.8566_val_loss_0.4337 epoch time 12.6627 seconds
# total time17.0 : 34.517499685287476
# loss: 0.4660, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 87.02it/s]
# loss: 0.4422, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 143.10it/s]
# loss: 0.4873, accuracy: 0.8100:   2%|▏         | 17/1000 [00:00<00:10, 93.49it/s]
# Epoch 82: train_acc_0.8573_train_loss_0.4283_val_acc_0.8547_val_loss_0.4314 epoch time 12.7369 seconds
# total time17.0 : 47.25442671775818
# loss: 0.7049, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 88.13it/s]
# loss: 0.3057, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 143.01it/s]
# loss: 0.4347, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 96.82it/s]
# Epoch 83: train_acc_0.8576_train_loss_0.4268_val_acc_0.8559_val_loss_0.4360 epoch time 12.5941 seconds
# total time17.0 : 59.848567962646484
# loss: 0.6571, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 87.56it/s]
# loss: 0.4476, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 144.81it/s]
# loss: 0.2886, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:10, 94.34it/s]
# Epoch 84: train_acc_0.8575_train_loss_0.4258_val_acc_0.8571_val_loss_0.4335 epoch time 12.6505 seconds
# total time18.0 : 12.499111652374268
# loss: 0.5291, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 86.67it/s]
# loss: 0.3445, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 145.05it/s]
# loss: 0.4460, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 93.52it/s]
# Epoch 85: train_acc_0.8585_train_loss_0.4244_val_acc_0.8548_val_loss_0.4293 epoch time 12.7702 seconds
# total time18.0 : 25.269275903701782
# loss: 0.4488, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 86.70it/s]
# loss: 0.3422, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 145.20it/s]
# loss: 0.2908, accuracy: 0.8900:   2%|▏         | 18/1000 [00:00<00:10, 97.20it/s]
# Epoch 86: train_acc_0.8576_train_loss_0.4234_val_acc_0.8554_val_loss_0.4403 epoch time 12.7630 seconds
# total time18.0 : 38.032275915145874
# loss: 0.4210, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.30it/s]
# loss: 0.2818, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 142.66it/s]
# loss: 0.4891, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 91.48it/s]
# Epoch 87: train_acc_0.8588_train_loss_0.4223_val_acc_0.8537_val_loss_0.4386 epoch time 12.7030 seconds
# total time18.0 : 50.735251665115356
# loss: 0.4135, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 87.11it/s]
# loss: 0.3789, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 143.83it/s]
# loss: 0.3708, accuracy: 0.8400:   2%|▏         | 18/1000 [00:00<00:10, 94.72it/s]
# Epoch 88: train_acc_0.8589_train_loss_0.4221_val_acc_0.8580_val_loss_0.4257 epoch time 12.7174 seconds
# total time19.0 : 3.452674150466919
# loss: 0.6618, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 87.36it/s]
# loss: 0.4460, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 143.28it/s]
# loss: 0.4207, accuracy: 0.8900:   2%|▏         | 18/1000 [00:00<00:10, 96.31it/s]
# Epoch 89: train_acc_0.8585_train_loss_0.4215_val_acc_0.8554_val_loss_0.4277 epoch time 12.6898 seconds
# total time19.0 : 16.14247226715088
# loss: 0.3773, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 88.09it/s]
# loss: 0.3557, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 145.73it/s]
# loss: 0.3302, accuracy: 0.8700:   2%|▏         | 17/1000 [00:00<00:10, 92.36it/s]
# Epoch 90: train_acc_0.8602_train_loss_0.4202_val_acc_0.8584_val_loss_0.4244 epoch time 12.5784 seconds
# total time19.0 : 28.720831632614136
# loss: 0.4335, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 88.04it/s]
# loss: 0.5153, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 146.46it/s]
# loss: 0.3717, accuracy: 0.8300:   2%|▏         | 18/1000 [00:00<00:10, 93.95it/s]
# Epoch 91: train_acc_0.8592_train_loss_0.4198_val_acc_0.8587_val_loss_0.4262 epoch time 12.5776 seconds
# total time19.0 : 41.29840612411499
# loss: 0.5456, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 87.57it/s]
# loss: 0.5151, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 144.48it/s]
# loss: 0.5238, accuracy: 0.8100:   2%|▏         | 18/1000 [00:00<00:10, 93.00it/s]
# Epoch 92: train_acc_0.8599_train_loss_0.4198_val_acc_0.8537_val_loss_0.4292 epoch time 12.6539 seconds
# total time19.0 : 53.95228457450867
# loss: 0.3663, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 87.86it/s]
# loss: 0.4631, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 141.59it/s]
# loss: 0.3318, accuracy: 0.8700:   2%|▏         | 18/1000 [00:00<00:10, 93.53it/s]
# Epoch 93: train_acc_0.8594_train_loss_0.4190_val_acc_0.8580_val_loss_0.4307 epoch time 12.6386 seconds
# total time20.0 : 6.590839147567749
# loss: 0.4199, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 87.50it/s]
# loss: 0.5943, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 144.23it/s]
# loss: 0.5695, accuracy: 0.8600:   2%|▏         | 19/1000 [00:00<00:09, 98.86it/s]
# Epoch 94: train_acc_0.8605_train_loss_0.4178_val_acc_0.8583_val_loss_0.4253 epoch time 12.6658 seconds
# total time20.0 : 19.256653785705566
# loss: 0.3385, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:11<00:00, 87.38it/s]
# loss: 0.6631, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 142.35it/s]
# loss: 0.4528, accuracy: 0.8500:   2%|▏         | 18/1000 [00:00<00:09, 98.81it/s]
# Epoch 95: train_acc_0.8603_train_loss_0.4174_val_acc_0.8541_val_loss_0.4271 epoch time 12.6969 seconds
# total time20.0 : 31.953545093536377
# loss: 0.4827, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 87.75it/s]
# loss: 0.4605, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 143.28it/s]
# loss: 0.2587, accuracy: 0.9100:   2%|▏         | 17/1000 [00:00<00:10, 92.36it/s]
# Epoch 96: train_acc_0.8612_train_loss_0.4157_val_acc_0.8604_val_loss_0.4219 epoch time 12.6397 seconds
# total time20.0 : 44.593273401260376
# loss: 0.3961, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:11<00:00, 87.67it/s]
# loss: 0.4881, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 143.34it/s]
# loss: 0.5315, accuracy: 0.8600:   2%|▏         | 18/1000 [00:00<00:10, 96.25it/s]
# Epoch 97: train_acc_0.8604_train_loss_0.4163_val_acc_0.8588_val_loss_0.4266 epoch time 12.6521 seconds
# total time20.0 : 57.24538254737854
# loss: 0.3415, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:11<00:00, 87.41it/s]
# loss: 0.6398, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 144.76it/s]
# loss: 0.3960, accuracy: 0.8800:   2%|▏         | 18/1000 [00:00<00:10, 97.43it/s]
# Epoch 98: train_acc_0.8606_train_loss_0.4149_val_acc_0.8568_val_loss_0.4237 epoch time 12.6723 seconds
# total time21.0 : 9.917659759521484
# loss: 0.3099, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:11<00:00, 87.13it/s]
# loss: 0.4122, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 145.86it/s]
# loss: 0.4149, accuracy: 0.8700:  18%|█▊        | 29/158 [00:00<00:00, 154.66it/s]
# Epoch 99: train_acc_0.8608_train_loss_0.4143_val_acc_0.8580_val_loss_0.4222 epoch time 12.7019 seconds
# total time21.0 : 22.619597673416138
# Generating test set evaluation metrics
# loss: 0.5037, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 144.48it/s]
# finish
# loss: 3.8411, accuracy: 0.0400:   0%|          | 4/1000 [00:00<00:15, 65.06it/s]
# stride2_filter32_layer2_type0
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 14, 14])
# torch.Size([100, 32, 14, 14])
# torch.Size([100, 32, 7, 7])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_strided_conv_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_strided_conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 1.0387, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:13<00:00, 73.70it/s]
# loss: 0.9546, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 140.24it/s]
# loss: 0.7884, accuracy: 0.7300:   2%|▏         | 15/1000 [00:00<00:12, 80.38it/s]
# Epoch 0: train_acc_0.5427_train_loss_1.6098_val_acc_0.7270_val_loss_0.8687 epoch time 14.8471 seconds
# total time0.0 : 14.847100257873535
# loss: 0.8159, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:13<00:00, 74.85it/s]
# loss: 0.5449, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 140.06it/s]
# loss: 0.6685, accuracy: 0.7900:   2%|▏         | 15/1000 [00:00<00:12, 79.58it/s]
# Epoch 1: train_acc_0.7612_train_loss_0.7643_val_acc_0.7799_val_loss_0.6875 epoch time 14.6258 seconds
# total time0.0 : 29.472872734069824
# loss: 0.4230, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 76.41it/s]
# loss: 0.7589, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 139.99it/s]
# loss: 0.6457, accuracy: 0.8200:   2%|▏         | 15/1000 [00:00<00:12, 79.73it/s]
# Epoch 2: train_acc_0.7948_train_loss_0.6377_val_acc_0.8106_val_loss_0.5920 epoch time 14.3570 seconds
# total time0.0 : 43.82990503311157
# loss: 0.6955, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 74.67it/s]
# loss: 0.4253, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 141.16it/s]
# loss: 0.7419, accuracy: 0.7500:   2%|▏         | 15/1000 [00:00<00:12, 79.18it/s]
# Epoch 3: train_acc_0.8156_train_loss_0.5673_val_acc_0.8205_val_loss_0.5554 epoch time 14.6532 seconds
# total time0.0 : 58.48309373855591
# loss: 0.5941, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:13<00:00, 74.65it/s]
# loss: 0.3670, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 138.55it/s]
# loss: 0.5507, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:12, 76.85it/s]
# Epoch 4: train_acc_0.8264_train_loss_0.5228_val_acc_0.8340_val_loss_0.5001 epoch time 14.6782 seconds
# total time1.0 : 13.161297082901001
# loss: 0.5191, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 74.66it/s]
# loss: 0.3695, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 138.23it/s]
# loss: 0.7853, accuracy: 0.8400:   2%|▏         | 15/1000 [00:00<00:12, 79.04it/s]
# Epoch 5: train_acc_0.8364_train_loss_0.4920_val_acc_0.8405_val_loss_0.4685 epoch time 14.6790 seconds
# total time1.0 : 27.8403103351593
# loss: 0.4313, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:13<00:00, 75.88it/s]
# loss: 0.3529, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 137.55it/s]
# loss: 0.5416, accuracy: 0.8400:   2%|▏         | 15/1000 [00:00<00:12, 79.44it/s]
# Epoch 6: train_acc_0.8420_train_loss_0.4684_val_acc_0.8425_val_loss_0.4641 epoch time 14.4698 seconds
# total time1.0 : 42.31012272834778
# loss: 0.4426, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 74.59it/s]
# loss: 0.4197, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 139.99it/s]
# loss: 0.2647, accuracy: 0.8700:   2%|▏         | 15/1000 [00:00<00:12, 77.45it/s]
# Epoch 7: train_acc_0.8473_train_loss_0.4515_val_acc_0.8401_val_loss_0.4599 epoch time 14.6781 seconds
# total time1.0 : 56.98826742172241
# loss: 0.7568, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:13<00:00, 74.75it/s]
# loss: 0.5066, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 139.60it/s]
# loss: 0.3420, accuracy: 0.8500:   2%|▏         | 15/1000 [00:00<00:12, 80.94it/s]
# Epoch 8: train_acc_0.8525_train_loss_0.4376_val_acc_0.8525_val_loss_0.4329 epoch time 14.6510 seconds
# total time2.0 : 11.639265775680542
# loss: 0.6696, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 74.78it/s]
# loss: 0.4874, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 139.96it/s]
# loss: 0.6341, accuracy: 0.8000:   2%|▏         | 15/1000 [00:00<00:12, 80.09it/s]
# Epoch 9: train_acc_0.8545_train_loss_0.4240_val_acc_0.8475_val_loss_0.4591 epoch time 14.6449 seconds
# total time2.0 : 26.2841215133667
# loss: 0.3405, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 74.56it/s]
# loss: 0.3261, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 140.53it/s]
# loss: 0.3198, accuracy: 0.8900:   2%|▏         | 15/1000 [00:00<00:12, 78.47it/s]
# Epoch 10: train_acc_0.8587_train_loss_0.4127_val_acc_0.8623_val_loss_0.4046 epoch time 14.6800 seconds
# total time2.0 : 40.96408247947693
# loss: 0.3987, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 74.52it/s]
# loss: 0.3927, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 139.82it/s]
# loss: 0.3825, accuracy: 0.8800:   2%|▏         | 15/1000 [00:00<00:12, 81.22it/s]
# Epoch 11: train_acc_0.8615_train_loss_0.4041_val_acc_0.8642_val_loss_0.3962 epoch time 14.6895 seconds
# total time2.0 : 55.65355849266052
# loss: 0.3226, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 74.63it/s]
# loss: 0.4359, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 141.27it/s]
# loss: 0.4047, accuracy: 0.8000:   2%|▏         | 15/1000 [00:00<00:12, 78.40it/s]
# Epoch 12: train_acc_0.8640_train_loss_0.3959_val_acc_0.8644_val_loss_0.3939 epoch time 14.6602 seconds
# total time3.0 : 10.313716173171997
# loss: 0.3384, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 74.54it/s]
# loss: 0.3329, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 139.99it/s]
# loss: 0.3439, accuracy: 0.8500:   2%|▏         | 15/1000 [00:00<00:12, 79.21it/s]
# Epoch 13: train_acc_0.8665_train_loss_0.3890_val_acc_0.8639_val_loss_0.3929 epoch time 14.6872 seconds
# total time3.0 : 25.000963926315308
# loss: 0.5208, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 74.70it/s]
# loss: 0.2432, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 139.04it/s]
# loss: 0.4309, accuracy: 0.8700:   2%|▏         | 15/1000 [00:00<00:12, 79.07it/s]
# Epoch 14: train_acc_0.8675_train_loss_0.3819_val_acc_0.8712_val_loss_0.3803 epoch time 14.6688 seconds
# total time3.0 : 39.66978430747986
# loss: 0.2989, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 75.75it/s]
# loss: 0.3643, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 140.42it/s]
# loss: 0.3983, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 77.63it/s]
# Epoch 15: train_acc_0.8705_train_loss_0.3751_val_acc_0.8678_val_loss_0.3866 epoch time 14.7307 seconds
# total time3.0 : 54.40045928955078
# loss: 0.4413, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 74.64it/s]
# loss: 0.5219, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 142.21it/s]
# loss: 0.3130, accuracy: 0.8500:   2%|▏         | 15/1000 [00:00<00:12, 79.58it/s]
# Epoch 16: train_acc_0.8701_train_loss_0.3720_val_acc_0.8685_val_loss_0.3722 epoch time 14.6507 seconds
# total time4.0 : 9.051149606704712
# loss: 0.2807, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 74.60it/s]
# loss: 0.2618, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 139.27it/s]
# loss: 0.2726, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 79.35it/s]
# Epoch 17: train_acc_0.8730_train_loss_0.3658_val_acc_0.8602_val_loss_0.3811 epoch time 14.6794 seconds
# total time4.0 : 23.730594396591187
# loss: 0.2551, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.67it/s]
# loss: 0.3360, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 142.40it/s]
# loss: 0.2561, accuracy: 0.9200:   2%|▏         | 15/1000 [00:00<00:12, 79.38it/s]
# Epoch 18: train_acc_0.8739_train_loss_0.3621_val_acc_0.8691_val_loss_0.3751 epoch time 14.6434 seconds
# total time4.0 : 38.37399339675903
# ...
# loss: 0.6947, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 132.47it/s]
# loss: 0.0902, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 65.76it/s]
# Epoch 59: train_acc_0.9484_train_loss_0.1228_val_acc_0.8636_val_loss_0.6616 epoch time 17.6644 seconds
# total time17.0 : 38.66297483444214
# loss: 0.1515, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:16<00:00, 61.42it/s]
# loss: 0.4597, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.42it/s]
# loss: 0.1000, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 63.56it/s]
# Epoch 60: train_acc_0.9500_train_loss_0.1161_val_acc_0.8601_val_loss_0.6602 epoch time 17.6146 seconds
# total time17.0 : 56.27758002281189
# loss: 0.1718, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:16<00:00, 61.27it/s]
# loss: 0.1776, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 132.84it/s]
# loss: 0.1011, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 64.52it/s]
# Epoch 61: train_acc_0.9504_train_loss_0.1188_val_acc_0.8608_val_loss_0.7054 epoch time 17.6540 seconds
# total time18.0 : 13.931585788726807
# loss: 0.0651, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:16<00:00, 61.37it/s]
# loss: 0.6617, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 134.56it/s]
# loss: 0.0778, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 64.24it/s]
# Epoch 62: train_acc_0.9509_train_loss_0.1197_val_acc_0.8621_val_loss_0.7131 epoch time 17.6112 seconds
# total time18.0 : 31.542804718017578
# loss: 0.1651, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:16<00:00, 61.25it/s]
# loss: 0.4314, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 131.27it/s]
# loss: 0.1378, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 63.39it/s]
# Epoch 63: train_acc_0.9509_train_loss_0.1168_val_acc_0.8646_val_loss_0.6642 epoch time 17.6758 seconds
# total time18.0 : 49.218602418899536
# loss: 0.1876, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# loss: 1.0364, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 134.94it/s]
# loss: 0.1205, accuracy: 0.9400:   1%|          | 12/1000 [00:00<00:15, 61.84it/s]
# Epoch 64: train_acc_0.9528_train_loss_0.1142_val_acc_0.8628_val_loss_0.6822 epoch time 17.6233 seconds
# total time19.0 : 6.841897964477539
# loss: 0.0908, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:16<00:00, 61.29it/s]
# loss: 0.3764, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 132.42it/s]
# loss: 0.0858, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 65.07it/s]
# Epoch 65: train_acc_0.9527_train_loss_0.1136_val_acc_0.8627_val_loss_0.6828 epoch time 17.6487 seconds
# total time19.0 : 24.490549564361572
# loss: 0.0889, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:16<00:00, 61.41it/s]
# loss: 0.5142, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 135.02it/s]
# loss: 0.0726, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 64.36it/s]
# Epoch 66: train_acc_0.9532_train_loss_0.1112_val_acc_0.8585_val_loss_0.7486 epoch time 17.5959 seconds
# total time19.0 : 42.08640384674072
# loss: 0.2010, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:16<00:00, 61.58it/s]
# loss: 0.5996, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 137.41it/s]
# loss: 0.0604, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 64.81it/s]
# Epoch 67: train_acc_0.9530_train_loss_0.1129_val_acc_0.8633_val_loss_0.7025 epoch time 17.5663 seconds
# total time19.0 : 59.65267729759216
# loss: 0.2561, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:16<00:00, 61.16it/s]
# loss: 0.7239, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.42it/s]
# loss: 0.0828, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 65.27it/s]
# Epoch 68: train_acc_0.9537_train_loss_0.1124_val_acc_0.8630_val_loss_0.6917 epoch time 17.6834 seconds
# total time20.0 : 17.33603072166443
# loss: 0.1560, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:16<00:00, 61.34it/s]
# loss: 0.6089, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 133.23it/s]
# loss: 0.0469, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 65.36it/s]
# Epoch 69: train_acc_0.9538_train_loss_0.1098_val_acc_0.8634_val_loss_0.7061 epoch time 17.6326 seconds
# total time20.0 : 34.968650817871094
# loss: 0.1781, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.89it/s]
# loss: 0.5568, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 131.38it/s]
# loss: 0.1000, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 65.57it/s]
# Epoch 70: train_acc_0.9546_train_loss_0.1088_val_acc_0.8660_val_loss_0.6911 epoch time 17.5008 seconds
# total time20.0 : 52.46947765350342
# loss: 0.1071, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:15<00:00, 63.47it/s]
# loss: 1.0369, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 134.98it/s]
# loss: 0.0844, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 65.04it/s]
# Epoch 71: train_acc_0.9539_train_loss_0.1105_val_acc_0.8584_val_loss_0.7249 epoch time 17.0667 seconds
# total time21.0 : 9.536154508590698
# loss: 0.2761, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# loss: 0.4717, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 138.65it/s]
# loss: 0.2029, accuracy: 0.9300:   1%|          | 12/1000 [00:00<00:15, 65.61it/s]
# Epoch 72: train_acc_0.9554_train_loss_0.1064_val_acc_0.8615_val_loss_0.7418 epoch time 17.6413 seconds
# total time21.0 : 27.17746639251709
# loss: 0.1229, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:16<00:00, 61.28it/s]
# loss: 0.5421, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 131.39it/s]
# loss: 0.0741, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:14, 65.98it/s]
# Epoch 73: train_acc_0.9548_train_loss_0.1111_val_acc_0.8601_val_loss_0.7086 epoch time 17.6622 seconds
# total time21.0 : 44.83965563774109
# loss: 0.0529, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:16<00:00, 61.41it/s]
# loss: 1.3622, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 132.68it/s]
# loss: 0.1258, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 65.17it/s]
# Epoch 74: train_acc_0.9554_train_loss_0.1060_val_acc_0.8616_val_loss_0.7376 epoch time 17.6184 seconds
# total time22.0 : 2.4580986499786377
# loss: 0.0451, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:16<00:00, 61.32it/s]
# loss: 0.6510, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 132.82it/s]
# loss: 0.0546, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 65.67it/s]
# Epoch 75: train_acc_0.9559_train_loss_0.1060_val_acc_0.8645_val_loss_0.7520 epoch time 17.6375 seconds
# total time22.0 : 20.095577239990234
# loss: 0.1172, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:16<00:00, 61.36it/s]
# loss: 1.0501, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 132.70it/s]
# loss: 0.0689, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 64.40it/s]
# Epoch 76: train_acc_0.9557_train_loss_0.1074_val_acc_0.8666_val_loss_0.7395 epoch time 17.6304 seconds
# total time22.0 : 37.72593545913696
# loss: 0.1016, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.29it/s]
# loss: 0.5497, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 133.00it/s]
# loss: 0.0653, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 65.56it/s]
# Epoch 77: train_acc_0.9564_train_loss_0.1056_val_acc_0.8634_val_loss_0.7517 epoch time 17.6430 seconds
# total time22.0 : 55.36892056465149
# loss: 0.1174, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 62.66it/s]
# loss: 0.6524, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 131.87it/s]
# loss: 0.1787, accuracy: 0.9400:   1%|          | 12/1000 [00:00<00:14, 65.98it/s]
# Epoch 78: train_acc_0.9572_train_loss_0.1056_val_acc_0.8606_val_loss_0.7371 epoch time 17.7125 seconds
# total time23.0 : 13.08143424987793
# loss: 0.1092, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:16<00:00, 61.35it/s]
# loss: 0.9381, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 131.34it/s]
# loss: 0.1243, accuracy: 0.9400:   1%|          | 12/1000 [00:00<00:15, 64.55it/s]
# Epoch 79: train_acc_0.9574_train_loss_0.1033_val_acc_0.8617_val_loss_0.7810 epoch time 17.6451 seconds
# total time23.0 : 30.726531982421875
# loss: 0.1078, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:16<00:00, 61.33it/s]
# loss: 0.7910, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 134.68it/s]
# loss: 0.1310, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 65.33it/s]
# Epoch 80: train_acc_0.9567_train_loss_0.1043_val_acc_0.8596_val_loss_0.7880 epoch time 17.6192 seconds
# total time23.0 : 48.34577560424805
# loss: 0.0586, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:16<00:00, 61.36it/s]
# loss: 0.4874, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 131.74it/s]
# loss: 0.0403, accuracy: 1.0000:   1%|          | 12/1000 [00:00<00:14, 66.27it/s]
# Epoch 81: train_acc_0.9587_train_loss_0.0992_val_acc_0.8585_val_loss_0.8379 epoch time 17.6385 seconds
# total time24.0 : 5.984317302703857
# loss: 0.1022, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:16<00:00, 61.28it/s]
# loss: 1.1979, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 141.87it/s]
# loss: 0.1366, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 65.41it/s]
# Epoch 82: train_acc_0.9575_train_loss_0.1048_val_acc_0.8618_val_loss_0.7848 epoch time 17.6340 seconds
# total time24.0 : 23.618342876434326
# loss: 0.1758, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:16<00:00, 61.40it/s]
# loss: 1.0088, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 133.70it/s]
# loss: 0.0906, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 64.75it/s]
# Epoch 83: train_acc_0.9588_train_loss_0.1008_val_acc_0.8573_val_loss_0.8460 epoch time 17.6121 seconds
# total time24.0 : 41.23046016693115
# loss: 0.0406, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:16<00:00, 61.27it/s]
# loss: 0.9584, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 131.15it/s]
# loss: 0.0403, accuracy: 0.9900:   1%|          | 12/1000 [00:00<00:15, 65.55it/s]
# Epoch 84: train_acc_0.9587_train_loss_0.1022_val_acc_0.8591_val_loss_0.8639 epoch time 17.6678 seconds
# total time24.0 : 58.89829087257385
# loss: 0.1905, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.37it/s]
# loss: 0.5443, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 131.91it/s]
# loss: 0.1108, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 64.72it/s]
# Epoch 85: train_acc_0.9582_train_loss_0.1016_val_acc_0.8613_val_loss_0.8198 epoch time 17.6350 seconds
# total time25.0 : 16.53331732749939
# loss: 0.1894, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:16<00:00, 61.49it/s]
# loss: 0.6252, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 133.52it/s]
# loss: 0.1296, accuracy: 0.9400:   1%|          | 12/1000 [00:00<00:15, 65.47it/s]
# Epoch 86: train_acc_0.9590_train_loss_0.1000_val_acc_0.8578_val_loss_0.8201 epoch time 17.5878 seconds
# total time25.0 : 34.12109565734863
# loss: 0.0615, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:16<00:00, 62.26it/s]
# loss: 1.2841, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 136.73it/s]
# loss: 0.0939, accuracy: 0.9500:   1%|          | 12/1000 [00:00<00:15, 63.27it/s]
# Epoch 87: train_acc_0.9576_train_loss_0.1026_val_acc_0.8618_val_loss_0.7876 epoch time 17.6962 seconds
# total time25.0 : 51.817291021347046
# loss: 0.0670, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:15<00:00, 62.81it/s]
# loss: 0.8228, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 135.02it/s]
# loss: 0.0276, accuracy: 0.9900:   1%|▏         | 13/1000 [00:00<00:14, 67.93it/s]
# Epoch 88: train_acc_0.9604_train_loss_0.0966_val_acc_0.8625_val_loss_0.7829 epoch time 17.2325 seconds
# total time26.0 : 9.049781799316406
# loss: 0.1071, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:15<00:00, 62.67it/s]
# loss: 0.7962, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.29it/s]
# loss: 0.0568, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 65.63it/s]
# Epoch 89: train_acc_0.9597_train_loss_0.0972_val_acc_0.8618_val_loss_0.8396 epoch time 17.2923 seconds
# total time26.0 : 26.342103719711304
# loss: 0.1250, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:16<00:00, 61.25it/s]
# loss: 0.9863, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 131.67it/s]
# loss: 0.0765, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:14, 65.94it/s]
# Epoch 90: train_acc_0.9595_train_loss_0.1002_val_acc_0.8598_val_loss_0.8449 epoch time 17.6691 seconds
# total time26.0 : 44.011253118515015
# loss: 0.0727, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:16<00:00, 61.24it/s]
# loss: 0.9291, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 132.73it/s]
# loss: 0.0849, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 64.73it/s]
# Epoch 91: train_acc_0.9603_train_loss_0.0960_val_acc_0.8634_val_loss_0.8413 epoch time 17.6622 seconds
# total time27.0 : 1.6734142303466797
# loss: 0.1265, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:16<00:00, 61.31it/s]
# loss: 0.4774, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 132.65it/s]
# loss: 0.0540, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:15, 64.55it/s]
# Epoch 92: train_acc_0.9600_train_loss_0.0965_val_acc_0.8634_val_loss_0.8241 epoch time 17.6419 seconds
# total time27.0 : 19.315279483795166
# loss: 0.1944, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.17it/s]
# loss: 0.7141, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 131.80it/s]
# loss: 0.0717, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 63.81it/s]
# Epoch 93: train_acc_0.9606_train_loss_0.0939_val_acc_0.8628_val_loss_0.8874 epoch time 17.6881 seconds
# total time27.0 : 37.00337290763855
# loss: 0.1616, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:16<00:00, 61.53it/s]
# loss: 1.0826, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 133.08it/s]
# loss: 0.0721, accuracy: 0.9700:   1%|          | 12/1000 [00:00<00:15, 64.63it/s]
# Epoch 94: train_acc_0.9600_train_loss_0.0990_val_acc_0.8606_val_loss_0.8346 epoch time 17.5839 seconds
# total time27.0 : 54.58729314804077
# loss: 0.1173, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.24it/s]
# loss: 0.8758, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 131.75it/s]
# loss: 0.1949, accuracy: 0.9100:   1%|          | 12/1000 [00:00<00:15, 65.18it/s]
# Epoch 95: train_acc_0.9611_train_loss_0.0959_val_acc_0.8624_val_loss_0.8534 epoch time 17.6709 seconds
# total time28.0 : 12.258200883865356
# loss: 0.1756, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:16<00:00, 61.22it/s]
# loss: 0.9260, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 131.84it/s]
# loss: 0.0436, accuracy: 0.9800:   1%|          | 12/1000 [00:00<00:14, 66.50it/s]
# Epoch 96: train_acc_0.9606_train_loss_0.0957_val_acc_0.8601_val_loss_0.8294 epoch time 17.6801 seconds
# total time28.0 : 29.938261032104492
# loss: 0.1478, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# loss: 0.5199, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 130.52it/s]
# loss: 0.0872, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 65.20it/s]
# Epoch 97: train_acc_0.9602_train_loss_0.0978_val_acc_0.8584_val_loss_0.8664 epoch time 17.6643 seconds
# total time28.0 : 47.6025505065918
# loss: 0.0867, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# loss: 1.1629, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 131.07it/s]
# loss: 0.0813, accuracy: 0.9600:   1%|          | 12/1000 [00:00<00:15, 65.51it/s]
# Epoch 98: train_acc_0.9617_train_loss_0.0928_val_acc_0.8601_val_loss_0.8501 epoch time 17.6617 seconds
# total time29.0 : 5.264220476150513
# loss: 0.0877, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:16<00:00, 61.30it/s]
# loss: 0.9425, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 138.86it/s]
# loss: 0.2502, accuracy: 0.9200:  17%|█▋        | 27/158 [00:00<00:00, 144.15it/s]
# Epoch 99: train_acc_0.9598_train_loss_0.0986_val_acc_0.8570_val_loss_0.8824 epoch time 17.6399 seconds
# total time29.0 : 22.90415620803833
# Generating test set evaluation metrics
# loss: 0.9472, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 130.62it/s]
# finish

# %%
#stride2_filter32_layer1234_type1

batch_size = 100
image_num_channels = 1
image_height = 28
image_width = 28
dim_reduction_idx = 1
dim_reduction_type = ['strided_convolution', 'dilated_convolution', 'max_pooling', 'avg_pooling']
num_filters = 32
num_layers = [1,2,3,4]
experiment_name = []
for layer in num_layers:
    experiment_name.append("stride2_filter32_layer{}_type{}".format(layer,dim_reduction_idx))
num_epochs = 100
weight_decay_coefficient = 1e-05
seed = 9112018
use_gpu = True

rng = np.random.RandomState(seed=seed)
train_data = data_providers.EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
val_data = data_providers.EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = data_providers.EMNISTDataProvider('test', batch_size=batch_size, rng=rng)

for experiment,layer in zip(experiment_name,num_layers):
    
    print(experiment)
    
    custom_conv_net = ConvolutionalNetwork(
        input_shape=(batch_size, image_num_channels, image_height, image_width),
        dim_reduction_type=dim_reduction_type[dim_reduction_idx],
        num_output_classes=47, num_filters=num_filters, num_layers=layer, use_bias=True)

    conv_experiment = ExperimentBuilder(network_model=custom_conv_net,
                                    experiment_name=experiment,
                                    num_epochs=num_epochs,
                                    weight_decay_coefficient=weight_decay_coefficient,
                                    use_gpu=use_gpu,
                                    train_data=train_data, val_data=val_data, test_data=test_data)
    print(custom_conv_net)
    total_losses = conv_experiment.run_experiment()
    print('finish')
    plot_stats_in_graph(total_losses[0])
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb2b315f8>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb5b80e48>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f6cb2b315f8>)
# loss: 3.8566, accuracy: 0.0100:   0%|          | 5/1000 [00:00<00:14, 66.38it/s]
# stride2_filter32_layer1_type1
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 26, 26])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_dilated_conv_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 1.3311, accuracy: 0.6100: 100%|██████████| 1000/1000 [00:14<00:00, 70.55it/s]
# loss: 1.1984, accuracy: 0.6200: 100%|██████████| 158/158 [00:01<00:00, 123.64it/s]
# loss: 1.3287, accuracy: 0.6100:   1%|▏         | 14/1000 [00:00<00:12, 76.93it/s]
# Epoch 0: train_acc_0.4240_train_loss_2.0847_val_acc_0.6252_val_loss_1.2990 epoch time 15.5910 seconds
# total time0.0 : 15.590972900390625
# loss: 0.9667, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:13<00:00, 71.44it/s]
# loss: 1.2081, accuracy: 0.6400: 100%|██████████| 158/158 [00:01<00:00, 123.65it/s]
# loss: 1.0403, accuracy: 0.7200:   1%|▏         | 14/1000 [00:00<00:12, 77.12it/s]
# Epoch 1: train_acc_0.6636_train_loss_1.1350_val_acc_0.6952_val_loss_1.0132 epoch time 15.5124 seconds
# total time0.0 : 31.10337233543396
# loss: 0.8197, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:13<00:00, 72.12it/s]
# loss: 0.9468, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 127.77it/s]
# loss: 1.1425, accuracy: 0.6900:   2%|▏         | 15/1000 [00:00<00:12, 77.60it/s]
# Epoch 2: train_acc_0.7040_train_loss_0.9813_val_acc_0.7253_val_loss_0.9075 epoch time 15.5321 seconds
# total time0.0 : 46.63542628288269
# loss: 0.9109, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:13<00:00, 72.52it/s]
# loss: 0.7523, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 127.87it/s]
# loss: 0.8715, accuracy: 0.8100:   1%|▏         | 14/1000 [00:00<00:13, 75.28it/s]
# Epoch 3: train_acc_0.7327_train_loss_0.8814_val_acc_0.7532_val_loss_0.8152 epoch time 15.5672 seconds
# total time1.0 : 2.20259428024292
# loss: 0.7354, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:13<00:00, 73.68it/s]
# loss: 0.8529, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 123.60it/s]
# loss: 1.0090, accuracy: 0.7300:   1%|▏         | 14/1000 [00:00<00:13, 75.18it/s]
# Epoch 4: train_acc_0.7516_train_loss_0.8097_val_acc_0.7678_val_loss_0.7569 epoch time 15.5565 seconds
# total time1.0 : 17.759074449539185
# loss: 0.8491, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:13<00:00, 71.99it/s]
# loss: 0.7419, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 127.84it/s]
# loss: 0.7816, accuracy: 0.7900:   2%|▏         | 15/1000 [00:00<00:12, 77.07it/s]
# Epoch 5: train_acc_0.7660_train_loss_0.7560_val_acc_0.7740_val_loss_0.7192 epoch time 15.5350 seconds
# total time1.0 : 33.294097900390625
# loss: 0.8500, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:13<00:00, 73.18it/s]
# loss: 0.5895, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 125.81it/s]
# loss: 0.6454, accuracy: 0.7800:   1%|▏         | 14/1000 [00:00<00:13, 75.66it/s]
# Epoch 6: train_acc_0.7785_train_loss_0.7136_val_acc_0.7876_val_loss_0.6722 epoch time 15.2616 seconds
# total time1.0 : 48.555681467056274
# loss: 0.8466, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:13<00:00, 73.98it/s]
# loss: 0.8857, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 121.55it/s]
# loss: 0.8355, accuracy: 0.7200:   1%|▏         | 14/1000 [00:00<00:13, 73.71it/s]
# Epoch 7: train_acc_0.7871_train_loss_0.6825_val_acc_0.7975_val_loss_0.6555 epoch time 14.9578 seconds
# total time2.0 : 3.5134809017181396
# loss: 0.4536, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 72.32it/s]
# loss: 0.5111, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 126.71it/s]
# loss: 0.6701, accuracy: 0.7600:   1%|▏         | 14/1000 [00:00<00:13, 75.34it/s]
# Epoch 8: train_acc_0.7949_train_loss_0.6555_val_acc_0.7980_val_loss_0.6306 epoch time 15.5738 seconds
# total time2.0 : 19.08733081817627
# loss: 0.3890, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.69it/s]
# loss: 0.5250, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 120.93it/s]
# loss: 0.5420, accuracy: 0.8200:   1%|▏         | 14/1000 [00:00<00:13, 75.49it/s]
# Epoch 9: train_acc_0.8000_train_loss_0.6343_val_acc_0.8003_val_loss_0.6201 epoch time 15.5470 seconds
# total time2.0 : 34.63436675071716
# loss: 0.5105, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:13<00:00, 71.93it/s]
# loss: 0.7690, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 124.01it/s]
# loss: 0.6163, accuracy: 0.8000:   1%|▏         | 14/1000 [00:00<00:13, 75.62it/s]
# Epoch 10: train_acc_0.8053_train_loss_0.6130_val_acc_0.8138_val_loss_0.5809 epoch time 15.5762 seconds
# total time2.0 : 50.210562229156494
# loss: 0.4845, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 71.99it/s]
# loss: 0.5581, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 123.40it/s]
# loss: 0.5143, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:13, 74.92it/s]
# Epoch 11: train_acc_0.8108_train_loss_0.5970_val_acc_0.8190_val_loss_0.5710 epoch time 15.5396 seconds
# total time3.0 : 5.750114679336548
# loss: 0.5020, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:13<00:00, 72.35it/s]
# loss: 0.3488, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 123.28it/s]
# loss: 0.5386, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:12, 75.91it/s]
# Epoch 12: train_acc_0.8153_train_loss_0.5817_val_acc_0.8161_val_loss_0.5734 epoch time 15.5782 seconds
# total time3.0 : 21.32830309867859
# loss: 0.4622, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.54it/s]
# loss: 0.4463, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 123.25it/s]
# loss: 0.6859, accuracy: 0.7300:   1%|▏         | 14/1000 [00:00<00:13, 75.44it/s]
# Epoch 13: train_acc_0.8186_train_loss_0.5672_val_acc_0.8258_val_loss_0.5451 epoch time 15.5398 seconds
# total time3.0 : 36.868053913116455
# loss: 0.4290, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 71.71it/s]
# loss: 0.6906, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 124.65it/s]
# loss: 0.4649, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:13, 74.38it/s]
# Epoch 14: train_acc_0.8224_train_loss_0.5545_val_acc_0.8285_val_loss_0.5295 epoch time 15.5157 seconds
# total time3.0 : 52.383734464645386
# loss: 0.5008, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.68it/s]
# loss: 0.5464, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 121.97it/s]
# loss: 0.6575, accuracy: 0.8000:   1%|▏         | 14/1000 [00:00<00:12, 77.32it/s]
# Epoch 15: train_acc_0.8265_train_loss_0.5430_val_acc_0.8244_val_loss_0.5336 epoch time 15.6238 seconds
# total time4.0 : 8.007565259933472
# loss: 0.6456, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:13<00:00, 72.48it/s]
# loss: 0.5775, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 121.45it/s]
# loss: 0.6541, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:13, 74.42it/s]
# Epoch 16: train_acc_0.8276_train_loss_0.5334_val_acc_0.8312_val_loss_0.5145 epoch time 15.5660 seconds
# total time4.0 : 23.573530912399292
# loss: 0.4578, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:13<00:00, 72.44it/s]
# loss: 0.6905, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 122.65it/s]
# loss: 0.4420, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:13, 74.49it/s]
# Epoch 17: train_acc_0.8308_train_loss_0.5226_val_acc_0.8335_val_loss_0.5069 epoch time 15.5581 seconds
# total time4.0 : 39.13158917427063
# loss: 0.3677, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 72.53it/s]
# loss: 0.5391, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 119.87it/s]
# loss: 0.4267, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 74.94it/s]
# Epoch 18: train_acc_0.8326_train_loss_0.5118_val_acc_0.8368_val_loss_0.4940 epoch time 15.6168 seconds
# total time4.0 : 54.74842190742493
# loss: 0.4285, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.35it/s]
# loss: 0.4804, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 126.53it/s]
# loss: 0.5841, accuracy: 0.7800:   1%|▏         | 14/1000 [00:00<00:13, 74.64it/s]
# Epoch 19: train_acc_0.8354_train_loss_0.5043_val_acc_0.8336_val_loss_0.4933 epoch time 15.5567 seconds
# total time5.0 : 10.3051438331604
# loss: 0.5114, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.48it/s]
# loss: 0.5040, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 125.01it/s]
# loss: 0.5104, accuracy: 0.8000:   1%|▏         | 14/1000 [00:00<00:13, 74.96it/s]
# Epoch 20: train_acc_0.8372_train_loss_0.4973_val_acc_0.8357_val_loss_0.4825 epoch time 15.5431 seconds
# total time5.0 : 25.84826111793518
# loss: 0.3061, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 73.01it/s]
# loss: 0.4603, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 124.63it/s]
# loss: 0.4594, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:13, 73.99it/s]
# Epoch 21: train_acc_0.8387_train_loss_0.4899_val_acc_0.8418_val_loss_0.4801 epoch time 15.5467 seconds
# total time5.0 : 41.3949990272522
# loss: 0.5163, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:13<00:00, 72.12it/s]
# loss: 0.3872, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 122.93it/s]
# loss: 0.5770, accuracy: 0.8200:   1%|▏         | 14/1000 [00:00<00:13, 74.28it/s]
# Epoch 22: train_acc_0.8404_train_loss_0.4836_val_acc_0.8459_val_loss_0.4648 epoch time 15.5573 seconds
# total time5.0 : 56.95225477218628
# loss: 0.4926, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.79it/s]
# loss: 0.5512, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 125.17it/s]
# loss: 0.5029, accuracy: 0.8100:   1%|▏         | 14/1000 [00:00<00:13, 75.18it/s]
# Epoch 23: train_acc_0.8419_train_loss_0.4788_val_acc_0.8448_val_loss_0.4590 epoch time 15.5345 seconds
# total time6.0 : 12.486746072769165
# loss: 0.8187, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 74.66it/s]
# loss: 0.3869, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 125.81it/s]
# loss: 0.3442, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 74.71it/s]
# Epoch 24: train_acc_0.8436_train_loss_0.4725_val_acc_0.8430_val_loss_0.4659 epoch time 15.4375 seconds
# total time6.0 : 27.924219846725464
# loss: 0.3469, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.48it/s]
# loss: 0.5538, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 124.03it/s]
# loss: 0.4987, accuracy: 0.8300:   2%|▏         | 15/1000 [00:00<00:12, 77.29it/s]
# Epoch 25: train_acc_0.8448_train_loss_0.4674_val_acc_0.8452_val_loss_0.4575 epoch time 15.4049 seconds
# total time6.0 : 43.32911252975464
# loss: 0.4979, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:13<00:00, 71.58it/s]
# loss: 0.5125, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 123.36it/s]
# loss: 0.4882, accuracy: 0.7800:   1%|▏         | 14/1000 [00:00<00:13, 74.23it/s]
# Epoch 26: train_acc_0.8457_train_loss_0.4629_val_acc_0.8431_val_loss_0.4552 epoch time 15.6297 seconds
# total time6.0 : 58.95876336097717
# loss: 0.4512, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 73.38it/s]
# loss: 0.5553, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 126.70it/s]
# loss: 0.3456, accuracy: 0.8500:   1%|▏         | 14/1000 [00:00<00:13, 74.81it/s]
# Epoch 27: train_acc_0.8474_train_loss_0.4585_val_acc_0.8403_val_loss_0.4665 epoch time 15.0653 seconds
# total time7.0 : 14.024035692214966
# loss: 0.4181, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 72.25it/s]
# loss: 0.3691, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 124.22it/s]
# loss: 0.6811, accuracy: 0.8500:   1%|▏         | 14/1000 [00:00<00:13, 73.58it/s]
# Epoch 28: train_acc_0.8480_train_loss_0.4542_val_acc_0.8429_val_loss_0.4676 epoch time 15.6392 seconds
# total time7.0 : 29.663195371627808
# loss: 0.5055, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:14<00:00, 70.23it/s]
# loss: 0.3371, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 123.38it/s]
# loss: 0.4946, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 77.83it/s]
# Epoch 29: train_acc_0.8501_train_loss_0.4499_val_acc_0.8535_val_loss_0.4440 epoch time 15.6619 seconds
# total time7.0 : 45.325058698654175
# loss: 0.3599, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 72.14it/s]
# loss: 0.3153, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 122.76it/s]
# loss: 0.4507, accuracy: 0.8200:   1%|▏         | 14/1000 [00:00<00:13, 72.60it/s]
# Epoch 30: train_acc_0.8510_train_loss_0.4454_val_acc_0.8496_val_loss_0.4495 epoch time 15.6599 seconds
# total time8.0 : 0.9849812984466553
# loss: 0.3587, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:14<00:00, 70.44it/s]
# loss: 0.3157, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 122.19it/s]
# loss: 0.2832, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:13, 74.04it/s]
# Epoch 31: train_acc_0.8515_train_loss_0.4420_val_acc_0.8527_val_loss_0.4355 epoch time 15.6313 seconds
# total time8.0 : 16.61629891395569
# loss: 0.6648, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:14<00:00, 70.54it/s]
# loss: 0.5857, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 121.70it/s]
# loss: 0.5928, accuracy: 0.7700:   1%|▏         | 14/1000 [00:00<00:12, 77.64it/s]
# Epoch 32: train_acc_0.8521_train_loss_0.4389_val_acc_0.8523_val_loss_0.4394 epoch time 15.6170 seconds
# total time8.0 : 32.233293771743774
# loss: 0.4091, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.68it/s]
# loss: 0.3943, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 125.36it/s]
# loss: 0.3195, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 78.75it/s]
# Epoch 33: train_acc_0.8540_train_loss_0.4355_val_acc_0.8528_val_loss_0.4318 epoch time 15.6589 seconds
# total time8.0 : 47.8921959400177
# loss: 0.4849, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:13<00:00, 71.44it/s]
# loss: 0.3422, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 123.68it/s]
# loss: 0.4943, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:13, 74.10it/s]
# Epoch 34: train_acc_0.8544_train_loss_0.4333_val_acc_0.8528_val_loss_0.4308 epoch time 15.6341 seconds
# total time9.0 : 3.526329278945923
# loss: 0.7066, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:13<00:00, 71.30it/s]
# loss: 0.5012, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 123.05it/s]
# loss: 0.2736, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 77.94it/s]
# Epoch 35: train_acc_0.8554_train_loss_0.4294_val_acc_0.8577_val_loss_0.4165 epoch time 15.6498 seconds
# total time9.0 : 19.176158905029297
# loss: 0.5089, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 71.22it/s]
# loss: 0.3934, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 122.94it/s]
# loss: 0.5824, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 75.94it/s]
# Epoch 36: train_acc_0.8557_train_loss_0.4274_val_acc_0.8541_val_loss_0.4322 epoch time 15.6625 seconds
# total time9.0 : 34.838613748550415
# loss: 0.3995, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:14<00:00, 70.31it/s]
# loss: 0.3357, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 121.16it/s]
# loss: 0.4205, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 78.53it/s]
# Epoch 37: train_acc_0.8568_train_loss_0.4254_val_acc_0.8583_val_loss_0.4205 epoch time 15.6726 seconds
# total time9.0 : 50.51121950149536
# loss: 0.3975, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 71.31it/s]
# loss: 0.3141, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 119.91it/s]
# loss: 0.5547, accuracy: 0.8100:   1%|▏         | 14/1000 [00:00<00:13, 74.31it/s]
# Epoch 38: train_acc_0.8574_train_loss_0.4220_val_acc_0.8601_val_loss_0.4120 epoch time 15.7053 seconds
# total time10.0 : 6.2165367603302
# loss: 0.2853, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:14<00:00, 70.38it/s]
# loss: 0.3441, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 120.97it/s]
# loss: 0.4073, accuracy: 0.8400:   1%|▏         | 14/1000 [00:00<00:12, 76.64it/s]
# Epoch 39: train_acc_0.8586_train_loss_0.4204_val_acc_0.8576_val_loss_0.4165 epoch time 15.6563 seconds
# total time10.0 : 21.872862100601196
# loss: 0.2672, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 71.71it/s]
# loss: 0.4394, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 121.20it/s]
# loss: 0.3117, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 73.31it/s]
# Epoch 40: train_acc_0.8588_train_loss_0.4175_val_acc_0.8578_val_loss_0.4230 epoch time 15.6350 seconds
# total time10.0 : 37.50790238380432
# loss: 0.4388, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:14<00:00, 70.25it/s]
# loss: 0.3599, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 126.26it/s]
# loss: 0.3913, accuracy: 0.8500:   1%|▏         | 14/1000 [00:00<00:12, 76.81it/s]
# Epoch 41: train_acc_0.8599_train_loss_0.4136_val_acc_0.8591_val_loss_0.4163 epoch time 15.6288 seconds
# total time10.0 : 53.13665843009949
# loss: 0.1795, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 71.99it/s]
# loss: 0.4472, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 123.36it/s]
# loss: 0.3101, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:13, 74.76it/s]
# Epoch 42: train_acc_0.8598_train_loss_0.4134_val_acc_0.8611_val_loss_0.4121 epoch time 15.5590 seconds
# total time11.0 : 8.695659875869751
# loss: 0.2582, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 71.67it/s]
# loss: 0.4930, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 126.85it/s]
# loss: 0.5816, accuracy: 0.8000:   1%|▏         | 14/1000 [00:00<00:13, 75.59it/s]
# Epoch 43: train_acc_0.8604_train_loss_0.4112_val_acc_0.8641_val_loss_0.4122 epoch time 15.5508 seconds
# total time11.0 : 24.246435165405273
# loss: 0.3042, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 71.69it/s]
# loss: 0.2821, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 122.64it/s]
# loss: 0.3780, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:13, 74.54it/s]
# Epoch 44: train_acc_0.8615_train_loss_0.4093_val_acc_0.8615_val_loss_0.4088 epoch time 15.5843 seconds
# total time11.0 : 39.83073449134827
# loss: 0.2968, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 72.39it/s]
# loss: 0.3366, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 123.18it/s]
# loss: 0.3707, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 76.60it/s]
# Epoch 45: train_acc_0.8619_train_loss_0.4067_val_acc_0.8604_val_loss_0.4127 epoch time 15.2386 seconds
# total time11.0 : 55.06933116912842
# loss: 0.5009, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 71.65it/s]
# loss: 0.3581, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 122.87it/s]
# loss: 0.3988, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 75.23it/s]
# Epoch 46: train_acc_0.8624_train_loss_0.4068_val_acc_0.8610_val_loss_0.4053 epoch time 15.5738 seconds
# total time12.0 : 10.643170833587646
# loss: 0.4257, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 73.64it/s]
# loss: 0.4136, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 122.36it/s]
# loss: 0.3224, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 76.17it/s]
# Epoch 47: train_acc_0.8622_train_loss_0.4045_val_acc_0.8651_val_loss_0.4043 epoch time 15.0697 seconds
# total time12.0 : 25.71286106109619
# loss: 0.2482, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.04it/s]
# loss: 0.4617, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 125.75it/s]
# loss: 0.2390, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 76.34it/s]
# Epoch 48: train_acc_0.8636_train_loss_0.4025_val_acc_0.8637_val_loss_0.4044 epoch time 15.5006 seconds
# total time12.0 : 41.21344232559204
# loss: 0.3847, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 73.61it/s]
# loss: 0.4361, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 123.21it/s]
# loss: 0.3547, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:13, 73.96it/s]
# Epoch 49: train_acc_0.8633_train_loss_0.4009_val_acc_0.8586_val_loss_0.4143 epoch time 15.4950 seconds
# total time12.0 : 56.708486795425415
# loss: 0.4095, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 71.65it/s]
# loss: 0.3753, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 123.79it/s]
# loss: 0.3033, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:13, 74.44it/s]
# Epoch 50: train_acc_0.8639_train_loss_0.3997_val_acc_0.8653_val_loss_0.3993 epoch time 15.6255 seconds
# total time13.0 : 12.334032773971558
# loss: 0.2725, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 71.88it/s]
# loss: 0.4921, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 121.67it/s]
# loss: 0.3852, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:13, 75.68it/s]
# Epoch 51: train_acc_0.8644_train_loss_0.3986_val_acc_0.8610_val_loss_0.4048 epoch time 15.6134 seconds
# total time13.0 : 27.947386503219604
# loss: 0.3288, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 71.95it/s]
# loss: 0.3011, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 120.75it/s]
# loss: 0.3955, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:12, 77.24it/s]
# Epoch 52: train_acc_0.8649_train_loss_0.3965_val_acc_0.8604_val_loss_0.4074 epoch time 15.5395 seconds
# total time13.0 : 43.48688793182373
# loss: 0.3185, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:14<00:00, 70.46it/s]
# loss: 0.4128, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 127.56it/s]
# loss: 0.2906, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 75.72it/s]
# Epoch 53: train_acc_0.8652_train_loss_0.3950_val_acc_0.8577_val_loss_0.4087 epoch time 15.6177 seconds
# total time13.0 : 59.104562520980835
# loss: 0.4419, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 71.65it/s]
# loss: 0.2988, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 126.82it/s]
# loss: 0.2350, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 77.62it/s]
# Epoch 54: train_acc_0.8648_train_loss_0.3936_val_acc_0.8661_val_loss_0.3898 epoch time 15.5503 seconds
# total time14.0 : 14.654826164245605
# loss: 0.4325, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 71.83it/s]
# loss: 0.2796, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 124.44it/s]
# loss: 0.4497, accuracy: 0.8400:   1%|▏         | 14/1000 [00:00<00:13, 75.65it/s]
# Epoch 55: train_acc_0.8657_train_loss_0.3931_val_acc_0.8637_val_loss_0.3965 epoch time 15.5114 seconds
# total time14.0 : 30.166240692138672
# loss: 0.3723, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 72.59it/s]
# loss: 0.3107, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 125.48it/s]
# loss: 0.3008, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:13, 75.55it/s]
# Epoch 56: train_acc_0.8662_train_loss_0.3912_val_acc_0.8661_val_loss_0.3927 epoch time 15.6045 seconds
# total time14.0 : 45.77077627182007
# loss: 0.6062, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:13<00:00, 71.41it/s]
# loss: 0.3133, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 121.62it/s]
# loss: 0.4004, accuracy: 0.8400:   1%|▏         | 14/1000 [00:00<00:13, 74.18it/s]
# Epoch 57: train_acc_0.8661_train_loss_0.3900_val_acc_0.8649_val_loss_0.3946 epoch time 15.5921 seconds
# total time15.0 : 1.3629255294799805
# loss: 0.3754, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.34it/s]
# loss: 0.3183, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 122.88it/s]
# loss: 0.3384, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:12, 76.40it/s]
# Epoch 58: train_acc_0.8662_train_loss_0.3900_val_acc_0.8642_val_loss_0.3939 epoch time 15.6042 seconds
# total time15.0 : 16.967076301574707
# loss: 0.4188, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.68it/s]
# loss: 0.3239, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 126.47it/s]
# loss: 0.2352, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 73.82it/s]
# Epoch 59: train_acc_0.8666_train_loss_0.3886_val_acc_0.8658_val_loss_0.3913 epoch time 15.6009 seconds
# total time15.0 : 32.56795954704285
# loss: 0.7636, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:13<00:00, 73.52it/s]
# loss: 0.3310, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 125.60it/s]
# loss: 0.3002, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 74.84it/s]
# Epoch 60: train_acc_0.8675_train_loss_0.3870_val_acc_0.8676_val_loss_0.3921 epoch time 15.6251 seconds
# total time15.0 : 48.19303226470947
# loss: 0.3414, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 71.69it/s]
# loss: 0.6272, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 122.84it/s]
# loss: 0.3471, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:13, 74.19it/s]
# Epoch 61: train_acc_0.8680_train_loss_0.3864_val_acc_0.8648_val_loss_0.3957 epoch time 15.5383 seconds
# total time16.0 : 3.7312870025634766
# loss: 0.6076, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:13<00:00, 71.63it/s]
# loss: 0.2259, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 126.57it/s]
# loss: 0.2084, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:13, 74.78it/s]
# Epoch 62: train_acc_0.8681_train_loss_0.3849_val_acc_0.8639_val_loss_0.3973 epoch time 15.6001 seconds
# total time16.0 : 19.331361293792725
# loss: 0.8409, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:13<00:00, 71.79it/s]
# loss: 0.3484, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 122.25it/s]
# loss: 0.2358, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 74.20it/s]
# Epoch 63: train_acc_0.8687_train_loss_0.3834_val_acc_0.8655_val_loss_0.3887 epoch time 15.5609 seconds
# total time16.0 : 34.89229083061218
# loss: 0.3477, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 72.78it/s]
# loss: 0.3909, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 125.15it/s]
# loss: 0.4463, accuracy: 0.8500:   2%|▏         | 15/1000 [00:00<00:12, 77.55it/s]
# Epoch 64: train_acc_0.8679_train_loss_0.3839_val_acc_0.8653_val_loss_0.3898 epoch time 15.5908 seconds
# total time16.0 : 50.483067750930786
# loss: 0.4242, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.92it/s]
# loss: 0.3055, accuracy: 0.9400: 100%|██████████| 158/158 [00:01<00:00, 121.67it/s]
# loss: 0.5194, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:13, 75.17it/s]
# Epoch 65: train_acc_0.8688_train_loss_0.3827_val_acc_0.8656_val_loss_0.3902 epoch time 15.3450 seconds
# total time17.0 : 5.828018426895142
# loss: 0.4686, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.45it/s]
# loss: 0.3301, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 126.17it/s]
# loss: 0.2423, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:12, 78.58it/s]
# Epoch 66: train_acc_0.8691_train_loss_0.3809_val_acc_0.8666_val_loss_0.3853 epoch time 15.6018 seconds
# total time17.0 : 21.42978310585022
# loss: 0.3229, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 73.44it/s]
# loss: 0.5002, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 122.87it/s]
# loss: 0.5162, accuracy: 0.8400:   1%|▏         | 14/1000 [00:00<00:12, 76.15it/s]
# Epoch 67: train_acc_0.8695_train_loss_0.3806_val_acc_0.8591_val_loss_0.3973 epoch time 15.0426 seconds
# total time17.0 : 36.47238731384277
# loss: 0.3628, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 73.24it/s]
# loss: 0.3930, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 127.93it/s]
# loss: 0.3745, accuracy: 0.8600:   1%|▏         | 14/1000 [00:00<00:13, 74.98it/s]
# Epoch 68: train_acc_0.8697_train_loss_0.3801_val_acc_0.8678_val_loss_0.3828 epoch time 15.5999 seconds
# total time17.0 : 52.07225298881531
# loss: 0.4693, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 72.10it/s]
# loss: 0.3374, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 122.73it/s]
# loss: 0.2772, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 73.22it/s]
# Epoch 69: train_acc_0.8699_train_loss_0.3789_val_acc_0.8656_val_loss_0.3895 epoch time 15.5806 seconds
# total time18.0 : 7.652817010879517
# loss: 0.6025, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 72.48it/s]
# loss: 0.3744, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 126.96it/s]
# loss: 0.3983, accuracy: 0.8500:   1%|▏         | 14/1000 [00:00<00:12, 78.06it/s]
# Epoch 70: train_acc_0.8698_train_loss_0.3779_val_acc_0.8692_val_loss_0.3793 epoch time 15.5454 seconds
# total time18.0 : 23.198266744613647
# loss: 0.4054, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 72.38it/s]
# loss: 0.5065, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 127.27it/s]
# loss: 0.3999, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 75.93it/s]
# Epoch 71: train_acc_0.8706_train_loss_0.3775_val_acc_0.8700_val_loss_0.3831 epoch time 15.5013 seconds
# total time18.0 : 38.69960403442383
# loss: 0.4040, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.35it/s]
# loss: 0.4631, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 126.94it/s]
# loss: 0.4074, accuracy: 0.8800:   2%|▏         | 15/1000 [00:00<00:13, 74.69it/s]
# Epoch 72: train_acc_0.8712_train_loss_0.3756_val_acc_0.8666_val_loss_0.3875 epoch time 15.5212 seconds
# total time18.0 : 54.220794916152954
# loss: 0.4410, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:14<00:00, 71.03it/s]
# loss: 0.5362, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 122.66it/s]
# loss: 0.4775, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:12, 76.29it/s]
# Epoch 73: train_acc_0.8715_train_loss_0.3745_val_acc_0.8661_val_loss_0.3843 epoch time 15.5078 seconds
# total time19.0 : 9.728636980056763
# loss: 0.4129, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:14<00:00, 70.81it/s]
# loss: 0.3038, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 127.13it/s]
# loss: 0.3898, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:13, 75.48it/s]
# Epoch 74: train_acc_0.8706_train_loss_0.3750_val_acc_0.8720_val_loss_0.3793 epoch time 15.5555 seconds
# total time19.0 : 25.28414797782898
# loss: 0.3652, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 71.92it/s]
# loss: 0.4041, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 121.99it/s]
# loss: 0.4506, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:12, 76.66it/s]
# Epoch 75: train_acc_0.8712_train_loss_0.3735_val_acc_0.8702_val_loss_0.3848 epoch time 15.5819 seconds
# total time19.0 : 40.86605715751648
# loss: 0.4912, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:13<00:00, 74.61it/s]
# loss: 0.3296, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 123.90it/s]
# loss: 0.3016, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:12, 76.61it/s]
# Epoch 76: train_acc_0.8721_train_loss_0.3722_val_acc_0.8705_val_loss_0.3764 epoch time 15.4967 seconds
# total time19.0 : 56.36272644996643
# loss: 0.3851, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:14<00:00, 70.76it/s]
# loss: 0.3140, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 123.00it/s]
# loss: 0.3008, accuracy: 0.8700:   1%|▏         | 14/1000 [00:00<00:13, 75.76it/s]
# Epoch 77: train_acc_0.8716_train_loss_0.3732_val_acc_0.8707_val_loss_0.3791 epoch time 15.5569 seconds
# total time20.0 : 11.919593095779419
# loss: 0.2809, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 74.45it/s]
# loss: 0.4012, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 124.88it/s]
# loss: 0.2532, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 76.63it/s]
# Epoch 78: train_acc_0.8723_train_loss_0.3711_val_acc_0.8665_val_loss_0.3854 epoch time 15.5999 seconds
# total time20.0 : 27.519532680511475
# loss: 0.3665, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 71.96it/s]
# loss: 0.2784, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 122.01it/s]
# loss: 0.4117, accuracy: 0.8300:   1%|▏         | 14/1000 [00:00<00:13, 74.10it/s]
# Epoch 79: train_acc_0.8715_train_loss_0.3714_val_acc_0.8708_val_loss_0.3763 epoch time 15.5442 seconds
# total time20.0 : 43.0636944770813
# loss: 0.4302, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:13<00:00, 71.96it/s]
# loss: 0.4635, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 126.58it/s]
# loss: 0.3423, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:12, 77.75it/s]
# Epoch 80: train_acc_0.8720_train_loss_0.3702_val_acc_0.8684_val_loss_0.3822 epoch time 15.5694 seconds
# total time20.0 : 58.633058309555054
# loss: 0.3046, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 71.80it/s]
# loss: 0.2622, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 122.81it/s]
# loss: 0.3097, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 73.10it/s]
# Epoch 81: train_acc_0.8726_train_loss_0.3689_val_acc_0.8692_val_loss_0.3736 epoch time 15.5803 seconds
# total time21.0 : 14.213336706161499
# loss: 0.4721, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.24it/s]
# loss: 0.2784, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 122.07it/s]
# loss: 0.4274, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 76.26it/s]
# Epoch 82: train_acc_0.8725_train_loss_0.3696_val_acc_0.8697_val_loss_0.3731 epoch time 15.6418 seconds
# total time21.0 : 29.8550968170166
# loss: 0.5755, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 72.02it/s]
# loss: 0.2156, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 120.46it/s]
# loss: 0.4824, accuracy: 0.8700:   2%|▏         | 15/1000 [00:00<00:12, 78.69it/s]
# Epoch 83: train_acc_0.8728_train_loss_0.3678_val_acc_0.8691_val_loss_0.3801 epoch time 15.6438 seconds
# total time21.0 : 45.49894070625305
# loss: 0.5964, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 71.85it/s]
# loss: 0.4012, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 123.77it/s]
# loss: 0.3754, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:13, 75.20it/s]
# Epoch 84: train_acc_0.8733_train_loss_0.3669_val_acc_0.8730_val_loss_0.3745 epoch time 15.3370 seconds
# total time22.0 : 0.835974931716919
# loss: 0.4530, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:14<00:00, 70.42it/s]
# loss: 0.3135, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 124.96it/s]
# loss: 0.2680, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:13, 73.45it/s]
# Epoch 85: train_acc_0.8731_train_loss_0.3664_val_acc_0.8673_val_loss_0.3784 epoch time 15.6424 seconds
# total time22.0 : 16.478334665298462
# loss: 0.4032, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:14<00:00, 70.68it/s]
# loss: 0.2570, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 125.41it/s]
# loss: 0.4098, accuracy: 0.8400:   2%|▏         | 15/1000 [00:00<00:12, 76.50it/s]
# Epoch 86: train_acc_0.8739_train_loss_0.3663_val_acc_0.8704_val_loss_0.3739 epoch time 15.5457 seconds
# total time22.0 : 32.02403235435486
# loss: 0.3813, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 73.53it/s]
# loss: 0.2181, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 121.60it/s]
# loss: 0.5129, accuracy: 0.8400:   1%|▏         | 14/1000 [00:00<00:12, 77.35it/s]
# Epoch 87: train_acc_0.8744_train_loss_0.3646_val_acc_0.8674_val_loss_0.3877 epoch time 15.0406 seconds
# total time22.0 : 47.06464433670044
# loss: 0.3217, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 71.95it/s]
# loss: 0.2860, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 123.89it/s]
# loss: 0.4744, accuracy: 0.8500:   1%|▏         | 14/1000 [00:00<00:13, 75.73it/s]
# Epoch 88: train_acc_0.8736_train_loss_0.3645_val_acc_0.8691_val_loss_0.3728 epoch time 15.5624 seconds
# total time23.0 : 2.62701153755188
# loss: 0.5479, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:13<00:00, 71.66it/s]
# loss: 0.4307, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 120.44it/s]
# loss: 0.3034, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:12, 78.85it/s]
# Epoch 89: train_acc_0.8731_train_loss_0.3647_val_acc_0.8695_val_loss_0.3780 epoch time 15.6402 seconds
# total time23.0 : 18.26721167564392
# loss: 0.2463, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 72.03it/s]
# loss: 0.2959, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 126.36it/s]
# loss: 0.3134, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 76.18it/s]
# Epoch 90: train_acc_0.8749_train_loss_0.3637_val_acc_0.8725_val_loss_0.3717 epoch time 15.6090 seconds
# total time23.0 : 33.87623047828674
# loss: 0.3914, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:14<00:00, 70.66it/s]
# loss: 0.3439, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 120.95it/s]
# loss: 0.3170, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 78.32it/s]
# Epoch 91: train_acc_0.8753_train_loss_0.3629_val_acc_0.8724_val_loss_0.3717 epoch time 15.6022 seconds
# total time23.0 : 49.478474140167236
# loss: 0.4575, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:13<00:00, 71.49it/s]
# loss: 0.3269, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 128.62it/s]
# loss: 0.3210, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 74.72it/s]
# Epoch 92: train_acc_0.8743_train_loss_0.3623_val_acc_0.8699_val_loss_0.3705 epoch time 15.6311 seconds
# total time24.0 : 5.109608888626099
# loss: 0.3484, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:13<00:00, 71.83it/s]
# loss: 0.3808, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 123.81it/s]
# loss: 0.4295, accuracy: 0.8000:   1%|▏         | 14/1000 [00:00<00:12, 76.51it/s]
# Epoch 93: train_acc_0.8744_train_loss_0.3623_val_acc_0.8730_val_loss_0.3705 epoch time 15.5584 seconds
# total time24.0 : 20.667975425720215
# loss: 0.3372, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 71.89it/s]
# loss: 0.4894, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 120.67it/s]
# loss: 0.3499, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:12, 76.09it/s]
# Epoch 94: train_acc_0.8757_train_loss_0.3616_val_acc_0.8730_val_loss_0.3657 epoch time 15.5458 seconds
# total time24.0 : 36.213757038116455
# loss: 0.2760, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 72.40it/s]
# loss: 0.4904, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 120.39it/s]
# loss: 0.2853, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 75.11it/s]
# Epoch 95: train_acc_0.8755_train_loss_0.3610_val_acc_0.8706_val_loss_0.3687 epoch time 15.6142 seconds
# total time24.0 : 51.82798767089844
# loss: 0.3134, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 71.98it/s]
# loss: 0.3118, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 120.07it/s]
# loss: 0.2946, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 77.68it/s]
# Epoch 96: train_acc_0.8758_train_loss_0.3596_val_acc_0.8741_val_loss_0.3706 epoch time 15.6556 seconds
# total time25.0 : 7.48363733291626
# loss: 0.3971, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:13<00:00, 71.88it/s]
# loss: 0.3726, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 121.38it/s]
# loss: 0.3216, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 74.26it/s]
# Epoch 97: train_acc_0.8751_train_loss_0.3607_val_acc_0.8726_val_loss_0.3714 epoch time 15.5962 seconds
# total time25.0 : 23.079796075820923
# loss: 0.2480, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:14<00:00, 70.61it/s]
# loss: 0.5876, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 120.88it/s]
# loss: 0.4063, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:13, 74.42it/s]
# Epoch 98: train_acc_0.8758_train_loss_0.3591_val_acc_0.8678_val_loss_0.3719 epoch time 15.6126 seconds
# total time25.0 : 38.692426443099976
# loss: 0.2799, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 71.43it/s]
# loss: 0.3357, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 119.80it/s]
# loss: 0.4951, accuracy: 0.8500:  16%|█▌        | 25/158 [00:00<00:00, 138.40it/s]
# Epoch 99: train_acc_0.8750_train_loss_0.3586_val_acc_0.8712_val_loss_0.3718 epoch time 15.6611 seconds
# total time25.0 : 54.35351848602295
# Generating test set evaluation metrics
# loss: 0.4332, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 118.88it/s]
# finish
# stride2_filter32_layer2_type1
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 26, 26])
# loss: 3.8562, accuracy: 0.0200:   0%|          | 4/1000 [00:00<00:23, 42.38it/s]
# torch.Size([100, 32, 26, 26])
# torch.Size([100, 32, 22, 22])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_dilated_conv_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(2, 2))
#     (conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_dilated_conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), dilation=(3, 3))
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 0.8653, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:22<00:00, 45.30it/s]
# loss: 0.7645, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 98.08it/s]
# loss: 0.5175, accuracy: 0.8300:   1%|          | 8/1000 [00:00<00:21, 46.04it/s]
# Epoch 0: train_acc_0.6463_train_loss_1.2072_val_acc_0.7841_val_loss_0.6635 epoch time 24.1072 seconds
# total time0.0 : 24.107195615768433
# loss: 0.7232, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:22<00:00, 45.16it/s]
# loss: 0.3848, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 99.60it/s]
# loss: 0.8009, accuracy: 0.7600:   1%|          | 8/1000 [00:00<00:21, 45.81it/s]
# Epoch 1: train_acc_0.8041_train_loss_0.6065_val_acc_0.8290_val_loss_0.5258 epoch time 24.1926 seconds
# total time0.0 : 48.29981970787048
# loss: 0.3180, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:22<00:00, 45.44it/s]
# loss: 0.5155, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 99.97it/s]
# loss: 0.3957, accuracy: 0.8900:   1%|          | 8/1000 [00:00<00:21, 46.63it/s]
# Epoch 2: train_acc_0.8338_train_loss_0.5021_val_acc_0.8437_val_loss_0.4631 epoch time 24.0672 seconds
# total time1.0 : 12.367000102996826
# loss: 0.6773, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:22<00:00, 45.04it/s]
# loss: 0.3190, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 96.50it/s]
# loss: 0.2445, accuracy: 0.9000:   1%|          | 8/1000 [00:00<00:21, 46.11it/s]
# Epoch 3: train_acc_0.8487_train_loss_0.4511_val_acc_0.8554_val_loss_0.4319 epoch time 24.1811 seconds
# total time1.0 : 36.54812836647034
# loss: 0.4527, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:22<00:00, 45.31it/s]
# loss: 0.3416, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 97.74it/s]
# loss: 0.2931, accuracy: 0.9200:   1%|          | 9/1000 [00:00<00:21, 46.23it/s]
# Epoch 4: train_acc_0.8577_train_loss_0.4178_val_acc_0.8635_val_loss_0.3982 epoch time 23.8254 seconds
# total time2.0 : 0.373532772064209
# loss: 0.4479, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:22<00:00, 45.67it/s]
# loss: 0.3596, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 97.96it/s]
# loss: 0.2664, accuracy: 0.9100:   1%|          | 8/1000 [00:00<00:21, 45.93it/s]
# Epoch 5: train_acc_0.8631_train_loss_0.3976_val_acc_0.8656_val_loss_0.3910 epoch time 24.0947 seconds
# total time2.0 : 24.468236923217773
# loss: 0.3533, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:21<00:00, 45.35it/s]
# loss: 0.3020, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 98.09it/s]
# loss: 0.2671, accuracy: 0.8900:   1%|          | 8/1000 [00:00<00:21, 46.85it/s]
# Epoch 6: train_acc_0.8676_train_loss_0.3811_val_acc_0.8708_val_loss_0.3777 epoch time 23.9926 seconds
# total time2.0 : 48.46082329750061
# loss: 0.3112, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:21<00:00, 45.52it/s]
# loss: 0.2817, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 101.86it/s]
# loss: 0.3710, accuracy: 0.8800:   1%|          | 9/1000 [00:00<00:21, 46.83it/s]
# Epoch 7: train_acc_0.8717_train_loss_0.3687_val_acc_0.8667_val_loss_0.3763 epoch time 24.0253 seconds
# total time3.0 : 12.486085176467896
# loss: 0.6573, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:22<00:00, 45.57it/s]
# loss: 0.4589, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 97.82it/s]
# loss: 0.2401, accuracy: 0.9200:   1%|          | 9/1000 [00:00<00:21, 46.72it/s]
# Epoch 8: train_acc_0.8748_train_loss_0.3576_val_acc_0.8783_val_loss_0.3544 epoch time 24.0605 seconds
# total time3.0 : 36.54655957221985
# loss: 0.6310, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:21<00:00, 45.40it/s]
# loss: 0.3225, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 99.34it/s]
# loss: 0.2244, accuracy: 0.9000:   1%|          | 8/1000 [00:00<00:21, 47.16it/s]
# Epoch 9: train_acc_0.8763_train_loss_0.3504_val_acc_0.8735_val_loss_0.3680 epoch time 24.0320 seconds
# total time4.0 : 0.5785982608795166
# loss: 0.3596, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:21<00:00, 45.22it/s]
# loss: 0.3166, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 98.04it/s]
# loss: 0.3372, accuracy: 0.9000:   1%|          | 9/1000 [00:00<00:21, 47.04it/s]
# Epoch 10: train_acc_0.8796_train_loss_0.3411_val_acc_0.8815_val_loss_0.3513 epoch time 24.0086 seconds
# total time4.0 : 24.587218284606934
# loss: 0.3184, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:21<00:00, 45.37it/s]
# loss: 0.2695, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 98.60it/s]
# loss: 0.2356, accuracy: 0.8700:   1%|          | 9/1000 [00:00<00:21, 46.83it/s]
# Epoch 11: train_acc_0.8815_train_loss_0.3349_val_acc_0.8827_val_loss_0.3379 epoch time 23.9712 seconds
# total time4.0 : 48.55845832824707
# loss: 0.2603, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:21<00:00, 45.76it/s]
# loss: 0.2820, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 97.90it/s]
# loss: 0.2552, accuracy: 0.8900:   1%|          | 9/1000 [00:00<00:21, 46.85it/s]
# Epoch 12: train_acc_0.8834_train_loss_0.3294_val_acc_0.8819_val_loss_0.3374 epoch time 23.9921 seconds
# total time5.0 : 12.55060338973999
# loss: 0.2939, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:21<00:00, 45.68it/s]
# loss: 0.3632, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 100.07it/s]
# loss: 0.2256, accuracy: 0.9100:   1%|          | 9/1000 [00:00<00:21, 46.79it/s]
# Epoch 13: train_acc_0.8854_train_loss_0.3243_val_acc_0.8777_val_loss_0.3443 epoch time 24.0487 seconds
# total time5.0 : 36.59926438331604
# loss: 0.4144, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:21<00:00, 45.43it/s]
# loss: 0.2762, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 99.07it/s]
# loss: 0.3318, accuracy: 0.9000:   1%|          | 9/1000 [00:00<00:20, 47.56it/s]
# Epoch 14: train_acc_0.8854_train_loss_0.3197_val_acc_0.8833_val_loss_0.3331 epoch time 24.0222 seconds
# total time6.0 : 0.6214714050292969
# loss: 0.2830, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:21<00:00, 45.29it/s]
# loss: 0.2692, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 97.40it/s]
# loss: 0.2408, accuracy: 0.8900:   1%|          | 8/1000 [00:00<00:21, 45.91it/s]
# Epoch 15: train_acc_0.8882_train_loss_0.3148_val_acc_0.8854_val_loss_0.3320 epoch time 23.9208 seconds
# total time6.0 : 24.542240142822266
# loss: 0.3793, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:21<00:00, 45.55it/s]
# loss: 0.4643, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 98.48it/s]
# loss: 0.2875, accuracy: 0.8700:   1%|          | 9/1000 [00:00<00:21, 46.18it/s]
# Epoch 16: train_acc_0.8880_train_loss_0.3116_val_acc_0.8854_val_loss_0.3254 epoch time 23.9922 seconds
# total time6.0 : 48.53448820114136
# loss: 0.2932, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:21<00:00, 46.08it/s]
# loss: 0.2614, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 97.83it/s]
# loss: 0.2975, accuracy: 0.9100:   1%|          | 8/1000 [00:00<00:21, 46.25it/s]
# Epoch 17: train_acc_0.8898_train_loss_0.3076_val_acc_0.8777_val_loss_0.3316 epoch time 23.8670 seconds
# total time7.0 : 12.401489973068237
# loss: 0.2032, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:21<00:00, 45.33it/s]
# loss: 0.3463, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 101.01it/s]
# loss: 0.1785, accuracy: 0.9300:   1%|          | 8/1000 [00:00<00:21, 46.50it/s]
# Epoch 18: train_acc_0.8906_train_loss_0.3047_val_acc_0.8873_val_loss_0.3240 epoch time 24.0179 seconds
# total time7.0 : 36.419360399246216
# ...
# total time33.0 : 37.15902400016785
# loss: 0.0450, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:31<00:00, 31.30it/s]
# loss: 0.7706, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 80.52it/s]
# loss: 0.0668, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 34.12it/s]
# Epoch 59: train_acc_0.9578_train_loss_0.1037_val_acc_0.8694_val_loss_0.6577 epoch time 34.2460 seconds
# total time34.0 : 11.405035018920898
# loss: 0.1269, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.51it/s]
# loss: 0.4368, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 81.20it/s]
# loss: 0.0745, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:30, 32.78it/s]
# Epoch 60: train_acc_0.9593_train_loss_0.0984_val_acc_0.8684_val_loss_0.6682 epoch time 33.9096 seconds
# total time34.0 : 45.314653635025024
# loss: 0.2112, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.70it/s]
# loss: 0.2564, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 79.17it/s]
# loss: 0.0763, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.60it/s]
# Epoch 61: train_acc_0.9600_train_loss_0.0983_val_acc_0.8703_val_loss_0.6698 epoch time 34.3104 seconds
# total time35.0 : 19.62501358985901
# loss: 0.0966, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:31<00:00, 31.39it/s]
# loss: 0.6578, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 79.90it/s]
# loss: 0.0836, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 33.24it/s]
# Epoch 62: train_acc_0.9611_train_loss_0.0964_val_acc_0.8688_val_loss_0.6916 epoch time 34.2169 seconds
# total time35.0 : 53.841959953308105
# loss: 0.1228, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.47it/s]
# loss: 0.5279, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 79.73it/s]
# loss: 0.0397, accuracy: 1.0000:   1%|          | 6/1000 [00:00<00:29, 33.65it/s]
# Epoch 63: train_acc_0.9609_train_loss_0.0960_val_acc_0.8699_val_loss_0.7174 epoch time 34.1886 seconds
# total time36.0 : 28.030589818954468
# loss: 0.1727, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:31<00:00, 31.33it/s]
# loss: 0.8699, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 81.02it/s]
# loss: 0.1397, accuracy: 0.9300:   1%|          | 6/1000 [00:00<00:30, 32.26it/s]
# Epoch 64: train_acc_0.9612_train_loss_0.0957_val_acc_0.8714_val_loss_0.6838 epoch time 34.2702 seconds
# total time37.0 : 2.3008337020874023
# loss: 0.1174, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.49it/s]
# loss: 0.6722, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 79.09it/s]
# loss: 0.1605, accuracy: 0.9100:   1%|          | 6/1000 [00:00<00:29, 33.41it/s]
# Epoch 65: train_acc_0.9617_train_loss_0.0935_val_acc_0.8685_val_loss_0.7148 epoch time 34.2727 seconds
# total time37.0 : 36.57349348068237
# loss: 0.0419, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.72it/s]
# loss: 0.4801, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 80.23it/s]
# loss: 0.0329, accuracy: 0.9900:   1%|          | 6/1000 [00:00<00:30, 32.44it/s]
# Epoch 66: train_acc_0.9634_train_loss_0.0924_val_acc_0.8685_val_loss_0.6786 epoch time 33.9418 seconds
# total time38.0 : 10.515343189239502
# loss: 0.1589, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:31<00:00, 31.66it/s]
# loss: 0.9149, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 79.87it/s]
# loss: 0.0872, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:29, 34.03it/s]
# Epoch 67: train_acc_0.9633_train_loss_0.0911_val_acc_0.8654_val_loss_0.7322 epoch time 34.2279 seconds
# total time38.0 : 44.74325966835022
# loss: 0.1005, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:31<00:00, 31.47it/s]
# loss: 1.0032, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 81.24it/s]
# loss: 0.0482, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:31, 31.84it/s]
# Epoch 68: train_acc_0.9635_train_loss_0.0907_val_acc_0.8661_val_loss_0.7327 epoch time 34.2437 seconds
# total time39.0 : 18.986944913864136
# loss: 0.1139, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:31<00:00, 31.11it/s]
# loss: 0.6944, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 79.68it/s]
# loss: 0.0853, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 33.22it/s]
# Epoch 69: train_acc_0.9649_train_loss_0.0877_val_acc_0.8672_val_loss_0.7210 epoch time 33.8647 seconds
# total time39.0 : 52.85160303115845
# loss: 0.1177, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:32<00:00, 31.11it/s]
# loss: 0.7608, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 81.18it/s]
# loss: 0.0454, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 32.18it/s]
# Epoch 70: train_acc_0.9648_train_loss_0.0882_val_acc_0.8682_val_loss_0.7384 epoch time 34.2316 seconds
# total time40.0 : 27.083195686340332
# loss: 0.0174, accuracy: 1.0000: 100%|██████████| 1000/1000 [00:31<00:00, 31.53it/s]
# loss: 0.9388, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 80.07it/s]
# loss: 0.0820, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 33.06it/s]
# Epoch 71: train_acc_0.9653_train_loss_0.0871_val_acc_0.8682_val_loss_0.7749 epoch time 34.2305 seconds
# total time41.0 : 1.31365966796875
# loss: 0.1432, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:31<00:00, 31.41it/s]
# loss: 0.6119, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 81.23it/s]
# loss: 0.0831, accuracy: 0.9400:   1%|          | 6/1000 [00:00<00:30, 32.57it/s]
# Epoch 72: train_acc_0.9647_train_loss_0.0866_val_acc_0.8701_val_loss_0.7392 epoch time 34.2462 seconds
# total time41.0 : 35.55988883972168
# loss: 0.1051, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.73it/s]
# loss: 0.6496, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 80.41it/s]
# loss: 0.0589, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:29, 33.75it/s]
# Epoch 73: train_acc_0.9670_train_loss_0.0820_val_acc_0.8664_val_loss_0.7944 epoch time 34.2366 seconds
# total time42.0 : 9.796529769897461
# loss: 0.0464, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.39it/s]
# loss: 0.8541, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 80.92it/s]
# loss: 0.1174, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:30, 32.88it/s]
# Epoch 74: train_acc_0.9649_train_loss_0.0867_val_acc_0.8616_val_loss_0.7978 epoch time 34.1909 seconds
# total time42.0 : 43.98745369911194
# loss: 0.0880, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.87it/s]
# loss: 0.9889, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 80.16it/s]
# loss: 0.0417, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 32.12it/s]
# Epoch 75: train_acc_0.9653_train_loss_0.0846_val_acc_0.8691_val_loss_0.7692 epoch time 34.1032 seconds
# total time43.0 : 18.090684413909912
# loss: 0.0323, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:31<00:00, 31.46it/s]
# loss: 1.5780, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 79.93it/s]
# loss: 0.0724, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.55it/s]
# Epoch 76: train_acc_0.9671_train_loss_0.0819_val_acc_0.8667_val_loss_0.8139 epoch time 34.2025 seconds
# total time43.0 : 52.29314112663269
# loss: 0.0832, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.64it/s]
# loss: 0.5997, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 79.10it/s]
# loss: 0.0561, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 32.94it/s]
# Epoch 77: train_acc_0.9680_train_loss_0.0801_val_acc_0.8662_val_loss_0.8264 epoch time 34.1929 seconds
# total time44.0 : 26.486007928848267
# loss: 0.0657, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:31<00:00, 31.83it/s]
# loss: 0.3664, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 79.93it/s]
# loss: 0.0331, accuracy: 0.9900:   1%|          | 6/1000 [00:00<00:30, 32.09it/s]
# Epoch 78: train_acc_0.9675_train_loss_0.0817_val_acc_0.8646_val_loss_0.7843 epoch time 33.7142 seconds
# total time45.0 : 0.2002408504486084
# loss: 0.0622, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.44it/s]
# loss: 0.5490, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 80.76it/s]
# loss: 0.0930, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:29, 33.64it/s]
# Epoch 79: train_acc_0.9682_train_loss_0.0817_val_acc_0.8653_val_loss_0.7954 epoch time 34.2095 seconds
# total time45.0 : 34.40969777107239
# loss: 0.0796, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.56it/s]
# loss: 1.0554, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 80.26it/s]
# loss: 0.0438, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:31, 32.02it/s]
# Epoch 80: train_acc_0.9687_train_loss_0.0794_val_acc_0.8670_val_loss_0.8105 epoch time 34.1339 seconds
# total time46.0 : 8.543577432632446
# loss: 0.1495, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:31<00:00, 31.70it/s]
# loss: 0.7309, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 79.80it/s]
# loss: 0.0473, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.97it/s]
# Epoch 81: train_acc_0.9693_train_loss_0.0775_val_acc_0.8656_val_loss_0.8246 epoch time 34.1837 seconds
# total time46.0 : 42.727251052856445
# loss: 0.0838, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.68it/s]
# loss: 0.7485, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 80.78it/s]
# loss: 0.1112, accuracy: 0.9400:   1%|          | 6/1000 [00:00<00:31, 31.77it/s]
# Epoch 82: train_acc_0.9688_train_loss_0.0800_val_acc_0.8686_val_loss_0.8162 epoch time 34.2594 seconds
# total time47.0 : 16.986631631851196
# loss: 0.0425, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.62it/s]
# loss: 0.8942, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 80.59it/s]
# loss: 0.0757, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 33.39it/s]
# Epoch 83: train_acc_0.9695_train_loss_0.0780_val_acc_0.8623_val_loss_0.8273 epoch time 34.0677 seconds
# total time47.0 : 51.05434322357178
# loss: 0.0245, accuracy: 1.0000: 100%|██████████| 1000/1000 [00:31<00:00, 31.64it/s]
# loss: 1.1970, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 80.40it/s]
# loss: 0.1232, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.75it/s]
# Epoch 84: train_acc_0.9694_train_loss_0.0770_val_acc_0.8665_val_loss_0.8431 epoch time 33.9191 seconds
# total time48.0 : 24.9734468460083
# loss: 0.1078, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:31<00:00, 31.85it/s]
# loss: 0.5415, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 79.88it/s]
# loss: 0.0819, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.43it/s]
# Epoch 85: train_acc_0.9699_train_loss_0.0753_val_acc_0.8664_val_loss_0.8414 epoch time 34.1294 seconds
# total time48.0 : 59.10287308692932
# loss: 0.1301, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.54it/s]
# loss: 0.8466, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 81.62it/s]
# loss: 0.0319, accuracy: 0.9900:   1%|          | 6/1000 [00:00<00:30, 32.53it/s]
# Epoch 86: train_acc_0.9703_train_loss_0.0771_val_acc_0.8622_val_loss_0.8507 epoch time 34.1521 seconds
# total time49.0 : 33.254982471466064
# loss: 0.0862, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.97it/s]
# loss: 1.1368, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 80.76it/s]
# loss: 0.0485, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:29, 34.23it/s]
# Epoch 87: train_acc_0.9702_train_loss_0.0761_val_acc_0.8653_val_loss_0.8076 epoch time 33.8643 seconds
# total time50.0 : 7.119264841079712
# loss: 0.0880, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.31it/s]
# loss: 0.5223, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 80.05it/s]
# loss: 0.0567, accuracy: 0.9900:   1%|          | 6/1000 [00:00<00:31, 31.65it/s]
# Epoch 88: train_acc_0.9710_train_loss_0.0735_val_acc_0.8617_val_loss_0.8409 epoch time 34.2434 seconds
# total time50.0 : 41.36263728141785
# loss: 0.0378, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.51it/s]
# loss: 0.8425, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 79.38it/s]
# loss: 0.0530, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 33.20it/s]
# Epoch 89: train_acc_0.9711_train_loss_0.0727_val_acc_0.8639_val_loss_0.9124 epoch time 34.2510 seconds
# total time51.0 : 15.613620519638062
# loss: 0.1169, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:31<00:00, 31.55it/s]
# loss: 1.2801, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 80.67it/s]
# loss: 0.0530, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:29, 33.21it/s]
# Epoch 90: train_acc_0.9709_train_loss_0.0753_val_acc_0.8666_val_loss_0.8646 epoch time 34.1601 seconds
# total time51.0 : 49.77371525764465
# loss: 0.1584, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:31<00:00, 31.46it/s]
# loss: 1.4125, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 79.54it/s]
# loss: 0.0196, accuracy: 1.0000:   1%|          | 6/1000 [00:00<00:29, 33.50it/s]
# Epoch 91: train_acc_0.9717_train_loss_0.0718_val_acc_0.8676_val_loss_0.8784 epoch time 34.1227 seconds
# total time52.0 : 23.89641547203064
# loss: 0.1427, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:31<00:00, 31.31it/s]
# loss: 0.6668, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 80.84it/s]
# loss: 0.0360, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 32.54it/s]
# Epoch 92: train_acc_0.9719_train_loss_0.0720_val_acc_0.8656_val_loss_0.8968 epoch time 34.2021 seconds
# total time52.0 : 58.0984902381897
# loss: 0.0632, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:31<00:00, 31.38it/s]
# loss: 0.7766, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 80.34it/s]
# loss: 0.0561, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:29, 33.60it/s]
# Epoch 93: train_acc_0.9726_train_loss_0.0716_val_acc_0.8645_val_loss_0.9108 epoch time 34.0305 seconds
# total time53.0 : 32.12903904914856
# loss: 0.1663, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:31<00:00, 31.75it/s]
# loss: 0.6323, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 82.13it/s]
# loss: 0.0487, accuracy: 0.9700:   1%|          | 6/1000 [00:00<00:30, 32.38it/s]
# Epoch 94: train_acc_0.9721_train_loss_0.0736_val_acc_0.8664_val_loss_0.8104 epoch time 34.2829 seconds
# total time54.0 : 6.411973476409912
# loss: 0.0743, accuracy: 0.9800: 100%|██████████| 1000/1000 [00:31<00:00, 31.32it/s]
# loss: 0.6044, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 79.66it/s]
# loss: 0.0640, accuracy: 0.9900:   1%|          | 6/1000 [00:00<00:30, 32.76it/s]
# Epoch 95: train_acc_0.9728_train_loss_0.0720_val_acc_0.8612_val_loss_0.8465 epoch time 34.2047 seconds
# total time54.0 : 40.61667060852051
# loss: 0.1445, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:31<00:00, 31.28it/s]
# loss: 0.7459, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 80.90it/s]
# loss: 0.0560, accuracy: 0.9800:   1%|          | 6/1000 [00:00<00:30, 32.28it/s]
# Epoch 96: train_acc_0.9741_train_loss_0.0675_val_acc_0.8629_val_loss_0.8873 epoch time 33.8232 seconds
# total time55.0 : 14.439870357513428
# loss: 0.0313, accuracy: 0.9900: 100%|██████████| 1000/1000 [00:31<00:00, 31.27it/s]
# loss: 0.2913, accuracy: 0.9400: 100%|██████████| 158/158 [00:01<00:00, 79.55it/s]
# loss: 0.1123, accuracy: 0.9600:   1%|          | 6/1000 [00:00<00:30, 32.96it/s]
# Epoch 97: train_acc_0.9729_train_loss_0.0708_val_acc_0.8643_val_loss_0.9311 epoch time 34.1585 seconds
# total time55.0 : 48.59838032722473
# loss: 0.1186, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:31<00:00, 31.31it/s]
# loss: 1.5138, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 80.85it/s]
# loss: 0.0207, accuracy: 1.0000:   1%|          | 6/1000 [00:00<00:30, 33.02it/s]
# Epoch 98: train_acc_0.9744_train_loss_0.0668_val_acc_0.8665_val_loss_0.9141 epoch time 34.1816 seconds
# total time56.0 : 22.78000831604004
# loss: 0.1059, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:31<00:00, 31.41it/s]
# loss: 1.2486, accuracy: 0.7600: 100%|██████████| 158/158 [00:02<00:00, 78.97it/s]
# loss: 0.3145, accuracy: 0.8800:  10%|█         | 16/158 [00:00<00:01, 85.06it/s]
# Epoch 99: train_acc_0.9741_train_loss_0.0669_val_acc_0.8597_val_loss_0.9109 epoch time 34.2133 seconds
# total time56.0 : 56.993284940719604
# Generating test set evaluation metrics
# loss: 0.9465, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 80.52it/s]
# finish

# %%
#stride2_filter32_layer1234_type2

batch_size = 100
image_num_channels = 1
image_height = 28
image_width = 28
dim_reduction_idx = 2
dim_reduction_type = ['strided_convolution', 'dilated_convolution', 'max_pooling', 'avg_pooling']
num_filters = 32
num_layers = [1,2,3,4]
experiment_name = []
for layer in num_layers:
    experiment_name.append("stride2_filter32_layer{}_type{}".format(layer,dim_reduction_idx))
num_epochs = 100
weight_decay_coefficient = 1e-05
seed = 9112018
use_gpu = True

rng = np.random.RandomState(seed=seed)
train_data = data_providers.EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
val_data = data_providers.EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = data_providers.EMNISTDataProvider('test', batch_size=batch_size, rng=rng)

for experiment,layer in zip(experiment_name,num_layers):
    
    print(experiment)
    
    custom_conv_net = ConvolutionalNetwork(
        input_shape=(batch_size, image_num_channels, image_height, image_width),
        dim_reduction_type=dim_reduction_type[dim_reduction_idx],
        num_output_classes=47, num_filters=num_filters, num_layers=layer, use_bias=True)

    conv_experiment = ExperimentBuilder(network_model=custom_conv_net,
                                    experiment_name=experiment,
                                    num_epochs=num_epochs,
                                    weight_decay_coefficient=weight_decay_coefficient,
                                    use_gpu=use_gpu,
                                    train_data=train_data, val_data=val_data, test_data=test_data)
    print(custom_conv_net)
    total_losses = conv_experiment.run_experiment()
    print('finish')
    plot_stats_in_graph(total_losses[0])
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe40a0dbc50>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe40a0b2dd8>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe40a0b2f98>)
# stride2_filter32_layer1_type2
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 15, 15])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_max_pool_0): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 2.7051, accuracy: 0.2800: 100%|██████████| 1000/1000 [00:10<00:00, 91.89it/s]
# loss: 2.6690, accuracy: 0.3400: 100%|██████████| 158/158 [00:01<00:00, 137.28it/s]
# Epoch 0: train_acc_0.1904_train_loss_3.1004_val_acc_0.2799_val_loss_2.7139 epoch time 12.1923 seconds
# total time0.0 : 12.192293643951416
# loss: 2.3486, accuracy: 0.3700: 100%|██████████| 1000/1000 [00:10<00:00, 95.53it/s]
# loss: 2.4995, accuracy: 0.3700: 100%|██████████| 158/158 [00:01<00:00, 151.11it/s]
# loss: 2.4363, accuracy: 0.3100:   2%|▏         | 20/1000 [00:00<00:09, 105.93it/s]
# Epoch 1: train_acc_0.3272_train_loss_2.5305_val_acc_0.3934_val_loss_2.3366 epoch time 11.6566 seconds
# total time0.0 : 23.848942518234253
# loss: 1.7830, accuracy: 0.5400: 100%|██████████| 1000/1000 [00:10<00:00, 95.64it/s]
# loss: 2.1334, accuracy: 0.4700: 100%|██████████| 158/158 [00:01<00:00, 147.23it/s]
# loss: 1.8476, accuracy: 0.4800:   2%|▏         | 19/1000 [00:00<00:09, 100.23it/s]
# Epoch 2: train_acc_0.4413_train_loss_2.1591_val_acc_0.4859_val_loss_1.9772 epoch time 11.6705 seconds
# total time0.0 : 35.51948142051697
# loss: 1.9193, accuracy: 0.4200: 100%|██████████| 1000/1000 [00:10<00:00, 96.23it/s]
# loss: 1.5666, accuracy: 0.6100: 100%|██████████| 158/158 [00:00<00:00, 164.91it/s]
# loss: 1.6606, accuracy: 0.5800:   2%|▏         | 20/1000 [00:00<00:09, 108.01it/s]
# Epoch 3: train_acc_0.5322_train_loss_1.8262_val_acc_0.5632_val_loss_1.6755 epoch time 11.5488 seconds
# total time0.0 : 47.068325996398926
# loss: 1.4945, accuracy: 0.6400: 100%|██████████| 1000/1000 [00:10<00:00, 100.00it/s]
# loss: 1.7730, accuracy: 0.5600: 100%|██████████| 158/158 [00:01<00:00, 149.84it/s]
# loss: 1.4480, accuracy: 0.5900:   2%|▏         | 19/1000 [00:00<00:09, 104.67it/s]
# Epoch 4: train_acc_0.5915_train_loss_1.5688_val_acc_0.6163_val_loss_1.4527 epoch time 11.1955 seconds
# total time0.0 : 58.26379132270813
# loss: 1.3501, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 95.57it/s]
# loss: 1.2738, accuracy: 0.6600: 100%|██████████| 158/158 [00:01<00:00, 148.25it/s]
# loss: 1.1023, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 98.50it/s]
# Epoch 5: train_acc_0.6297_train_loss_1.3878_val_acc_0.6468_val_loss_1.3038 epoch time 11.6703 seconds
# total time1.0 : 9.934045553207397
# loss: 1.2520, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 95.31it/s]
# loss: 1.0235, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 150.28it/s]
# loss: 1.0872, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 106.52it/s]
# Epoch 6: train_acc_0.6546_train_loss_1.2625_val_acc_0.6659_val_loss_1.2003 epoch time 11.6833 seconds
# total time1.0 : 21.617306232452393
# loss: 1.4049, accuracy: 0.5700: 100%|██████████| 1000/1000 [00:10<00:00, 95.47it/s]
# loss: 1.4234, accuracy: 0.6200: 100%|██████████| 158/158 [00:01<00:00, 150.07it/s]
# loss: 1.1112, accuracy: 0.6800:   2%|▏         | 20/1000 [00:00<00:09, 101.76it/s]
# Epoch 7: train_acc_0.6703_train_loss_1.1781_val_acc_0.6813_val_loss_1.1288 epoch time 11.6751 seconds
# total time1.0 : 33.29242467880249
# loss: 0.8502, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 95.26it/s]
# loss: 1.0190, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 148.21it/s]
# loss: 1.1872, accuracy: 0.5800:   2%|▏         | 19/1000 [00:00<00:09, 101.70it/s]
# Epoch 8: train_acc_0.6823_train_loss_1.1167_val_acc_0.6885_val_loss_1.0811 epoch time 11.7069 seconds
# total time1.0 : 44.99935460090637
# loss: 0.9914, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 95.48it/s]
# loss: 1.0483, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 150.90it/s]
# loss: 1.1854, accuracy: 0.6400:   2%|▏         | 20/1000 [00:00<00:08, 110.61it/s]
# Epoch 9: train_acc_0.6905_train_loss_1.0727_val_acc_0.6948_val_loss_1.0443 epoch time 11.6587 seconds
# total time1.0 : 56.65806841850281
# loss: 0.8353, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 96.07it/s]
# loss: 0.9929, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 150.82it/s]
# loss: 1.1785, accuracy: 0.6900:   2%|▏         | 20/1000 [00:00<00:09, 108.83it/s]
# Epoch 10: train_acc_0.6967_train_loss_1.0388_val_acc_0.7058_val_loss_1.0084 epoch time 11.6000 seconds
# total time2.0 : 8.258053064346313
# loss: 0.9007, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 95.88it/s]
# loss: 0.9869, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 147.21it/s]
# loss: 0.9798, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 102.71it/s]
# Epoch 11: train_acc_0.7012_train_loss_1.0129_val_acc_0.7074_val_loss_0.9904 epoch time 11.6437 seconds
# total time2.0 : 19.90172028541565
# loss: 0.9277, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 95.53it/s]
# loss: 0.7996, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 150.36it/s]
# loss: 0.8947, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 102.57it/s]
# Epoch 12: train_acc_0.7065_train_loss_0.9919_val_acc_0.7110_val_loss_0.9729 epoch time 11.6601 seconds
# total time2.0 : 31.561827421188354
# loss: 0.9154, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.28it/s]
# loss: 0.8132, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 145.18it/s]
# loss: 0.8701, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 101.18it/s]
# Epoch 13: train_acc_0.7109_train_loss_0.9747_val_acc_0.7176_val_loss_0.9534 epoch time 11.7254 seconds
# total time2.0 : 43.28718280792236
# loss: 0.9126, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 96.73it/s]
# loss: 1.1202, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 149.84it/s]
# loss: 0.9105, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 102.47it/s]
# Epoch 14: train_acc_0.7127_train_loss_0.9611_val_acc_0.7179_val_loss_0.9410 epoch time 11.5364 seconds
# total time2.0 : 54.82358002662659
# loss: 0.8420, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 95.34it/s]
# loss: 0.8292, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 148.05it/s]
# loss: 0.8974, accuracy: 0.6600:   2%|▏         | 20/1000 [00:00<00:09, 102.19it/s]
# Epoch 15: train_acc_0.7158_train_loss_0.9491_val_acc_0.7193_val_loss_0.9330 epoch time 11.6956 seconds
# total time3.0 : 6.5191330909729
# loss: 1.0713, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 98.73it/s]
# loss: 0.9944, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 151.44it/s]
# loss: 0.7571, accuracy: 0.7400:   2%|▏         | 20/1000 [00:00<00:09, 101.99it/s]
# Epoch 16: train_acc_0.7173_train_loss_0.9384_val_acc_0.7250_val_loss_0.9244 epoch time 11.3114 seconds
# total time3.0 : 17.830485582351685
# loss: 0.8130, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 96.64it/s]
# loss: 1.1866, accuracy: 0.6200: 100%|██████████| 158/158 [00:01<00:00, 151.12it/s]
# loss: 0.9085, accuracy: 0.7500:   2%|▏         | 20/1000 [00:00<00:09, 101.76it/s]
# Epoch 17: train_acc_0.7198_train_loss_0.9286_val_acc_0.7240_val_loss_0.9171 epoch time 11.5362 seconds
# total time3.0 : 29.36665415763855
# loss: 0.8779, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 97.90it/s]
# loss: 0.8425, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 153.21it/s]
# loss: 1.0950, accuracy: 0.6600:   2%|▏         | 20/1000 [00:00<00:09, 103.98it/s]
# Epoch 18: train_acc_0.7232_train_loss_0.9196_val_acc_0.7270_val_loss_0.9030 epoch time 11.7203 seconds
# total time3.0 : 41.086904525756836
# loss: 0.8827, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.57it/s]
# loss: 0.8174, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 156.28it/s]
# loss: 0.7358, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.00it/s]
# Epoch 19: train_acc_0.7241_train_loss_0.9130_val_acc_0.7242_val_loss_0.9030 epoch time 11.6807 seconds
# total time3.0 : 52.76764440536499
# loss: 0.9914, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 97.95it/s]
# loss: 0.8131, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 147.47it/s]
# loss: 1.1509, accuracy: 0.7300:   2%|▏         | 20/1000 [00:00<00:09, 104.66it/s]
# Epoch 20: train_acc_0.7248_train_loss_0.9065_val_acc_0.7319_val_loss_0.8941 epoch time 11.7440 seconds
# total time4.0 : 4.511658191680908
# loss: 0.6795, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:10<00:00, 95.93it/s]
# loss: 0.7891, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 150.06it/s]
# loss: 0.9194, accuracy: 0.7600:   2%|▏         | 20/1000 [00:00<00:09, 104.07it/s]
# Epoch 21: train_acc_0.7273_train_loss_0.8994_val_acc_0.7325_val_loss_0.8872 epoch time 11.6176 seconds
# total time4.0 : 16.129265069961548
# loss: 0.9945, accuracy: 0.6500: 100%|██████████| 1000/1000 [00:10<00:00, 96.94it/s]
# loss: 0.8224, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 148.93it/s]
# loss: 0.8780, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 102.97it/s]
# Epoch 22: train_acc_0.7296_train_loss_0.8924_val_acc_0.7335_val_loss_0.8825 epoch time 11.7058 seconds
# total time4.0 : 27.835090160369873
# loss: 0.9116, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 95.42it/s]
# loss: 0.9093, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 149.04it/s]
# loss: 0.8645, accuracy: 0.7300:   2%|▏         | 20/1000 [00:00<00:09, 103.14it/s]
# Epoch 23: train_acc_0.7300_train_loss_0.8881_val_acc_0.7330_val_loss_0.8776 epoch time 11.6841 seconds
# total time4.0 : 39.51916527748108
# loss: 1.2734, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 96.72it/s]
# loss: 0.6773, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.24it/s]
# loss: 0.8828, accuracy: 0.7200:   2%|▏         | 19/1000 [00:00<00:09, 100.62it/s]
# Epoch 24: train_acc_0.7325_train_loss_0.8816_val_acc_0.7356_val_loss_0.8721 epoch time 11.5443 seconds
# total time4.0 : 51.06349492073059
# loss: 0.8252, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 95.53it/s]
# loss: 0.9161, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 147.83it/s]
# loss: 1.2381, accuracy: 0.6500:   2%|▏         | 19/1000 [00:00<00:09, 102.47it/s]
# Epoch 25: train_acc_0.7332_train_loss_0.8767_val_acc_0.7342_val_loss_0.8734 epoch time 11.6787 seconds
# total time5.0 : 2.742220878601074
# loss: 0.9702, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 95.11it/s]
# loss: 0.8244, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 149.65it/s]
# loss: 0.9712, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 100.18it/s]
# Epoch 26: train_acc_0.7344_train_loss_0.8730_val_acc_0.7372_val_loss_0.8600 epoch time 11.7119 seconds
# total time5.0 : 14.454078197479248
# loss: 0.8911, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 96.22it/s]
# loss: 0.8561, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 152.13it/s]
# loss: 1.1696, accuracy: 0.6900:   2%|▏         | 20/1000 [00:00<00:09, 107.74it/s]
# Epoch 27: train_acc_0.7355_train_loss_0.8672_val_acc_0.7353_val_loss_0.8615 epoch time 11.5707 seconds
# total time5.0 : 26.024736166000366
# loss: 0.9135, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.28it/s]
# loss: 0.8529, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 148.50it/s]
# loss: 0.5931, accuracy: 0.8100:   2%|▏         | 19/1000 [00:00<00:09, 103.38it/s]
# Epoch 28: train_acc_0.7360_train_loss_0.8629_val_acc_0.7384_val_loss_0.8540 epoch time 11.7014 seconds
# total time5.0 : 37.72615718841553
# loss: 1.0052, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 95.55it/s]
# loss: 0.7428, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.77it/s]
# loss: 0.7169, accuracy: 0.8000:   2%|▏         | 20/1000 [00:00<00:09, 107.95it/s]
# Epoch 29: train_acc_0.7382_train_loss_0.8576_val_acc_0.7392_val_loss_0.8527 epoch time 11.6673 seconds
# total time5.0 : 49.393505573272705
# loss: 0.6155, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 98.94it/s]
# loss: 0.7359, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 155.72it/s]
# loss: 1.0928, accuracy: 0.6100:   2%|▏         | 20/1000 [00:00<00:09, 104.09it/s]
# Epoch 30: train_acc_0.7395_train_loss_0.8531_val_acc_0.7419_val_loss_0.8538 epoch time 11.2604 seconds
# total time6.0 : 0.6539082527160645
# loss: 0.8138, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 98.05it/s]
# loss: 0.6562, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 146.70it/s]
# loss: 0.9135, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 104.10it/s]
# Epoch 31: train_acc_0.7412_train_loss_0.8489_val_acc_0.7442_val_loss_0.8446 epoch time 11.4166 seconds
# total time6.0 : 12.070538997650146
# loss: 0.9388, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 95.37it/s]
# loss: 0.8495, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 148.70it/s]
# loss: 0.8896, accuracy: 0.7300:   2%|▏         | 20/1000 [00:00<00:09, 103.51it/s]
# Epoch 32: train_acc_0.7421_train_loss_0.8445_val_acc_0.7459_val_loss_0.8359 epoch time 11.6872 seconds
# total time6.0 : 23.757732152938843
# loss: 0.8700, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 95.17it/s]
# loss: 0.7825, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 149.91it/s]
# loss: 0.8481, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 102.54it/s]
# Epoch 33: train_acc_0.7437_train_loss_0.8408_val_acc_0.7468_val_loss_0.8318 epoch time 11.7048 seconds
# total time6.0 : 35.46256184577942
# loss: 0.9669, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 94.65it/s]
# loss: 0.9056, accuracy: 0.7200: 100%|██████████| 158/158 [00:00<00:00, 161.46it/s]
# loss: 0.9926, accuracy: 0.7000:   2%|▏         | 20/1000 [00:00<00:09, 108.48it/s]
# Epoch 34: train_acc_0.7436_train_loss_0.8368_val_acc_0.7475_val_loss_0.8334 epoch time 11.7509 seconds
# total time6.0 : 47.213417768478394
# loss: 1.2115, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 95.95it/s]
# loss: 0.9076, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 149.93it/s]
# loss: 0.8216, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 98.84it/s]
# Epoch 35: train_acc_0.7462_train_loss_0.8333_val_acc_0.7494_val_loss_0.8236 epoch time 11.6165 seconds
# total time6.0 : 58.82988691329956
# loss: 0.9274, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 95.32it/s]
# loss: 0.7950, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 150.08it/s]
# loss: 0.9393, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 101.66it/s]
# Epoch 36: train_acc_0.7454_train_loss_0.8303_val_acc_0.7474_val_loss_0.8279 epoch time 11.6846 seconds
# total time7.0 : 10.514455556869507
# loss: 0.9277, accuracy: 0.6400: 100%|██████████| 1000/1000 [00:10<00:00, 95.42it/s]
# loss: 0.6576, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 149.49it/s]
# loss: 0.8942, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 98.94it/s]
# Epoch 37: train_acc_0.7477_train_loss_0.8272_val_acc_0.7509_val_loss_0.8252 epoch time 11.6820 seconds
# total time7.0 : 22.196429014205933
# loss: 0.6897, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 95.21it/s]
# loss: 0.7584, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.11it/s]
# loss: 0.9003, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.27it/s]
# Epoch 38: train_acc_0.7478_train_loss_0.8232_val_acc_0.7541_val_loss_0.8138 epoch time 11.7116 seconds
# total time7.0 : 33.908013582229614
# loss: 0.7501, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 95.26it/s]
# loss: 1.0531, accuracy: 0.6700: 100%|██████████| 158/158 [00:01<00:00, 153.82it/s]
# loss: 0.7847, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.60it/s]
# Epoch 39: train_acc_0.7495_train_loss_0.8200_val_acc_0.7475_val_loss_0.8181 epoch time 11.7158 seconds
# total time7.0 : 45.623855113983154
# loss: 0.6701, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 94.98it/s]
# loss: 0.7796, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 150.74it/s]
# loss: 0.9122, accuracy: 0.7500:   2%|▏         | 20/1000 [00:00<00:09, 105.52it/s]
# Epoch 40: train_acc_0.7495_train_loss_0.8170_val_acc_0.7496_val_loss_0.8149 epoch time 11.7141 seconds
# total time7.0 : 57.337952613830566
# loss: 0.7515, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 95.45it/s]
# loss: 0.7202, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.47it/s]
# loss: 0.9385, accuracy: 0.7400:   2%|▏         | 21/1000 [00:00<00:08, 116.43it/s]
# Epoch 41: train_acc_0.7506_train_loss_0.8131_val_acc_0.7509_val_loss_0.8116 epoch time 11.6861 seconds
# total time8.0 : 9.024012088775635
# loss: 0.4768, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:10<00:00, 97.88it/s]
# loss: 0.8617, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 155.57it/s]
# loss: 0.7104, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 101.47it/s]
# Epoch 42: train_acc_0.7521_train_loss_0.8117_val_acc_0.7534_val_loss_0.8071 epoch time 11.4281 seconds
# total time8.0 : 20.452149629592896
# loss: 0.6572, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:10<00:00, 95.50it/s]
# loss: 0.8197, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 151.35it/s]
# loss: 0.9568, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 102.18it/s]
# Epoch 43: train_acc_0.7517_train_loss_0.8089_val_acc_0.7549_val_loss_0.8063 epoch time 11.6602 seconds
# total time8.0 : 32.112313747406006
# loss: 0.6330, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 95.60it/s]
# loss: 0.6895, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 149.86it/s]
# loss: 0.9015, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 103.57it/s]
# Epoch 44: train_acc_0.7529_train_loss_0.8057_val_acc_0.7545_val_loss_0.8034 epoch time 11.6589 seconds
# total time8.0 : 43.77123785018921
# loss: 0.8582, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 96.90it/s]
# loss: 0.7697, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 146.43it/s]
# loss: 0.7831, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 101.72it/s]
# Epoch 45: train_acc_0.7534_train_loss_0.8024_val_acc_0.7570_val_loss_0.7952 epoch time 11.5401 seconds
# total time8.0 : 55.31131291389465
# loss: 0.9389, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 95.29it/s]
# loss: 0.7361, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 149.84it/s]
# loss: 0.8022, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 102.76it/s]
# Epoch 46: train_acc_0.7553_train_loss_0.8012_val_acc_0.7552_val_loss_0.7957 epoch time 11.6889 seconds
# total time9.0 : 7.0002312660217285
# loss: 0.8809, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.33it/s]
# loss: 0.8515, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 147.57it/s]
# loss: 0.6466, accuracy: 0.7900:   2%|▏         | 20/1000 [00:00<00:09, 105.05it/s]
# Epoch 47: train_acc_0.7550_train_loss_0.7990_val_acc_0.7565_val_loss_0.7943 epoch time 11.7012 seconds
# total time9.0 : 18.701384782791138
# loss: 0.6221, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.69it/s]
# loss: 0.7905, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 146.90it/s]
# loss: 0.7166, accuracy: 0.8000:   2%|▏         | 20/1000 [00:00<00:09, 104.39it/s]
# Epoch 48: train_acc_0.7559_train_loss_0.7960_val_acc_0.7571_val_loss_0.7927 epoch time 11.6691 seconds
# total time9.0 : 30.37051796913147
# loss: 0.8947, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 94.89it/s]
# loss: 1.0477, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 146.75it/s]
# loss: 0.8155, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 106.00it/s]
# Epoch 49: train_acc_0.7558_train_loss_0.7938_val_acc_0.7552_val_loss_0.7922 epoch time 11.7580 seconds
# total time9.0 : 42.128474712371826
# loss: 0.9246, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 95.23it/s]
# loss: 0.6403, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 150.17it/s]
# loss: 0.8449, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 99.20it/s]
# Epoch 50: train_acc_0.7557_train_loss_0.7917_val_acc_0.7601_val_loss_0.7888 epoch time 11.6970 seconds
# total time9.0 : 53.8254668712616
# loss: 0.5947, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.17it/s]
# loss: 0.8251, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 149.59it/s]
# loss: 0.9655, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 103.25it/s]
# Epoch 51: train_acc_0.7573_train_loss_0.7891_val_acc_0.7566_val_loss_0.7902 epoch time 11.7055 seconds
# total time10.0 : 5.53100323677063
# loss: 0.6994, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 95.06it/s]
# loss: 0.7376, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 149.08it/s]
# loss: 0.6882, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 104.53it/s]
# Epoch 52: train_acc_0.7580_train_loss_0.7874_val_acc_0.7580_val_loss_0.7880 epoch time 11.7179 seconds
# total time10.0 : 17.24894380569458
# loss: 0.6493, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 94.94it/s]
# loss: 0.8039, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 152.06it/s]
# loss: 1.1580, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 101.64it/s]
# Epoch 53: train_acc_0.7581_train_loss_0.7850_val_acc_0.7566_val_loss_0.7865 epoch time 11.7125 seconds
# total time10.0 : 28.961417198181152
# loss: 0.8548, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 97.15it/s]
# loss: 0.6250, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 147.22it/s]
# loss: 0.7579, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.43it/s]
# Epoch 54: train_acc_0.7579_train_loss_0.7832_val_acc_0.7596_val_loss_0.7780 epoch time 11.7077 seconds
# total time10.0 : 40.66906929016113
# loss: 0.8191, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 97.22it/s]
# loss: 0.9098, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 150.58it/s]
# loss: 0.8767, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 100.83it/s]
# Epoch 55: train_acc_0.7607_train_loss_0.7810_val_acc_0.7609_val_loss_0.7759 epoch time 11.4757 seconds
# total time10.0 : 52.14472484588623
# loss: 0.7893, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 95.42it/s]
# loss: 0.7036, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 147.63it/s]
# loss: 0.8627, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 102.87it/s]
# Epoch 56: train_acc_0.7596_train_loss_0.7793_val_acc_0.7621_val_loss_0.7754 epoch time 11.6891 seconds
# total time11.0 : 3.833808422088623
# loss: 0.8927, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:09<00:00, 101.43it/s]
# loss: 0.7017, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 153.70it/s]
# loss: 0.7021, accuracy: 0.7700:   2%|▏         | 20/1000 [00:00<00:09, 108.89it/s]
# Epoch 57: train_acc_0.7605_train_loss_0.7769_val_acc_0.7580_val_loss_0.7765 epoch time 11.0308 seconds
# total time11.0 : 14.864641666412354
# loss: 0.7211, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 95.73it/s]
# loss: 0.8646, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 153.94it/s]
# loss: 0.7085, accuracy: 0.7400:   2%|▏         | 20/1000 [00:00<00:08, 112.12it/s]
# Epoch 58: train_acc_0.7615_train_loss_0.7757_val_acc_0.7584_val_loss_0.7742 epoch time 11.6624 seconds
# total time11.0 : 26.527081727981567
# loss: 0.8402, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.41it/s]
# loss: 0.7242, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 146.52it/s]
# loss: 0.8434, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 99.85it/s]
# Epoch 59: train_acc_0.7618_train_loss_0.7733_val_acc_0.7637_val_loss_0.7714 epoch time 11.7028 seconds
# total time11.0 : 38.22984600067139
# loss: 0.9965, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 95.30it/s]
# loss: 0.6711, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 147.76it/s]
# loss: 0.7876, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:10, 98.08it/s]
# Epoch 60: train_acc_0.7618_train_loss_0.7721_val_acc_0.7596_val_loss_0.7745 epoch time 11.7054 seconds
# total time11.0 : 49.935288190841675
# loss: 0.6434, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:10<00:00, 96.26it/s]
# loss: 0.7964, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 152.14it/s]
# loss: 0.6151, accuracy: 0.8000:   2%|▏         | 19/1000 [00:00<00:09, 100.89it/s]
# Epoch 61: train_acc_0.7626_train_loss_0.7704_val_acc_0.7632_val_loss_0.7697 epoch time 11.5669 seconds
# total time12.0 : 1.5021700859069824
# loss: 0.9551, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 96.62it/s]
# loss: 0.5886, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 148.98it/s]
# loss: 0.6751, accuracy: 0.7800:   2%|▏         | 20/1000 [00:00<00:09, 104.97it/s]
# Epoch 62: train_acc_0.7623_train_loss_0.7684_val_acc_0.7646_val_loss_0.7657 epoch time 11.5472 seconds
# total time12.0 : 13.049381732940674
# loss: 1.2065, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 96.87it/s]
# loss: 0.8399, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 151.63it/s]
# loss: 0.9041, accuracy: 0.7500:   2%|▏         | 20/1000 [00:00<00:09, 104.55it/s]
# Epoch 63: train_acc_0.7640_train_loss_0.7661_val_acc_0.7612_val_loss_0.7656 epoch time 11.5023 seconds
# total time12.0 : 24.551659107208252
# loss: 0.7851, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 96.92it/s]
# loss: 0.6957, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 152.43it/s]
# loss: 0.6728, accuracy: 0.8400:   2%|▏         | 20/1000 [00:00<00:09, 106.99it/s]
# Epoch 64: train_acc_0.7641_train_loss_0.7648_val_acc_0.7604_val_loss_0.7670 epoch time 11.4904 seconds
# total time12.0 : 36.042078733444214
# loss: 0.8330, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 96.72it/s]
# loss: 0.7503, accuracy: 0.7600: 100%|██████████| 158/158 [00:00<00:00, 164.32it/s]
# loss: 0.7067, accuracy: 0.7700:   2%|▏         | 20/1000 [00:00<00:09, 105.31it/s]
# Epoch 65: train_acc_0.7652_train_loss_0.7633_val_acc_0.7629_val_loss_0.7631 epoch time 11.4833 seconds
# total time12.0 : 47.525343894958496
# loss: 0.9511, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 95.81it/s]
# loss: 0.6726, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 147.63it/s]
# loss: 0.5354, accuracy: 0.8400:   2%|▏         | 19/1000 [00:00<00:09, 103.66it/s]
# Epoch 66: train_acc_0.7650_train_loss_0.7616_val_acc_0.7651_val_loss_0.7598 epoch time 11.6507 seconds
# total time12.0 : 59.175999879837036
# loss: 0.7670, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 95.20it/s]
# loss: 0.7780, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 149.28it/s]
# loss: 0.8561, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:09, 101.73it/s]
# Epoch 67: train_acc_0.7656_train_loss_0.7605_val_acc_0.7626_val_loss_0.7602 epoch time 11.7062 seconds
# total time13.0 : 10.882159948348999
# loss: 0.8564, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 97.00it/s]
# loss: 0.7447, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 152.97it/s]
# loss: 0.8388, accuracy: 0.7400:   2%|▏         | 21/1000 [00:00<00:08, 110.50it/s]
# Epoch 68: train_acc_0.7644_train_loss_0.7589_val_acc_0.7634_val_loss_0.7616 epoch time 11.4819 seconds
# total time13.0 : 22.364022254943848
# loss: 0.7708, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 96.36it/s]
# loss: 0.6564, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.25it/s]
# loss: 0.6477, accuracy: 0.8000:   2%|▏         | 19/1000 [00:00<00:09, 105.17it/s]
# Epoch 69: train_acc_0.7661_train_loss_0.7569_val_acc_0.7658_val_loss_0.7562 epoch time 11.5869 seconds
# total time13.0 : 33.95092296600342
# loss: 0.9823, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 97.93it/s]
# loss: 0.6608, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.32it/s]
# loss: 0.8329, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 98.79it/s]
# Epoch 70: train_acc_0.7667_train_loss_0.7551_val_acc_0.7677_val_loss_0.7527 epoch time 11.6766 seconds
# total time13.0 : 45.6275098323822
# loss: 0.7080, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 95.36it/s]
# loss: 0.9506, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 147.80it/s]
# loss: 0.6384, accuracy: 0.8500:   2%|▏         | 20/1000 [00:00<00:09, 104.53it/s]
# Epoch 71: train_acc_0.7679_train_loss_0.7538_val_acc_0.7681_val_loss_0.7519 epoch time 11.6952 seconds
# total time13.0 : 57.32269549369812
# loss: 0.8317, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 95.66it/s]
# loss: 0.8113, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 147.45it/s]
# loss: 0.6645, accuracy: 0.8200:   2%|▏         | 19/1000 [00:00<00:09, 100.16it/s]
# Epoch 72: train_acc_0.7675_train_loss_0.7513_val_acc_0.7690_val_loss_0.7516 epoch time 11.6661 seconds
# total time14.0 : 8.988746643066406
# loss: 0.8728, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 94.90it/s]
# loss: 0.8542, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 152.22it/s]
# loss: 0.7171, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 103.01it/s]
# Epoch 73: train_acc_0.7683_train_loss_0.7505_val_acc_0.7665_val_loss_0.7497 epoch time 11.7609 seconds
# total time14.0 : 20.749675035476685
# loss: 0.7391, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 95.17it/s]
# loss: 0.7695, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 149.40it/s]
# loss: 0.7991, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 104.03it/s]
# Epoch 74: train_acc_0.7690_train_loss_0.7491_val_acc_0.7674_val_loss_0.7469 epoch time 11.7066 seconds
# total time14.0 : 32.456297874450684
# loss: 0.7879, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 95.13it/s]
# loss: 0.8785, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 148.62it/s]
# loss: 0.8585, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 100.61it/s]
# Epoch 75: train_acc_0.7693_train_loss_0.7467_val_acc_0.7694_val_loss_0.7512 epoch time 11.7197 seconds
# total time14.0 : 44.17594838142395
# loss: 0.9940, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 96.98it/s]
# loss: 0.6632, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 148.20it/s]
# loss: 0.7174, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 104.36it/s]
# Epoch 76: train_acc_0.7698_train_loss_0.7454_val_acc_0.7717_val_loss_0.7471 epoch time 11.5184 seconds
# total time14.0 : 55.69430494308472
# loss: 0.8864, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 95.05it/s]
# loss: 0.6145, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.20it/s]
# loss: 0.5543, accuracy: 0.8100:   2%|▏         | 19/1000 [00:00<00:09, 103.79it/s]
# Epoch 77: train_acc_0.7690_train_loss_0.7442_val_acc_0.7701_val_loss_0.7427 epoch time 11.7305 seconds
# total time15.0 : 7.424806118011475
# loss: 0.7845, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 96.71it/s]
# loss: 0.7664, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.04it/s]
# loss: 0.6220, accuracy: 0.8000:   2%|▏         | 19/1000 [00:00<00:09, 101.40it/s]
# Epoch 78: train_acc_0.7709_train_loss_0.7430_val_acc_0.7689_val_loss_0.7478 epoch time 11.7344 seconds
# total time15.0 : 19.159217834472656
# loss: 0.7015, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 95.08it/s]
# loss: 0.7204, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 148.76it/s]
# loss: 0.5632, accuracy: 0.7700:   2%|▏         | 20/1000 [00:00<00:09, 105.88it/s]
# Epoch 79: train_acc_0.7701_train_loss_0.7418_val_acc_0.7704_val_loss_0.7410 epoch time 11.7214 seconds
# total time15.0 : 30.88056969642639
# loss: 0.7516, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 97.54it/s]
# loss: 0.8180, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 147.67it/s]
# loss: 0.6931, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 102.17it/s]
# Epoch 80: train_acc_0.7710_train_loss_0.7393_val_acc_0.7702_val_loss_0.7383 epoch time 11.7204 seconds
# total time15.0 : 42.60093927383423
# loss: 0.7156, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 95.73it/s]
# loss: 0.7712, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 149.29it/s]
# loss: 0.5585, accuracy: 0.8400:   2%|▏         | 20/1000 [00:00<00:09, 104.98it/s]
# Epoch 81: train_acc_0.7725_train_loss_0.7384_val_acc_0.7701_val_loss_0.7385 epoch time 11.6470 seconds
# total time15.0 : 54.24795937538147
# loss: 0.9151, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 95.25it/s]
# loss: 0.7275, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 145.45it/s]
# loss: 0.8162, accuracy: 0.7900:   2%|▏         | 20/1000 [00:00<00:09, 106.61it/s]
# Epoch 82: train_acc_0.7718_train_loss_0.7372_val_acc_0.7723_val_loss_0.7345 epoch time 11.7273 seconds
# total time16.0 : 5.97529149055481
# loss: 1.1469, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 96.59it/s]
# loss: 0.6447, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 156.86it/s]
# loss: 0.7775, accuracy: 0.7300:   2%|▏         | 21/1000 [00:00<00:09, 105.21it/s]
# Epoch 83: train_acc_0.7722_train_loss_0.7355_val_acc_0.7706_val_loss_0.7396 epoch time 11.5019 seconds
# total time16.0 : 17.47714352607727
# loss: 0.8225, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 99.61it/s]
# loss: 0.8064, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 150.14it/s]
# loss: 0.5843, accuracy: 0.8500:   2%|▏         | 19/1000 [00:00<00:09, 103.21it/s]
# Epoch 84: train_acc_0.7732_train_loss_0.7341_val_acc_0.7718_val_loss_0.7372 epoch time 11.2326 seconds
# total time16.0 : 28.709769010543823
# loss: 0.7757, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 95.50it/s]
# loss: 0.6333, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 149.04it/s]
# loss: 0.7127, accuracy: 0.8000:   2%|▏         | 20/1000 [00:00<00:09, 101.93it/s]
# Epoch 85: train_acc_0.7730_train_loss_0.7330_val_acc_0.7687_val_loss_0.7348 epoch time 11.6717 seconds
# total time16.0 : 40.38149952888489
# loss: 0.7385, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 97.18it/s]
# loss: 0.7434, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 149.37it/s]
# loss: 0.7287, accuracy: 0.7700:   2%|▏         | 20/1000 [00:00<00:09, 107.36it/s]
# Epoch 86: train_acc_0.7739_train_loss_0.7314_val_acc_0.7709_val_loss_0.7361 epoch time 11.4919 seconds
# total time16.0 : 51.87338900566101
# loss: 0.7607, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 95.68it/s]
# loss: 0.5528, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 148.75it/s]
# loss: 0.8731, accuracy: 0.7200:   2%|▏         | 20/1000 [00:00<00:09, 102.75it/s]
# Epoch 87: train_acc_0.7748_train_loss_0.7299_val_acc_0.7735_val_loss_0.7335 epoch time 11.6534 seconds
# total time17.0 : 3.5268046855926514
# loss: 0.6893, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 94.98it/s]
# loss: 0.6237, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 150.32it/s]
# loss: 0.6191, accuracy: 0.8200:   2%|▏         | 20/1000 [00:00<00:09, 105.61it/s]
# Epoch 88: train_acc_0.7747_train_loss_0.7285_val_acc_0.7734_val_loss_0.7288 epoch time 11.7193 seconds
# total time17.0 : 15.246073007583618
# loss: 0.8967, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.33it/s]
# loss: 0.7386, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 147.92it/s]
# loss: 0.6426, accuracy: 0.8100:   2%|▏         | 19/1000 [00:00<00:09, 106.96it/s]
# Epoch 89: train_acc_0.7753_train_loss_0.7273_val_acc_0.7744_val_loss_0.7270 epoch time 11.7021 seconds
# total time17.0 : 26.948215007781982
# loss: 0.5920, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 95.35it/s]
# loss: 0.5261, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 148.71it/s]
# loss: 0.6500, accuracy: 0.8200:   2%|▏         | 19/1000 [00:00<00:09, 103.11it/s]
# Epoch 90: train_acc_0.7758_train_loss_0.7262_val_acc_0.7766_val_loss_0.7239 epoch time 11.6920 seconds
# total time17.0 : 38.64016509056091
# loss: 0.8508, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.15it/s]
# loss: 0.7332, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 148.68it/s]
# loss: 0.7051, accuracy: 0.8100:   2%|▏         | 20/1000 [00:00<00:08, 111.66it/s]
# Epoch 91: train_acc_0.7759_train_loss_0.7245_val_acc_0.7739_val_loss_0.7231 epoch time 11.7156 seconds
# total time17.0 : 50.355725049972534
# loss: 0.8368, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 95.33it/s]
# loss: 0.7214, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 146.35it/s]
# loss: 0.7798, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 99.46it/s]
# Epoch 92: train_acc_0.7759_train_loss_0.7236_val_acc_0.7707_val_loss_0.7249 epoch time 11.7114 seconds
# total time18.0 : 2.067145586013794
# loss: 0.7409, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 94.86it/s]
# loss: 0.8188, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 148.34it/s]
# loss: 0.8418, accuracy: 0.7300:   2%|▏         | 20/1000 [00:00<00:08, 109.02it/s]
# Epoch 93: train_acc_0.7766_train_loss_0.7225_val_acc_0.7772_val_loss_0.7234 epoch time 11.7517 seconds
# total time18.0 : 13.818836450576782
# loss: 0.6793, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.54it/s]
# loss: 0.9860, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 157.49it/s]
# loss: 0.6988, accuracy: 0.8000:   2%|▏         | 21/1000 [00:00<00:08, 114.17it/s]
# Epoch 94: train_acc_0.7767_train_loss_0.7212_val_acc_0.7773_val_loss_0.7227 epoch time 11.6091 seconds
# total time18.0 : 25.427935361862183
# loss: 0.6314, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:10<00:00, 96.88it/s]
# loss: 1.0221, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 148.01it/s]
# loss: 0.8603, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 103.82it/s]
# Epoch 95: train_acc_0.7773_train_loss_0.7194_val_acc_0.7761_val_loss_0.7180 epoch time 11.5328 seconds
# total time18.0 : 36.96071434020996
# loss: 0.7114, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 95.62it/s]
# loss: 0.6281, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 151.38it/s]
# loss: 1.0151, accuracy: 0.6600:   2%|▏         | 19/1000 [00:00<00:09, 102.63it/s]
# Epoch 96: train_acc_0.7782_train_loss_0.7181_val_acc_0.7770_val_loss_0.7205 epoch time 11.6424 seconds
# total time18.0 : 48.603119134902954
# loss: 0.8277, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 95.18it/s]
# loss: 0.7405, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 148.08it/s]
# loss: 0.6809, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:09, 101.43it/s]
# Epoch 97: train_acc_0.7783_train_loss_0.7177_val_acc_0.7777_val_loss_0.7181 epoch time 11.7146 seconds
# total time19.0 : 0.3177645206451416
# loss: 0.6095, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 95.17it/s]
# loss: 0.9635, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 153.20it/s]
# loss: 0.6636, accuracy: 0.8000:   2%|▏         | 20/1000 [00:00<00:09, 104.01it/s]
# Epoch 98: train_acc_0.7770_train_loss_0.7167_val_acc_0.7751_val_loss_0.7229 epoch time 11.7270 seconds
# total time19.0 : 12.04477071762085
# loss: 0.6296, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:10<00:00, 95.44it/s]
# loss: 0.6377, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 148.50it/s]
# loss: 0.6891, accuracy: 0.7400:  19%|█▉        | 30/158 [00:00<00:00, 158.58it/s]
# Epoch 99: train_acc_0.7783_train_loss_0.7148_val_acc_0.7767_val_loss_0.7181 epoch time 11.6824 seconds
# total time19.0 : 23.727181911468506
# Generating test set evaluation metrics
# loss: 0.7674, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 153.19it/s]
# finish
# loss: 3.8407, accuracy: 0.0300:   1%|          | 6/1000 [00:00<00:14, 67.47it/s]
# stride2_filter32_layer2_type2
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 15, 15])
# torch.Size([100, 32, 15, 15])
# torch.Size([100, 32, 8, 8])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_max_pool_0): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_max_pool_1): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 1.2778, accuracy: 0.6500: 100%|██████████| 1000/1000 [00:12<00:00, 79.07it/s]
# loss: 1.1715, accuracy: 0.6600: 100%|██████████| 158/158 [00:01<00:00, 135.54it/s]
# loss: 1.2568, accuracy: 0.6200:   2%|▏         | 16/1000 [00:00<00:11, 83.68it/s]
# Epoch 0: train_acc_0.4622_train_loss_1.9449_val_acc_0.6636_val_loss_1.1241 epoch time 13.9670 seconds
# total time0.0 : 13.966974973678589
# loss: 1.1437, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:12<00:00, 80.10it/s]
# loss: 0.7097, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 139.11it/s]
# loss: 1.0032, accuracy: 0.6800:   2%|▏         | 16/1000 [00:00<00:11, 83.99it/s]
# Epoch 1: train_acc_0.6947_train_loss_1.0061_val_acc_0.7200_val_loss_0.9014 epoch time 13.7593 seconds
# total time0.0 : 27.726303577423096
# loss: 0.6458, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:12<00:00, 80.39it/s]
# loss: 0.8722, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 137.39it/s]
# loss: 0.9780, accuracy: 0.7100:   2%|▏         | 16/1000 [00:00<00:11, 85.11it/s]
# Epoch 2: train_acc_0.7373_train_loss_0.8557_val_acc_0.7544_val_loss_0.7985 epoch time 13.7274 seconds
# total time0.0 : 41.45369482040405
# loss: 0.7551, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:12<00:00, 81.00it/s]
# loss: 0.6059, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 135.58it/s]
# loss: 0.6636, accuracy: 0.8200:   2%|▏         | 16/1000 [00:00<00:11, 89.11it/s]
# Epoch 3: train_acc_0.7588_train_loss_0.7793_val_acc_0.7715_val_loss_0.7453 epoch time 13.6524 seconds
# total time0.0 : 55.106127977371216
# loss: 0.7635, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:12<00:00, 82.33it/s]
# loss: 0.6147, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 139.06it/s]
# loss: 0.6508, accuracy: 0.7700:   2%|▏         | 16/1000 [00:00<00:11, 83.20it/s]
# Epoch 4: train_acc_0.7723_train_loss_0.7268_val_acc_0.7781_val_loss_0.7089 epoch time 13.6512 seconds
# total time1.0 : 8.757342100143433
# loss: 0.6580, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:12<00:00, 80.75it/s]
# loss: 0.5788, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.52it/s]
# loss: 0.8787, accuracy: 0.7800:   2%|▏         | 16/1000 [00:00<00:11, 84.65it/s]
# Epoch 5: train_acc_0.7832_train_loss_0.6874_val_acc_0.7904_val_loss_0.6573 epoch time 13.5829 seconds
# total time1.0 : 22.340256452560425
# loss: 0.7194, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:12<00:00, 84.68it/s]
# loss: 0.5612, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 136.95it/s]
# loss: 0.5581, accuracy: 0.8200:   2%|▏         | 16/1000 [00:00<00:11, 85.88it/s]
# Epoch 6: train_acc_0.7930_train_loss_0.6548_val_acc_0.7960_val_loss_0.6405 epoch time 13.5562 seconds
# total time1.0 : 35.89643383026123
# loss: 0.5925, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 83.52it/s]
# loss: 0.6071, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 137.86it/s]
# loss: 0.8641, accuracy: 0.8000:   2%|▏         | 16/1000 [00:00<00:11, 87.15it/s]
# Epoch 7: train_acc_0.8012_train_loss_0.6296_val_acc_0.7978_val_loss_0.6224 epoch time 13.2547 seconds
# total time1.0 : 49.1511070728302
# loss: 1.0513, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:11<00:00, 93.96it/s]
# loss: 0.7767, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 149.86it/s]
# loss: 0.6438, accuracy: 0.8600:   2%|▏         | 18/1000 [00:00<00:10, 94.55it/s]
# Epoch 8: train_acc_0.8059_train_loss_0.6082_val_acc_0.8139_val_loss_0.5767 epoch time 13.0449 seconds
# total time2.0 : 2.1960012912750244
# loss: 0.7844, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 89.23it/s]
# loss: 0.6115, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 139.55it/s]
# loss: 0.5411, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:10, 92.62it/s]
# Epoch 9: train_acc_0.8113_train_loss_0.5893_val_acc_0.8143_val_loss_0.5808 epoch time 12.4785 seconds
# total time2.0 : 14.67452597618103
# loss: 0.4752, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:11<00:00, 84.90it/s]
# loss: 0.4459, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 138.77it/s]
# loss: 0.4301, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:10, 93.64it/s]
# Epoch 10: train_acc_0.8153_train_loss_0.5737_val_acc_0.8195_val_loss_0.5612 epoch time 13.0553 seconds
# total time2.0 : 27.729846715927124
# loss: 0.6613, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 84.48it/s]
# loss: 0.5839, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 137.60it/s]
# loss: 0.6439, accuracy: 0.7700:   2%|▏         | 17/1000 [00:00<00:10, 91.88it/s]
# Epoch 11: train_acc_0.8194_train_loss_0.5602_val_acc_0.8177_val_loss_0.5570 epoch time 13.1197 seconds
# total time2.0 : 40.84950375556946
# loss: 0.4506, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 84.08it/s]
# loss: 0.5288, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 137.82it/s]
# loss: 0.4288, accuracy: 0.8500:   2%|▏         | 17/1000 [00:00<00:11, 87.86it/s]
# Epoch 12: train_acc_0.8227_train_loss_0.5483_val_acc_0.8212_val_loss_0.5477 epoch time 13.1797 seconds
# total time2.0 : 54.029176235198975
# loss: 0.6462, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:11<00:00, 84.57it/s]
# loss: 0.5555, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 138.97it/s]
# loss: 0.7025, accuracy: 0.7600:   2%|▏         | 17/1000 [00:00<00:10, 91.08it/s]
# Epoch 13: train_acc_0.8271_train_loss_0.5356_val_acc_0.8235_val_loss_0.5347 epoch time 13.1023 seconds
# total time3.0 : 7.1315085887908936
# loss: 0.6672, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 83.94it/s]
# loss: 0.3284, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 148.29it/s]
# loss: 0.4868, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:11, 87.85it/s]
# Epoch 14: train_acc_0.8280_train_loss_0.5261_val_acc_0.8315_val_loss_0.5145 epoch time 13.1797 seconds
# total time3.0 : 20.311167001724243
# loss: 0.4741, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 84.32it/s]
# loss: 0.3904, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 139.81it/s]
# loss: 0.4132, accuracy: 0.8400:   2%|▏         | 17/1000 [00:00<00:10, 90.99it/s]
# Epoch 15: train_acc_0.8313_train_loss_0.5183_val_acc_0.8315_val_loss_0.5109 epoch time 13.1269 seconds
# total time3.0 : 33.43809652328491
# loss: 0.6797, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:11<00:00, 83.64it/s]
# loss: 0.6801, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 138.62it/s]
# loss: 0.4896, accuracy: 0.8300:   2%|▏         | 17/1000 [00:00<00:10, 89.93it/s]
# Epoch 16: train_acc_0.8322_train_loss_0.5116_val_acc_0.8326_val_loss_0.4996 epoch time 13.2354 seconds
# total time3.0 : 46.673516273498535
# loss: 0.3526, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 83.54it/s]
# loss: 0.4763, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 140.00it/s]
# loss: 0.5631, accuracy: 0.9000:   2%|▏         | 16/1000 [00:00<00:11, 87.40it/s]
# Epoch 17: train_acc_0.8351_train_loss_0.5030_val_acc_0.8227_val_loss_0.5109 epoch time 13.2410 seconds
# total time3.0 : 59.91451978683472
# loss: 0.3960, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 86.87it/s]
# loss: 0.4354, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 139.16it/s]
# loss: 0.4817, accuracy: 0.8900:   2%|▏         | 18/1000 [00:00<00:10, 94.86it/s]
# Epoch 18: train_acc_0.8369_train_loss_0.4963_val_acc_0.8353_val_loss_0.4931 epoch time 12.7815 seconds
# total time4.0 : 12.696030378341675
# ...
# loss: 0.4176, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 128.79it/s]
# loss: 0.2073, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:12, 77.95it/s]
# Epoch 59: train_acc_0.9224_train_loss_0.1933_val_acc_0.8743_val_loss_0.4090 epoch time 14.8524 seconds
# total time14.0 : 47.31991744041443
# loss: 0.2195, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:12<00:00, 74.42it/s]
# loss: 0.3474, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 128.90it/s]
# loss: 0.1127, accuracy: 0.9700:   1%|▏         | 14/1000 [00:00<00:12, 76.79it/s]
# Epoch 60: train_acc_0.9233_train_loss_0.1907_val_acc_0.8720_val_loss_0.4151 epoch time 14.4878 seconds
# total time15.0 : 1.807675838470459
# loss: 0.2105, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 74.42it/s]
# loss: 0.2763, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 129.21it/s]
# loss: 0.2269, accuracy: 0.8900:   2%|▏         | 15/1000 [00:00<00:12, 78.90it/s]
# Epoch 61: train_acc_0.9249_train_loss_0.1880_val_acc_0.8729_val_loss_0.4224 epoch time 14.7961 seconds
# total time15.0 : 16.603798627853394
# loss: 0.1714, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.34it/s]
# loss: 0.4243, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 129.85it/s]
# loss: 0.1841, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:13, 75.37it/s]
# Epoch 62: train_acc_0.9239_train_loss_0.1883_val_acc_0.8702_val_loss_0.4258 epoch time 14.8074 seconds
# total time15.0 : 31.411216020584106
# loss: 0.2209, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 75.67it/s]
# loss: 0.1874, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 130.80it/s]
# loss: 0.1490, accuracy: 0.9500:   2%|▏         | 15/1000 [00:00<00:12, 77.14it/s]
# Epoch 63: train_acc_0.9249_train_loss_0.1878_val_acc_0.8723_val_loss_0.4306 epoch time 14.8341 seconds
# total time15.0 : 46.245266914367676
# loss: 0.2511, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 74.16it/s]
# loss: 0.4689, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 128.79it/s]
# loss: 0.1191, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 78.39it/s]
# Epoch 64: train_acc_0.9265_train_loss_0.1841_val_acc_0.8722_val_loss_0.4287 epoch time 14.8535 seconds
# total time16.0 : 1.098733901977539
# loss: 0.2119, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 75.03it/s]
# loss: 0.3628, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 128.82it/s]
# loss: 0.2886, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:12, 76.04it/s]
# Epoch 65: train_acc_0.9260_train_loss_0.1834_val_acc_0.8741_val_loss_0.4308 epoch time 14.6924 seconds
# total time16.0 : 15.79117727279663
# loss: 0.2165, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 74.07it/s]
# loss: 0.2401, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 129.96it/s]
# loss: 0.2031, accuracy: 0.9500:   2%|▏         | 15/1000 [00:00<00:12, 78.68it/s]
# Epoch 66: train_acc_0.9269_train_loss_0.1829_val_acc_0.8720_val_loss_0.4303 epoch time 14.8524 seconds
# total time16.0 : 30.643609762191772
# loss: 0.2734, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 78.29it/s]
# loss: 0.4278, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 131.43it/s]
# loss: 0.2169, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 79.31it/s]
# Epoch 67: train_acc_0.9272_train_loss_0.1812_val_acc_0.8692_val_loss_0.4321 epoch time 14.7654 seconds
# total time16.0 : 45.409048080444336
# loss: 0.2009, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.76it/s]
# loss: 0.7524, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 129.44it/s]
# loss: 0.1656, accuracy: 0.9200:   2%|▏         | 15/1000 [00:00<00:12, 79.65it/s]
# Epoch 68: train_acc_0.9270_train_loss_0.1811_val_acc_0.8702_val_loss_0.4398 epoch time 14.7305 seconds
# total time17.0 : 0.13956212997436523
# loss: 0.2098, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 74.63it/s]
# loss: 0.5017, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.68it/s]
# loss: 0.2018, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:12, 77.80it/s]
# Epoch 69: train_acc_0.9275_train_loss_0.1807_val_acc_0.8691_val_loss_0.4411 epoch time 14.7247 seconds
# total time17.0 : 14.864310503005981
# loss: 0.1829, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 76.16it/s]
# loss: 0.4037, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 127.95it/s]
# loss: 0.0550, accuracy: 0.9900:   1%|▏         | 14/1000 [00:00<00:13, 75.71it/s]
# Epoch 70: train_acc_0.9282_train_loss_0.1774_val_acc_0.8727_val_loss_0.4373 epoch time 14.8785 seconds
# total time17.0 : 29.742857694625854
# loss: 0.0894, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 76.22it/s]
# loss: 0.7585, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.50it/s]
# loss: 0.1501, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:12, 78.24it/s]
# Epoch 71: train_acc_0.9289_train_loss_0.1763_val_acc_0.8714_val_loss_0.4456 epoch time 14.7404 seconds
# total time17.0 : 44.48326301574707
# loss: 0.2241, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 74.57it/s]
# loss: 0.4734, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 139.87it/s]
# loss: 0.1220, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 77.03it/s]
# Epoch 72: train_acc_0.9292_train_loss_0.1768_val_acc_0.8746_val_loss_0.4330 epoch time 14.7176 seconds
# total time17.0 : 59.20091199874878
# loss: 0.2871, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 75.34it/s]
# loss: 0.3748, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 130.71it/s]
# loss: 0.2127, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 77.45it/s]
# Epoch 73: train_acc_0.9298_train_loss_0.1745_val_acc_0.8692_val_loss_0.4497 epoch time 14.6204 seconds
# total time18.0 : 13.82126498222351
# loss: 0.1120, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 74.43it/s]
# loss: 0.4570, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 131.51it/s]
# loss: 0.2134, accuracy: 0.9100:   2%|▏         | 15/1000 [00:00<00:12, 77.07it/s]
# Epoch 74: train_acc_0.9298_train_loss_0.1737_val_acc_0.8681_val_loss_0.4514 epoch time 14.7744 seconds
# total time18.0 : 28.595666885375977
# loss: 0.1844, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 74.23it/s]
# loss: 0.4200, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 130.78it/s]
# loss: 0.0916, accuracy: 0.9600:   2%|▏         | 15/1000 [00:00<00:12, 77.55it/s]
# Epoch 75: train_acc_0.9308_train_loss_0.1731_val_acc_0.8679_val_loss_0.4644 epoch time 14.8196 seconds
# total time18.0 : 43.415305852890015
# loss: 0.1163, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 76.66it/s]
# loss: 0.7702, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 145.48it/s]
# loss: 0.1274, accuracy: 0.9800:   2%|▏         | 15/1000 [00:00<00:12, 81.51it/s]
# Epoch 76: train_acc_0.9301_train_loss_0.1721_val_acc_0.8686_val_loss_0.4674 epoch time 14.2653 seconds
# total time18.0 : 57.68062996864319
# loss: 0.1723, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 75.62it/s]
# loss: 0.4773, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 129.82it/s]
# loss: 0.1225, accuracy: 0.9700:   1%|▏         | 14/1000 [00:00<00:12, 75.92it/s]
# Epoch 77: train_acc_0.9309_train_loss_0.1699_val_acc_0.8718_val_loss_0.4633 epoch time 14.5791 seconds
# total time19.0 : 12.259746313095093
# loss: 0.1943, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 73.97it/s]
# loss: 0.1810, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 129.52it/s]
# loss: 0.1098, accuracy: 0.9700:   2%|▏         | 15/1000 [00:00<00:12, 76.82it/s]
# Epoch 78: train_acc_0.9318_train_loss_0.1690_val_acc_0.8709_val_loss_0.4670 epoch time 14.8783 seconds
# total time19.0 : 27.13807487487793
# loss: 0.1608, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 73.84it/s]
# loss: 0.5991, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 128.85it/s]
# loss: 0.1606, accuracy: 0.9300:   2%|▏         | 15/1000 [00:00<00:12, 78.84it/s]
# Epoch 79: train_acc_0.9319_train_loss_0.1684_val_acc_0.8727_val_loss_0.4716 epoch time 14.9086 seconds
# total time19.0 : 42.046643018722534
# loss: 0.1603, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.64it/s]
# loss: 0.3674, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 129.87it/s]
# loss: 0.1572, accuracy: 0.9500:   2%|▏         | 15/1000 [00:00<00:12, 81.10it/s]
# Epoch 80: train_acc_0.9324_train_loss_0.1676_val_acc_0.8700_val_loss_0.4692 epoch time 14.7523 seconds
# total time19.0 : 56.798903942108154
# loss: 0.1540, accuracy: 0.9700: 100%|██████████| 1000/1000 [00:12<00:00, 76.24it/s]
# loss: 0.2949, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 128.14it/s]
# loss: 0.0985, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 76.71it/s]
# Epoch 81: train_acc_0.9326_train_loss_0.1663_val_acc_0.8687_val_loss_0.4741 epoch time 14.3745 seconds
# total time20.0 : 11.17336630821228
# loss: 0.1075, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 73.78it/s]
# loss: 0.4316, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 129.27it/s]
# loss: 0.1274, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 77.31it/s]
# Epoch 82: train_acc_0.9328_train_loss_0.1664_val_acc_0.8673_val_loss_0.4895 epoch time 14.9147 seconds
# total time20.0 : 26.088059902191162
# loss: 0.1512, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 74.19it/s]
# loss: 0.4735, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 127.21it/s]
# loss: 0.1408, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 77.37it/s]
# Epoch 83: train_acc_0.9337_train_loss_0.1641_val_acc_0.8686_val_loss_0.4792 epoch time 14.8581 seconds
# total time20.0 : 40.94616770744324
# loss: 0.1203, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 75.89it/s]
# loss: 0.6472, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 129.67it/s]
# loss: 0.1516, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:12, 76.99it/s]
# Epoch 84: train_acc_0.9336_train_loss_0.1638_val_acc_0.8666_val_loss_0.4837 epoch time 14.9202 seconds
# total time20.0 : 55.86641502380371
# loss: 0.2645, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 75.21it/s]
# loss: 0.5312, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 129.11it/s]
# loss: 0.2195, accuracy: 0.9100:   2%|▏         | 15/1000 [00:00<00:12, 77.44it/s]
# Epoch 85: train_acc_0.9343_train_loss_0.1613_val_acc_0.8704_val_loss_0.4908 epoch time 14.9072 seconds
# total time21.0 : 10.773650169372559
# loss: 0.2717, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 73.85it/s]
# loss: 0.4120, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 127.15it/s]
# loss: 0.1186, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 76.80it/s]
# Epoch 86: train_acc_0.9341_train_loss_0.1614_val_acc_0.8659_val_loss_0.4900 epoch time 14.9226 seconds
# total time21.0 : 25.69622278213501
# loss: 0.1788, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:13<00:00, 73.86it/s]
# loss: 0.8155, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 132.54it/s]
# loss: 0.1016, accuracy: 0.9800:   1%|▏         | 14/1000 [00:00<00:12, 76.87it/s]
# Epoch 87: train_acc_0.9337_train_loss_0.1611_val_acc_0.8711_val_loss_0.4916 epoch time 14.8706 seconds
# total time21.0 : 40.566866397857666
# loss: 0.1792, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 73.64it/s]
# loss: 0.5681, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 130.46it/s]
# loss: 0.1043, accuracy: 0.9600:   2%|▏         | 15/1000 [00:00<00:12, 78.68it/s]
# Epoch 88: train_acc_0.9353_train_loss_0.1591_val_acc_0.8686_val_loss_0.4984 epoch time 14.8239 seconds
# total time21.0 : 55.390753507614136
# loss: 0.1459, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 74.12it/s]
# loss: 0.6861, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 130.31it/s]
# loss: 0.1932, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:12, 78.07it/s]
# Epoch 89: train_acc_0.9347_train_loss_0.1584_val_acc_0.8632_val_loss_0.5086 epoch time 14.8440 seconds
# total time22.0 : 10.234771728515625
# loss: 0.1717, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 74.22it/s]
# loss: 0.5975, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 128.14it/s]
# loss: 0.1675, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:12, 78.10it/s]
# Epoch 90: train_acc_0.9359_train_loss_0.1577_val_acc_0.8637_val_loss_0.5271 epoch time 14.8382 seconds
# total time22.0 : 25.072949409484863
# loss: 0.2144, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 74.81it/s]
# loss: 0.4911, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 128.86it/s]
# loss: 0.1297, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 76.33it/s]
# Epoch 91: train_acc_0.9352_train_loss_0.1575_val_acc_0.8670_val_loss_0.5109 epoch time 14.9079 seconds
# total time22.0 : 39.980870962142944
# loss: 0.1455, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.02it/s]
# loss: 0.2774, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 129.96it/s]
# loss: 0.1098, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:12, 81.08it/s]
# Epoch 92: train_acc_0.9350_train_loss_0.1582_val_acc_0.8682_val_loss_0.5108 epoch time 14.8672 seconds
# total time22.0 : 54.848029136657715
# loss: 0.1108, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 73.96it/s]
# loss: 0.3005, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 128.05it/s]
# loss: 0.1446, accuracy: 0.9600:   2%|▏         | 15/1000 [00:00<00:12, 79.79it/s]
# Epoch 93: train_acc_0.9360_train_loss_0.1559_val_acc_0.8637_val_loss_0.5172 epoch time 14.8941 seconds
# total time23.0 : 9.742176055908203
# loss: 0.0873, accuracy: 0.9600: 100%|██████████| 1000/1000 [00:13<00:00, 75.53it/s]
# loss: 0.5911, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 128.73it/s]
# loss: 0.1452, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 76.19it/s]
# Epoch 94: train_acc_0.9370_train_loss_0.1529_val_acc_0.8671_val_loss_0.5037 epoch time 14.8472 seconds
# total time23.0 : 24.58938193321228
# loss: 0.1638, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 75.47it/s]
# loss: 0.4761, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 128.61it/s]
# loss: 0.1586, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 77.70it/s]
# Epoch 95: train_acc_0.9382_train_loss_0.1518_val_acc_0.8647_val_loss_0.5384 epoch time 14.9332 seconds
# total time23.0 : 39.52258324623108
# loss: 0.1735, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 75.31it/s]
# loss: 0.6314, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 130.38it/s]
# loss: 0.1493, accuracy: 0.9300:   2%|▏         | 15/1000 [00:00<00:12, 77.82it/s]
# Epoch 96: train_acc_0.9365_train_loss_0.1556_val_acc_0.8662_val_loss_0.5389 epoch time 14.7746 seconds
# total time23.0 : 54.29717993736267
# loss: 0.2015, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 75.82it/s]
# loss: 0.4888, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 153.79it/s]
# loss: 0.2053, accuracy: 0.9300:   2%|▏         | 15/1000 [00:00<00:12, 81.67it/s]
# Epoch 97: train_acc_0.9372_train_loss_0.1524_val_acc_0.8689_val_loss_0.5233 epoch time 14.4768 seconds
# total time24.0 : 8.77401351928711
# loss: 0.1894, accuracy: 0.9500: 100%|██████████| 1000/1000 [00:13<00:00, 74.67it/s]
# loss: 0.6536, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 130.02it/s]
# loss: 0.1046, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 78.94it/s]
# Epoch 98: train_acc_0.9387_train_loss_0.1500_val_acc_0.8674_val_loss_0.5298 epoch time 14.7498 seconds
# total time24.0 : 23.52380347251892
# loss: 0.1966, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 73.82it/s]
# loss: 0.7211, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 128.36it/s]
# loss: 0.2608, accuracy: 0.8800:  16%|█▋        | 26/158 [00:00<00:00, 145.68it/s]
# Epoch 99: train_acc_0.9375_train_loss_0.1516_val_acc_0.8628_val_loss_0.5335 epoch time 14.9177 seconds
# total time24.0 : 38.44153070449829
# Generating test set evaluation metrics
# loss: 0.9446, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 127.81it/s]
# finish

# %%
#stride2_filter32_layer1234_type3

batch_size = 100
image_num_channels = 1
image_height = 28
image_width = 28
dim_reduction_idx = 3
dim_reduction_type = ['strided_convolution', 'dilated_convolution', 'max_pooling', 'avg_pooling']
num_filters = 32
num_layers = [1,2,3,4]
experiment_name = []
for layer in num_layers:
    experiment_name.append("stride2_filter32_layer{}_type{}".format(layer,dim_reduction_idx))
num_epochs = 100
weight_decay_coefficient = 1e-05
seed = 9112018
use_gpu = True

rng = np.random.RandomState(seed=seed)
train_data = data_providers.EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
val_data = data_providers.EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = data_providers.EMNISTDataProvider('test', batch_size=batch_size, rng=rng)

for experiment,layer in zip(experiment_name,num_layers):
    
    print(experiment)
    
    custom_conv_net = ConvolutionalNetwork(
        input_shape=(batch_size, image_num_channels, image_height, image_width),
        dim_reduction_type=dim_reduction_type[dim_reduction_idx],
        num_output_classes=47, num_filters=num_filters, num_layers=layer, use_bias=True)

    conv_experiment = ExperimentBuilder(network_model=custom_conv_net,
                                    experiment_name=experiment,
                                    num_epochs=num_epochs,
                                    weight_decay_coefficient=weight_decay_coefficient,
                                    use_gpu=use_gpu,
                                    train_data=train_data, val_data=val_data, test_data=test_data)
    print(custom_conv_net)
    total_losses = conv_experiment.run_experiment()
    print('finish')
    plot_stats_in_graph(total_losses[0])
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe409f5c1d0>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe407068198>)
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7fe409f5c1d0>)
# loss: 3.8517, accuracy: 0.0300:   2%|▏         | 18/1000 [00:00<00:08, 121.22it/s]
# stride2_filter32_layer1_type3
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 15, 15])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_avg_pool_0): AvgPool2d(kernel_size=2, stride=2, padding=1)
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 2.8158, accuracy: 0.2900: 100%|██████████| 1000/1000 [00:10<00:00, 95.09it/s]
# loss: 2.7877, accuracy: 0.2600: 100%|██████████| 158/158 [00:01<00:00, 152.75it/s]
# loss: 2.7325, accuracy: 0.1800:   2%|▏         | 19/1000 [00:00<00:09, 99.71it/s]
# Epoch 0: train_acc_0.1683_train_loss_3.1568_val_acc_0.2172_val_loss_2.8571 epoch time 11.7395 seconds
# total time0.0 : 11.73953104019165
# loss: 2.8016, accuracy: 0.2600: 100%|██████████| 1000/1000 [00:10<00:00, 99.16it/s]
# loss: 2.9409, accuracy: 0.2300: 100%|██████████| 158/158 [00:01<00:00, 152.94it/s]
# loss: 2.9255, accuracy: 0.2300:   2%|▏         | 20/1000 [00:00<00:09, 102.47it/s]
# Epoch 1: train_acc_0.2236_train_loss_2.8251_val_acc_0.2362_val_loss_2.7876 epoch time 11.9047 seconds
# total time0.0 : 23.644237279891968
# loss: 2.4544, accuracy: 0.2900: 100%|██████████| 1000/1000 [00:10<00:00, 94.01it/s]
# loss: 2.8220, accuracy: 0.2800: 100%|██████████| 158/158 [00:01<00:00, 149.48it/s]
# loss: 2.7194, accuracy: 0.2200:   2%|▏         | 18/1000 [00:00<00:10, 95.15it/s]
# Epoch 2: train_acc_0.2564_train_loss_2.7370_val_acc_0.2659_val_loss_2.6761 epoch time 11.8366 seconds
# total time0.0 : 35.48079752922058
# loss: 2.6871, accuracy: 0.2900: 100%|██████████| 1000/1000 [00:10<00:00, 92.26it/s]
# loss: 2.3648, accuracy: 0.3500: 100%|██████████| 158/158 [00:01<00:00, 149.37it/s]
# loss: 2.4638, accuracy: 0.3400:   2%|▏         | 20/1000 [00:00<00:09, 104.42it/s]
# Epoch 3: train_acc_0.3056_train_loss_2.5951_val_acc_0.3286_val_loss_2.5075 epoch time 12.0396 seconds
# total time0.0 : 47.520352602005005
# loss: 2.4692, accuracy: 0.4100: 100%|██████████| 1000/1000 [00:10<00:00, 92.20it/s]
# loss: 2.5879, accuracy: 0.3000: 100%|██████████| 158/158 [00:01<00:00, 154.26it/s]
# loss: 2.2524, accuracy: 0.4400:   2%|▏         | 19/1000 [00:00<00:09, 99.49it/s]
# Epoch 4: train_acc_0.3577_train_loss_2.4223_val_acc_0.3891_val_loss_2.3249 epoch time 12.0654 seconds
# total time0.0 : 59.58579421043396
# loss: 2.0361, accuracy: 0.4100: 100%|██████████| 1000/1000 [00:10<00:00, 92.76it/s]
# loss: 2.1691, accuracy: 0.4000: 100%|██████████| 158/158 [00:01<00:00, 145.05it/s]
# loss: 1.8553, accuracy: 0.5100:   2%|▏         | 19/1000 [00:00<00:09, 99.20it/s]
# Epoch 5: train_acc_0.4119_train_loss_2.2369_val_acc_0.4416_val_loss_2.1310 epoch time 12.0137 seconds
# total time1.0 : 11.599526643753052
# loss: 1.9576, accuracy: 0.5100: 100%|██████████| 1000/1000 [00:10<00:00, 91.71it/s]
# loss: 1.7576, accuracy: 0.5100: 100%|██████████| 158/158 [00:01<00:00, 147.33it/s]
# loss: 1.8912, accuracy: 0.4600:   2%|▏         | 20/1000 [00:00<00:09, 107.18it/s]
# Epoch 6: train_acc_0.4721_train_loss_2.0341_val_acc_0.5004_val_loss_1.9272 epoch time 12.1162 seconds
# total time1.0 : 23.7157199382782
# loss: 1.8990, accuracy: 0.5100: 100%|██████████| 1000/1000 [00:10<00:00, 94.37it/s]
# loss: 1.8564, accuracy: 0.5100: 100%|██████████| 158/158 [00:01<00:00, 145.62it/s]
# loss: 1.6197, accuracy: 0.5600:   2%|▏         | 19/1000 [00:00<00:09, 101.51it/s]
# Epoch 7: train_acc_0.5233_train_loss_1.8317_val_acc_0.5461_val_loss_1.7282 epoch time 11.8272 seconds
# total time1.0 : 35.54289770126343
# loss: 1.4247, accuracy: 0.5900: 100%|██████████| 1000/1000 [00:10<00:00, 91.96it/s]
# loss: 1.5292, accuracy: 0.6400: 100%|██████████| 158/158 [00:01<00:00, 150.56it/s]
# loss: 1.5946, accuracy: 0.5700:   2%|▏         | 19/1000 [00:00<00:09, 99.33it/s]
# Epoch 8: train_acc_0.5638_train_loss_1.6552_val_acc_0.5863_val_loss_1.5754 epoch time 12.1018 seconds
# total time1.0 : 47.644675731658936
# loss: 1.4372, accuracy: 0.5500: 100%|██████████| 1000/1000 [00:10<00:00, 92.89it/s]
# loss: 1.4372, accuracy: 0.6600: 100%|██████████| 158/158 [00:01<00:00, 146.37it/s]
# loss: 1.5386, accuracy: 0.5900:   2%|▏         | 18/1000 [00:00<00:10, 96.88it/s]
# Epoch 9: train_acc_0.5956_train_loss_1.5205_val_acc_0.6085_val_loss_1.4568 epoch time 11.9893 seconds
# total time1.0 : 59.63401198387146
# loss: 1.1710, accuracy: 0.6400: 100%|██████████| 1000/1000 [00:10<00:00, 92.36it/s]
# loss: 1.2945, accuracy: 0.6700: 100%|██████████| 158/158 [00:01<00:00, 146.89it/s]
# loss: 1.5662, accuracy: 0.5300:   2%|▏         | 18/1000 [00:00<00:10, 96.57it/s]
# Epoch 10: train_acc_0.6156_train_loss_1.4183_val_acc_0.6324_val_loss_1.3619 epoch time 12.0418 seconds
# total time2.0 : 11.675778865814209
# loss: 1.2478, accuracy: 0.6300: 100%|██████████| 1000/1000 [00:10<00:00, 93.72it/s]
# loss: 1.2914, accuracy: 0.6300: 100%|██████████| 158/158 [00:01<00:00, 152.90it/s]
# loss: 1.2260, accuracy: 0.6600:   2%|▏         | 19/1000 [00:00<00:09, 101.63it/s]
# Epoch 11: train_acc_0.6332_train_loss_1.3389_val_acc_0.6465_val_loss_1.2930 epoch time 11.8916 seconds
# total time2.0 : 23.567349672317505
# loss: 1.2475, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 93.67it/s]
# loss: 1.0965, accuracy: 0.6700: 100%|██████████| 158/158 [00:01<00:00, 145.21it/s]
# loss: 1.0882, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 99.15it/s]
# Epoch 12: train_acc_0.6469_train_loss_1.2748_val_acc_0.6595_val_loss_1.2344 epoch time 11.9034 seconds
# total time2.0 : 35.47076678276062
# loss: 1.0681, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 93.82it/s]
# loss: 1.0400, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 150.59it/s]
# loss: 1.0883, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 99.84it/s]
# Epoch 13: train_acc_0.6586_train_loss_1.2213_val_acc_0.6742_val_loss_1.1805 epoch time 11.8507 seconds
# total time2.0 : 47.32143521308899
# loss: 1.0695, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 94.04it/s]
# loss: 1.3240, accuracy: 0.6700: 100%|██████████| 158/158 [00:01<00:00, 150.96it/s]
# loss: 1.1560, accuracy: 0.6400:   2%|▏         | 19/1000 [00:00<00:09, 103.12it/s]
# Epoch 14: train_acc_0.6670_train_loss_1.1770_val_acc_0.6784_val_loss_1.1414 epoch time 11.8183 seconds
# total time2.0 : 59.139686822891235
# loss: 1.0414, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 94.49it/s]
# loss: 1.0354, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 151.44it/s]
# loss: 1.1110, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 102.21it/s]
# Epoch 15: train_acc_0.6761_train_loss_1.1394_val_acc_0.6847_val_loss_1.1072 epoch time 11.7661 seconds
# total time3.0 : 10.905747175216675
# loss: 1.2287, accuracy: 0.6600: 100%|██████████| 1000/1000 [00:10<00:00, 94.42it/s]
# loss: 1.1592, accuracy: 0.6500: 100%|██████████| 158/158 [00:01<00:00, 151.18it/s]
# loss: 0.9797, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 100.12it/s]
# Epoch 16: train_acc_0.6825_train_loss_1.1067_val_acc_0.6937_val_loss_1.0782 epoch time 11.7741 seconds
# total time3.0 : 22.679814100265503
# loss: 0.9513, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 96.76it/s]
# loss: 1.2987, accuracy: 0.5900: 100%|██████████| 158/158 [00:01<00:00, 153.39it/s]
# loss: 1.2296, accuracy: 0.6600:   2%|▏         | 19/1000 [00:00<00:09, 101.02it/s]
# Epoch 17: train_acc_0.6879_train_loss_1.0783_val_acc_0.6959_val_loss_1.0550 epoch time 11.5031 seconds
# total time3.0 : 34.182920694351196
# loss: 0.9540, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 94.36it/s]
# loss: 0.9644, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 153.70it/s]
# loss: 0.9870, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 100.01it/s]
# Epoch 18: train_acc_0.6944_train_loss_1.0535_val_acc_0.7042_val_loss_1.0222 epoch time 11.7642 seconds
# total time3.0 : 45.94711208343506
# loss: 0.9305, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 94.26it/s]
# loss: 0.9114, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 149.93it/s]
# loss: 0.8626, accuracy: 0.7200:   2%|▏         | 19/1000 [00:00<00:09, 101.79it/s]
# Epoch 19: train_acc_0.6979_train_loss_1.0335_val_acc_0.6994_val_loss_1.0121 epoch time 11.8027 seconds
# total time3.0 : 57.7498140335083
# loss: 1.1467, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 94.42it/s]
# loss: 0.8631, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 150.39it/s]
# loss: 1.0449, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 101.35it/s]
# Epoch 20: train_acc_0.7016_train_loss_1.0154_val_acc_0.7099_val_loss_0.9905 epoch time 11.7818 seconds
# total time4.0 : 9.5315842628479
# loss: 0.8079, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 94.07it/s]
# loss: 0.8716, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 149.05it/s]
# loss: 1.0888, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 99.88it/s]
# Epoch 21: train_acc_0.7049_train_loss_0.9993_val_acc_0.7118_val_loss_0.9774 epoch time 11.8298 seconds
# total time4.0 : 21.36138415336609
# loss: 1.0523, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 93.55it/s]
# loss: 0.9509, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 155.92it/s]
# loss: 1.0622, accuracy: 0.6900:   2%|▏         | 20/1000 [00:00<00:09, 105.75it/s]
# Epoch 22: train_acc_0.7100_train_loss_0.9839_val_acc_0.7159_val_loss_0.9634 epoch time 11.8411 seconds
# total time4.0 : 33.20248603820801
# loss: 0.9739, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 97.11it/s]
# loss: 0.9700, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 150.65it/s]
# loss: 1.0350, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 100.93it/s]
# Epoch 23: train_acc_0.7117_train_loss_0.9730_val_acc_0.7173_val_loss_0.9502 epoch time 11.4860 seconds
# total time4.0 : 44.688467264175415
# loss: 1.3326, accuracy: 0.6600: 100%|██████████| 1000/1000 [00:10<00:00, 93.30it/s]
# loss: 0.7623, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 148.89it/s]
# loss: 0.9366, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 99.19it/s]
# Epoch 24: train_acc_0.7137_train_loss_0.9607_val_acc_0.7201_val_loss_0.9458 epoch time 11.9211 seconds
# total time4.0 : 56.609519481658936
# loss: 0.9011, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 93.18it/s]
# loss: 0.9490, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 146.81it/s]
# loss: 1.2239, accuracy: 0.6500:   2%|▏         | 19/1000 [00:00<00:10, 97.95it/s]
# Epoch 25: train_acc_0.7164_train_loss_0.9507_val_acc_0.7201_val_loss_0.9333 epoch time 11.9502 seconds
# total time5.0 : 8.559725046157837
# loss: 0.9833, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 93.79it/s]
# loss: 0.9120, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 145.39it/s]
# loss: 0.8495, accuracy: 0.7600:   2%|▏         | 20/1000 [00:00<00:09, 106.17it/s]
# Epoch 26: train_acc_0.7179_train_loss_0.9431_val_acc_0.7195_val_loss_0.9242 epoch time 11.8947 seconds
# total time5.0 : 20.454398155212402
# loss: 0.9500, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 96.23it/s]
# loss: 0.8409, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 151.61it/s]
# loss: 0.9461, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 98.79it/s]
# Epoch 27: train_acc_0.7201_train_loss_0.9339_val_acc_0.7222_val_loss_0.9224 epoch time 11.5749 seconds
# total time5.0 : 32.02929663658142
# loss: 0.9979, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 92.84it/s]
# loss: 0.8565, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 143.55it/s]
# loss: 0.6743, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 104.39it/s]
# Epoch 28: train_acc_0.7214_train_loss_0.9270_val_acc_0.7251_val_loss_0.9109 epoch time 12.0116 seconds
# total time5.0 : 44.04086995124817
# loss: 1.0760, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 93.58it/s]
# loss: 0.7894, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 146.96it/s]
# loss: 0.9318, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 104.61it/s]
# Epoch 29: train_acc_0.7233_train_loss_0.9199_val_acc_0.7244_val_loss_0.9054 epoch time 11.9091 seconds
# total time5.0 : 55.949989318847656
# loss: 0.7034, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 93.00it/s]
# loss: 0.7778, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 148.85it/s]
# loss: 0.9657, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 100.78it/s]
# Epoch 30: train_acc_0.7257_train_loss_0.9128_val_acc_0.7275_val_loss_0.9081 epoch time 11.9573 seconds
# total time6.0 : 7.907299280166626
# loss: 0.8725, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 93.76it/s]
# loss: 0.7140, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 153.62it/s]
# loss: 0.9826, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 99.47it/s]
# Epoch 31: train_acc_0.7267_train_loss_0.9074_val_acc_0.7323_val_loss_0.8917 epoch time 11.8733 seconds
# total time6.0 : 19.780550241470337
# loss: 1.0425, accuracy: 0.6500: 100%|██████████| 1000/1000 [00:10<00:00, 94.07it/s]
# loss: 0.9199, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 152.91it/s]
# loss: 0.8937, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 101.84it/s]
# Epoch 32: train_acc_0.7275_train_loss_0.9016_val_acc_0.7339_val_loss_0.8828 epoch time 11.8421 seconds
# total time6.0 : 31.6226327419281
# loss: 0.9771, accuracy: 0.6500: 100%|██████████| 1000/1000 [00:10<00:00, 93.53it/s]
# loss: 0.8409, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 147.84it/s]
# loss: 0.9698, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 101.45it/s]
# Epoch 33: train_acc_0.7293_train_loss_0.8971_val_acc_0.7334_val_loss_0.8817 epoch time 11.8987 seconds
# total time6.0 : 43.52129530906677
# loss: 0.9967, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 93.34it/s]
# loss: 0.9753, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 148.56it/s]
# loss: 0.8881, accuracy: 0.6500:   2%|▏         | 19/1000 [00:00<00:10, 96.09it/s]
# Epoch 34: train_acc_0.7301_train_loss_0.8920_val_acc_0.7326_val_loss_0.8830 epoch time 11.9190 seconds
# total time6.0 : 55.4402916431427
# loss: 1.2067, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 93.26it/s]
# loss: 0.8783, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 147.76it/s]
# loss: 0.8403, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 102.02it/s]
# Epoch 35: train_acc_0.7321_train_loss_0.8881_val_acc_0.7334_val_loss_0.8715 epoch time 11.9324 seconds
# total time7.0 : 7.372711896896362
# loss: 0.9420, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 92.97it/s]
# loss: 0.8653, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 145.17it/s]
# loss: 0.8751, accuracy: 0.7600:   2%|▏         | 18/1000 [00:00<00:10, 96.78it/s]
# Epoch 36: train_acc_0.7320_train_loss_0.8846_val_acc_0.7363_val_loss_0.8716 epoch time 11.9892 seconds
# total time7.0 : 19.361886501312256
# loss: 0.9755, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 94.94it/s]
# loss: 0.6488, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 149.05it/s]
# loss: 0.9872, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 101.89it/s]
# Epoch 37: train_acc_0.7331_train_loss_0.8808_val_acc_0.7363_val_loss_0.8686 epoch time 11.7331 seconds
# total time7.0 : 31.094960689544678
# loss: 0.7224, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 93.14it/s]
# loss: 0.7695, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 147.99it/s]
# loss: 0.9708, accuracy: 0.7000:   2%|▏         | 18/1000 [00:00<00:10, 97.40it/s]
# Epoch 38: train_acc_0.7348_train_loss_0.8765_val_acc_0.7409_val_loss_0.8599 epoch time 11.9457 seconds
# total time7.0 : 43.040635108947754
# loss: 0.7913, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 92.90it/s]
# loss: 1.0465, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 144.66it/s]
# loss: 0.8438, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 101.96it/s]
# Epoch 39: train_acc_0.7360_train_loss_0.8731_val_acc_0.7356_val_loss_0.8626 epoch time 12.0005 seconds
# total time7.0 : 55.04110860824585
# loss: 0.6946, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 93.09it/s]
# loss: 0.8172, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 154.13it/s]
# loss: 0.7025, accuracy: 0.8100:   2%|▏         | 18/1000 [00:00<00:09, 98.65it/s]
# Epoch 40: train_acc_0.7369_train_loss_0.8693_val_acc_0.7354_val_loss_0.8584 epoch time 11.9615 seconds
# total time8.0 : 7.002564191818237
# loss: 0.8019, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 92.41it/s]
# loss: 0.7604, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 146.89it/s]
# loss: 0.6366, accuracy: 0.8200:   2%|▏         | 19/1000 [00:00<00:09, 99.18it/s]
# Epoch 41: train_acc_0.7378_train_loss_0.8658_val_acc_0.7373_val_loss_0.8580 epoch time 12.0412 seconds
# total time8.0 : 19.04373025894165
# loss: 0.5389, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:10<00:00, 91.97it/s]
# loss: 0.9219, accuracy: 0.6900: 100%|██████████| 158/158 [00:01<00:00, 148.20it/s]
# loss: 0.7349, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 100.48it/s]
# Epoch 42: train_acc_0.7382_train_loss_0.8644_val_acc_0.7403_val_loss_0.8490 epoch time 12.0794 seconds
# total time8.0 : 31.123131036758423
# loss: 0.7698, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 92.74it/s]
# loss: 0.9826, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 146.77it/s]
# loss: 1.0049, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 99.65it/s]
# Epoch 43: train_acc_0.7385_train_loss_0.8614_val_acc_0.7392_val_loss_0.8506 epoch time 12.0028 seconds
# total time8.0 : 43.1259560585022
# loss: 0.7105, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 92.87it/s]
# loss: 0.7561, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 154.72it/s]
# loss: 0.8874, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 99.83it/s]
# Epoch 44: train_acc_0.7395_train_loss_0.8581_val_acc_0.7385_val_loss_0.8494 epoch time 11.9879 seconds
# total time8.0 : 55.11387228965759
# loss: 0.9315, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 92.16it/s]
# loss: 0.8370, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 152.56it/s]
# loss: 0.8165, accuracy: 0.7200:   2%|▏         | 19/1000 [00:00<00:09, 103.04it/s]
# Epoch 45: train_acc_0.7398_train_loss_0.8545_val_acc_0.7418_val_loss_0.8420 epoch time 12.0690 seconds
# total time9.0 : 7.182862758636475
# loss: 1.0549, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 92.44it/s]
# loss: 0.7784, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 144.99it/s]
# loss: 0.8583, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 99.71it/s]
# Epoch 46: train_acc_0.7412_train_loss_0.8539_val_acc_0.7424_val_loss_0.8423 epoch time 12.0481 seconds
# total time9.0 : 19.230980396270752
# loss: 0.9032, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 93.74it/s]
# loss: 0.9064, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 147.81it/s]
# loss: 0.8615, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 103.06it/s]
# Epoch 47: train_acc_0.7425_train_loss_0.8516_val_acc_0.7446_val_loss_0.8380 epoch time 11.8779 seconds
# total time9.0 : 31.10892367362976
# loss: 0.6569, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 101.58it/s]
# loss: 0.8041, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 150.64it/s]
# loss: 0.8026, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:09, 101.16it/s]
# Epoch 48: train_acc_0.7415_train_loss_0.8485_val_acc_0.7442_val_loss_0.8371 epoch time 11.9150 seconds
# total time9.0 : 43.02390456199646
# loss: 0.9497, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 93.24it/s]
# loss: 1.1391, accuracy: 0.6700: 100%|██████████| 158/158 [00:01<00:00, 148.08it/s]
# loss: 0.8430, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 99.77it/s]
# Epoch 49: train_acc_0.7431_train_loss_0.8465_val_acc_0.7447_val_loss_0.8384 epoch time 11.6677 seconds
# total time9.0 : 54.691654443740845
# loss: 0.9436, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 93.20it/s]
# loss: 0.7259, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 148.43it/s]
# loss: 0.8937, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 99.64it/s]
# Epoch 50: train_acc_0.7417_train_loss_0.8443_val_acc_0.7484_val_loss_0.8302 epoch time 11.9296 seconds
# total time10.0 : 6.621213436126709
# loss: 0.6521, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 93.44it/s]
# loss: 0.8264, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 143.93it/s]
# loss: 1.0754, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:10, 97.84it/s]
# Epoch 51: train_acc_0.7430_train_loss_0.8420_val_acc_0.7415_val_loss_0.8374 epoch time 11.9409 seconds
# total time10.0 : 18.562137126922607
# loss: 0.7456, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 92.87it/s]
# loss: 0.7387, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 151.72it/s]
# loss: 0.6846, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 101.20it/s]
# Epoch 52: train_acc_0.7439_train_loss_0.8405_val_acc_0.7436_val_loss_0.8327 epoch time 11.9491 seconds
# total time10.0 : 30.511258602142334
# loss: 0.6612, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 95.71it/s]
# loss: 0.8137, accuracy: 0.6600: 100%|██████████| 158/158 [00:01<00:00, 146.14it/s]
# loss: 1.1610, accuracy: 0.6500:   2%|▏         | 19/1000 [00:00<00:09, 98.83it/s]
# Epoch 53: train_acc_0.7455_train_loss_0.8381_val_acc_0.7431_val_loss_0.8304 epoch time 11.6738 seconds
# total time10.0 : 42.185094594955444
# loss: 0.8803, accuracy: 0.6800: 100%|██████████| 1000/1000 [00:10<00:00, 92.78it/s]
# loss: 0.6842, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 146.84it/s]
# loss: 0.7811, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 98.50it/s]
# Epoch 54: train_acc_0.7451_train_loss_0.8365_val_acc_0.7495_val_loss_0.8223 epoch time 11.9989 seconds
# total time10.0 : 54.183971643447876
# loss: 0.9292, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 92.82it/s]
# loss: 0.9984, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 149.90it/s]
# loss: 0.9285, accuracy: 0.7200:   2%|▏         | 18/1000 [00:00<00:09, 98.26it/s]
# Epoch 55: train_acc_0.7463_train_loss_0.8345_val_acc_0.7477_val_loss_0.8221 epoch time 11.9720 seconds
# total time11.0 : 6.156006336212158
# loss: 0.9146, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 92.32it/s]
# loss: 0.7699, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 145.85it/s]
# loss: 1.0398, accuracy: 0.6700:   2%|▏         | 18/1000 [00:00<00:10, 97.14it/s]
# Epoch 56: train_acc_0.7469_train_loss_0.8328_val_acc_0.7489_val_loss_0.8201 epoch time 12.0595 seconds
# total time11.0 : 18.21547245979309
# loss: 0.9473, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 94.09it/s]
# loss: 0.7460, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 145.74it/s]
# loss: 0.8788, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 102.18it/s]
# Epoch 57: train_acc_0.7458_train_loss_0.8309_val_acc_0.7453_val_loss_0.8231 epoch time 11.8537 seconds
# total time11.0 : 30.06919240951538
# loss: 0.7924, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 92.60it/s]
# loss: 0.9260, accuracy: 0.7200: 100%|██████████| 158/158 [00:01<00:00, 145.65it/s]
# loss: 0.9471, accuracy: 0.6900:   2%|▏         | 19/1000 [00:00<00:09, 98.24it/s]
# Epoch 58: train_acc_0.7470_train_loss_0.8296_val_acc_0.7422_val_loss_0.8215 epoch time 12.0250 seconds
# total time11.0 : 42.094176054000854
# loss: 0.8408, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 93.05it/s]
# loss: 0.7883, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 147.14it/s]
# loss: 0.8954, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:10, 98.03it/s]
# Epoch 59: train_acc_0.7473_train_loss_0.8274_val_acc_0.7497_val_loss_0.8157 epoch time 11.9601 seconds
# total time11.0 : 54.05431604385376
# loss: 1.0958, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 92.50it/s]
# loss: 0.7203, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 147.65it/s]
# loss: 0.9441, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 98.37it/s]
# Epoch 60: train_acc_0.7480_train_loss_0.8264_val_acc_0.7462_val_loss_0.8232 epoch time 12.0187 seconds
# total time12.0 : 6.072969675064087
# loss: 0.7407, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 93.66it/s]
# loss: 0.8984, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.63it/s]
# loss: 0.6364, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:09, 99.29it/s]
# Epoch 61: train_acc_0.7485_train_loss_0.8249_val_acc_0.7489_val_loss_0.8176 epoch time 11.8800 seconds
# total time12.0 : 17.95297360420227
# loss: 0.9850, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 92.36it/s]
# loss: 0.5869, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 147.44it/s]
# loss: 0.6905, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 99.60it/s]
# Epoch 62: train_acc_0.7489_train_loss_0.8231_val_acc_0.7481_val_loss_0.8142 epoch time 12.0407 seconds
# total time12.0 : 29.99367594718933
# loss: 1.2450, accuracy: 0.6300: 100%|██████████| 1000/1000 [00:10<00:00, 93.04it/s]
# loss: 0.8841, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 148.85it/s]
# loss: 0.7928, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 100.82it/s]
# Epoch 63: train_acc_0.7498_train_loss_0.8207_val_acc_0.7462_val_loss_0.8135 epoch time 11.9484 seconds
# total time12.0 : 41.94207262992859
# loss: 0.8484, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 97.04it/s]
# loss: 0.6851, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 150.09it/s]
# loss: 0.7681, accuracy: 0.7600:   2%|▏         | 18/1000 [00:00<00:09, 98.64it/s]
# Epoch 64: train_acc_0.7509_train_loss_0.8199_val_acc_0.7475_val_loss_0.8147 epoch time 11.7961 seconds
# total time12.0 : 53.73812675476074
# loss: 0.9153, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 94.19it/s]
# loss: 0.8001, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 149.53it/s]
# loss: 0.7647, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:10, 97.57it/s]
# Epoch 65: train_acc_0.7515_train_loss_0.8184_val_acc_0.7518_val_loss_0.8136 epoch time 11.8118 seconds
# total time13.0 : 5.549971580505371
# loss: 0.9782, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 93.25it/s]
# loss: 0.7636, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 146.10it/s]
# loss: 0.5756, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 100.41it/s]
# Epoch 66: train_acc_0.7507_train_loss_0.8174_val_acc_0.7537_val_loss_0.8048 epoch time 11.9481 seconds
# total time13.0 : 17.49804711341858
# loss: 0.8467, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 95.44it/s]
# loss: 0.8052, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 150.82it/s]
# loss: 0.8827, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.87it/s]
# Epoch 67: train_acc_0.7502_train_loss_0.8162_val_acc_0.7511_val_loss_0.8082 epoch time 11.6987 seconds
# total time13.0 : 29.196768045425415
# loss: 0.9298, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 93.66it/s]
# loss: 0.7567, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 152.43it/s]
# loss: 0.7140, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:10, 98.04it/s]
# Epoch 68: train_acc_0.7501_train_loss_0.8151_val_acc_0.7523_val_loss_0.8080 epoch time 11.8939 seconds
# total time13.0 : 41.090715646743774
# loss: 0.8495, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 93.80it/s]
# loss: 0.7469, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 150.95it/s]
# loss: 0.6793, accuracy: 0.8200:   2%|▏         | 18/1000 [00:00<00:09, 98.86it/s]
# Epoch 69: train_acc_0.7513_train_loss_0.8134_val_acc_0.7513_val_loss_0.8039 epoch time 11.8498 seconds
# total time13.0 : 52.94052028656006
# loss: 1.0312, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 93.17it/s]
# loss: 0.7002, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 148.01it/s]
# loss: 0.9314, accuracy: 0.7400:   2%|▏         | 19/1000 [00:00<00:09, 100.84it/s]
# Epoch 70: train_acc_0.7526_train_loss_0.8115_val_acc_0.7543_val_loss_0.7985 epoch time 11.9400 seconds
# total time14.0 : 4.880545616149902
# loss: 0.7695, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:10<00:00, 93.13it/s]
# loss: 0.9568, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 148.55it/s]
# loss: 0.7098, accuracy: 0.8500:   2%|▏         | 18/1000 [00:00<00:10, 97.56it/s]
# Epoch 71: train_acc_0.7531_train_loss_0.8103_val_acc_0.7551_val_loss_0.7975 epoch time 11.9463 seconds
# total time14.0 : 16.82682180404663
# loss: 0.8814, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 92.82it/s]
# loss: 0.8051, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 143.79it/s]
# loss: 0.9780, accuracy: 0.7400:   2%|▏         | 18/1000 [00:00<00:10, 94.80it/s]
# Epoch 72: train_acc_0.7534_train_loss_0.8081_val_acc_0.7552_val_loss_0.8012 epoch time 12.0148 seconds
# total time14.0 : 28.84160304069519
# loss: 0.9601, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 92.75it/s]
# loss: 0.8592, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.15it/s]
# loss: 0.7360, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:09, 101.56it/s]
# Epoch 73: train_acc_0.7524_train_loss_0.8077_val_acc_0.7504_val_loss_0.7984 epoch time 11.9928 seconds
# total time14.0 : 40.83436918258667
# loss: 0.7582, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 93.72it/s]
# loss: 0.8041, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 154.76it/s]
# loss: 0.8318, accuracy: 0.7100:   2%|▏         | 19/1000 [00:00<00:09, 99.93it/s]
# Epoch 74: train_acc_0.7540_train_loss_0.8066_val_acc_0.7548_val_loss_0.7944 epoch time 11.8311 seconds
# total time14.0 : 52.66550970077515
# loss: 0.8725, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 97.22it/s]
# loss: 1.0208, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 148.98it/s]
# loss: 0.9350, accuracy: 0.7300:   2%|▏         | 18/1000 [00:00<00:10, 93.99it/s]
# Epoch 75: train_acc_0.7542_train_loss_0.8041_val_acc_0.7549_val_loss_0.8005 epoch time 11.4913 seconds
# total time15.0 : 4.156797647476196
# loss: 1.0219, accuracy: 0.6700: 100%|██████████| 1000/1000 [00:10<00:00, 92.75it/s]
# loss: 0.6638, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 154.38it/s]
# loss: 0.8374, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 100.70it/s]
# Epoch 76: train_acc_0.7550_train_loss_0.8030_val_acc_0.7578_val_loss_0.7973 epoch time 11.9924 seconds
# total time15.0 : 16.14918327331543
# loss: 0.9156, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 93.16it/s]
# loss: 0.6959, accuracy: 0.7300: 100%|██████████| 158/158 [00:00<00:00, 168.18it/s]
# loss: 0.5958, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 99.31it/s]
# Epoch 77: train_acc_0.7539_train_loss_0.8025_val_acc_0.7557_val_loss_0.7940 epoch time 11.9195 seconds
# total time15.0 : 28.068689584732056
# loss: 0.8472, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 98.55it/s]
# loss: 0.8622, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 154.53it/s]
# loss: 0.7053, accuracy: 0.7900:   2%|▏         | 19/1000 [00:00<00:09, 101.69it/s]
# Epoch 78: train_acc_0.7549_train_loss_0.8011_val_acc_0.7544_val_loss_0.7968 epoch time 11.8813 seconds
# total time15.0 : 39.9499614238739
# loss: 0.7739, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 93.86it/s]
# loss: 0.7835, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 147.27it/s]
# loss: 0.8690, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 103.87it/s]
# Epoch 79: train_acc_0.7553_train_loss_0.8002_val_acc_0.7569_val_loss_0.7896 epoch time 11.8708 seconds
# total time15.0 : 51.8207733631134
# loss: 0.7886, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:10<00:00, 92.50it/s]
# loss: 0.9096, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 145.59it/s]
# loss: 0.7304, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 98.11it/s]
# Epoch 80: train_acc_0.7571_train_loss_0.7977_val_acc_0.7583_val_loss_0.7887 epoch time 12.0406 seconds
# total time16.0 : 3.8613967895507812
# loss: 0.8048, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 92.11it/s]
# loss: 0.7493, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 148.43it/s]
# loss: 0.6075, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:09, 102.80it/s]
# Epoch 81: train_acc_0.7569_train_loss_0.7969_val_acc_0.7554_val_loss_0.7906 epoch time 12.0639 seconds
# total time16.0 : 15.925306558609009
# loss: 1.0083, accuracy: 0.6900: 100%|██████████| 1000/1000 [00:10<00:00, 93.24it/s]
# loss: 0.7640, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 148.93it/s]
# loss: 0.7760, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 98.22it/s]
# Epoch 82: train_acc_0.7568_train_loss_0.7960_val_acc_0.7605_val_loss_0.7838 epoch time 11.9313 seconds
# total time16.0 : 27.856582641601562
# loss: 1.1080, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 92.77it/s]
# loss: 0.7353, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 147.46it/s]
# loss: 0.6669, accuracy: 0.8300:   2%|▏         | 19/1000 [00:00<00:09, 102.49it/s]
# Epoch 83: train_acc_0.7570_train_loss_0.7945_val_acc_0.7604_val_loss_0.7898 epoch time 11.9937 seconds
# total time16.0 : 39.850279808044434
# loss: 0.8852, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:10<00:00, 92.87it/s]
# loss: 0.8748, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 147.04it/s]
# loss: 0.6321, accuracy: 0.7300:   2%|▏         | 18/1000 [00:00<00:09, 98.39it/s]
# Epoch 84: train_acc_0.7577_train_loss_0.7938_val_acc_0.7587_val_loss_0.7868 epoch time 11.9855 seconds
# total time16.0 : 51.83574604988098
# loss: 0.8334, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 92.24it/s]
# loss: 0.6557, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 146.02it/s]
# loss: 0.8886, accuracy: 0.7500:   2%|▏         | 18/1000 [00:00<00:09, 98.53it/s]
# Epoch 85: train_acc_0.7576_train_loss_0.7923_val_acc_0.7557_val_loss_0.7844 epoch time 12.0682 seconds
# total time17.0 : 3.9039113521575928
# loss: 0.7710, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 92.51it/s]
# loss: 0.8285, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 152.29it/s]
# loss: 0.8435, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 99.65it/s]
# Epoch 86: train_acc_0.7583_train_loss_0.7911_val_acc_0.7579_val_loss_0.7866 epoch time 12.0234 seconds
# total time17.0 : 15.927288293838501
# loss: 0.8391, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:10<00:00, 93.42it/s]
# loss: 0.5683, accuracy: 0.8300: 100%|██████████| 158/158 [00:00<00:00, 159.14it/s]
# loss: 0.7795, accuracy: 0.7500:   2%|▏         | 19/1000 [00:00<00:09, 98.68it/s]
# Epoch 87: train_acc_0.7577_train_loss_0.7894_val_acc_0.7581_val_loss_0.7860 epoch time 11.8886 seconds
# total time17.0 : 27.815857887268066
# loss: 0.7338, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 92.48it/s]
# loss: 0.6579, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 147.36it/s]
# loss: 0.7417, accuracy: 0.7500:   2%|▏         | 18/1000 [00:00<00:10, 97.67it/s]
# Epoch 88: train_acc_0.7585_train_loss_0.7879_val_acc_0.7574_val_loss_0.7798 epoch time 12.0309 seconds
# total time17.0 : 39.84674334526062
# loss: 0.9989, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:10<00:00, 92.40it/s]
# loss: 0.7815, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 152.16it/s]
# loss: 0.7841, accuracy: 0.8000:   2%|▏         | 18/1000 [00:00<00:09, 99.80it/s]
# Epoch 89: train_acc_0.7596_train_loss_0.7873_val_acc_0.7585_val_loss_0.7783 epoch time 12.0461 seconds
# total time17.0 : 51.89282464981079
# loss: 0.6754, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 92.48it/s]
# loss: 0.5289, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 153.28it/s]
# loss: 0.7265, accuracy: 0.7700:   2%|▏         | 19/1000 [00:00<00:10, 97.79it/s]
# Epoch 90: train_acc_0.7591_train_loss_0.7862_val_acc_0.7596_val_loss_0.7764 epoch time 12.0373 seconds
# total time18.0 : 3.930145025253296
# loss: 0.9276, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:10<00:00, 92.93it/s]
# loss: 0.7629, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 149.08it/s]
# loss: 0.7581, accuracy: 0.8000:   2%|▏         | 19/1000 [00:00<00:09, 101.82it/s]
# Epoch 91: train_acc_0.7606_train_loss_0.7845_val_acc_0.7591_val_loss_0.7751 epoch time 11.9583 seconds
# total time18.0 : 15.888437271118164
# loss: 0.9391, accuracy: 0.7000: 100%|██████████| 1000/1000 [00:10<00:00, 93.35it/s]
# loss: 0.7418, accuracy: 0.7600: 100%|██████████| 158/158 [00:01<00:00, 148.40it/s]
# loss: 0.8281, accuracy: 0.7300:   2%|▏         | 19/1000 [00:00<00:10, 97.11it/s]
# Epoch 92: train_acc_0.7600_train_loss_0.7837_val_acc_0.7575_val_loss_0.7784 epoch time 11.9206 seconds
# total time18.0 : 27.809040307998657
# loss: 0.7262, accuracy: 0.7600: 100%|██████████| 1000/1000 [00:10<00:00, 93.03it/s]
# loss: 0.8319, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 146.88it/s]
# loss: 0.6467, accuracy: 0.7900:   2%|▏         | 18/1000 [00:00<00:09, 98.35it/s]
# Epoch 93: train_acc_0.7600_train_loss_0.7829_val_acc_0.7612_val_loss_0.7755 epoch time 11.9679 seconds
# total time18.0 : 39.77689075469971
# loss: 0.7549, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 91.89it/s]
# loss: 0.9774, accuracy: 0.7100: 100%|██████████| 158/158 [00:01<00:00, 149.74it/s]
# loss: 1.0703, accuracy: 0.7000:   2%|▏         | 19/1000 [00:00<00:09, 98.68it/s]
# Epoch 94: train_acc_0.7599_train_loss_0.7817_val_acc_0.7592_val_loss_0.7788 epoch time 12.0799 seconds
# total time18.0 : 51.856769323349
# loss: 0.6768, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:10<00:00, 93.03it/s]
# loss: 1.0524, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 154.15it/s]
# loss: 0.8958, accuracy: 0.7600:   2%|▏         | 19/1000 [00:00<00:09, 102.25it/s]
# Epoch 95: train_acc_0.7618_train_loss_0.7800_val_acc_0.7601_val_loss_0.7699 epoch time 11.9694 seconds
# total time19.0 : 3.8262081146240234
# loss: 0.8132, accuracy: 0.7300: 100%|██████████| 1000/1000 [00:10<00:00, 93.17it/s]
# loss: 0.6915, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 147.27it/s]
# loss: 1.1364, accuracy: 0.6800:   2%|▏         | 19/1000 [00:00<00:09, 101.16it/s]
# Epoch 96: train_acc_0.7611_train_loss_0.7789_val_acc_0.7615_val_loss_0.7738 epoch time 11.9457 seconds
# total time19.0 : 15.771859884262085
# loss: 0.8714, accuracy: 0.7100: 100%|██████████| 1000/1000 [00:10<00:00, 92.44it/s]
# loss: 0.8196, accuracy: 0.7400: 100%|██████████| 158/158 [00:00<00:00, 160.57it/s]
# loss: 0.7828, accuracy: 0.7800:   2%|▏         | 19/1000 [00:00<00:09, 101.68it/s]
# Epoch 97: train_acc_0.7622_train_loss_0.7790_val_acc_0.7627_val_loss_0.7758 epoch time 12.0146 seconds
# total time19.0 : 27.786489725112915
# loss: 0.6909, accuracy: 0.8000: 100%|██████████| 1000/1000 [00:10<00:00, 92.82it/s]
# loss: 0.9871, accuracy: 0.7500: 100%|██████████| 158/158 [00:01<00:00, 152.71it/s]
# loss: 0.9992, accuracy: 0.7200:   2%|▏         | 19/1000 [00:00<00:10, 95.90it/s]
# Epoch 98: train_acc_0.7615_train_loss_0.7777_val_acc_0.7577_val_loss_0.7744 epoch time 11.9978 seconds
# total time19.0 : 39.784297704696655
# loss: 0.7131, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:10<00:00, 92.55it/s]
# loss: 0.6791, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 146.73it/s]
# loss: 0.8004, accuracy: 0.7300:  19%|█▉        | 30/158 [00:00<00:00, 162.65it/s]
# Epoch 99: train_acc_0.7624_train_loss_0.7757_val_acc_0.7596_val_loss_0.7709 epoch time 12.0219 seconds
# total time19.0 : 51.80623173713684
# Generating test set evaluation metrics
# loss: 0.8984, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 150.13it/s]
# finish
# loss: 3.8541, accuracy: 0.0000:   1%|          | 10/1000 [00:00<00:13, 73.52it/s]
# stride2_filter32_layer2_type3
# Building basic block of ConvolutionalNetwork using input shape (100, 1, 28, 28)
# torch.Size([100, 32, 28, 28])
# torch.Size([100, 32, 15, 15])
# torch.Size([100, 32, 15, 15])
# torch.Size([100, 32, 8, 8])
# shape before final linear layer torch.Size([100, 32, 2, 2])
# Block is built, output volume is torch.Size([100, 47])
# use GPU
# ConvolutionalNetwork(
#   (layer_dict): ModuleDict(
#     (conv_0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_avg_pool_0): AvgPool2d(kernel_size=2, stride=2, padding=1)
#     (conv_1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (dim_reduction_avg_pool_1): AvgPool2d(kernel_size=2, stride=2, padding=1)
#   )
#   (logit_linear_layer): Linear(in_features=128, out_features=47, bias=True)
# )
# loss: 1.2948, accuracy: 0.6600: 100%|██████████| 1000/1000 [00:12<00:00, 78.98it/s]
# loss: 1.2081, accuracy: 0.6200: 100%|██████████| 158/158 [00:01<00:00, 149.85it/s]
# loss: 1.5220, accuracy: 0.5700:   2%|▏         | 17/1000 [00:00<00:10, 91.90it/s]
# Epoch 0: train_acc_0.4493_train_loss_2.0057_val_acc_0.6508_val_loss_1.1843 epoch time 13.8518 seconds
# total time0.0 : 13.851764678955078
# loss: 1.1863, accuracy: 0.6500: 100%|██████████| 1000/1000 [00:11<00:00, 85.13it/s]
# loss: 0.8179, accuracy: 0.7000: 100%|██████████| 158/158 [00:01<00:00, 137.82it/s]
# loss: 1.1898, accuracy: 0.5900:   2%|▏         | 17/1000 [00:00<00:11, 87.81it/s]
# Epoch 1: train_acc_0.6811_train_loss_1.0765_val_acc_0.7135_val_loss_0.9495 epoch time 12.9600 seconds
# total time0.0 : 26.81175422668457
# loss: 0.6262, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 83.98it/s]
# loss: 0.9346, accuracy: 0.6800: 100%|██████████| 158/158 [00:01<00:00, 139.70it/s]
# loss: 0.9355, accuracy: 0.6900:   2%|▏         | 17/1000 [00:00<00:11, 88.02it/s]
# Epoch 2: train_acc_0.7242_train_loss_0.9160_val_acc_0.7401_val_loss_0.8529 epoch time 13.1775 seconds
# total time0.0 : 39.98921275138855
# loss: 0.8211, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 85.03it/s]
# loss: 0.6094, accuracy: 0.7900: 100%|██████████| 158/158 [00:01<00:00, 146.36it/s]
# loss: 0.6418, accuracy: 0.8000:   2%|▏         | 17/1000 [00:00<00:10, 89.61it/s]
# Epoch 3: train_acc_0.7462_train_loss_0.8335_val_acc_0.7615_val_loss_0.7900 epoch time 12.9756 seconds
# total time0.0 : 52.96478533744812
# loss: 0.9624, accuracy: 0.7500: 100%|██████████| 1000/1000 [00:11<00:00, 84.47it/s]
# loss: 0.6644, accuracy: 0.7400: 100%|██████████| 158/158 [00:01<00:00, 137.42it/s]
# loss: 0.7941, accuracy: 0.7800:   2%|▏         | 17/1000 [00:00<00:10, 90.47it/s]
# Epoch 4: train_acc_0.7598_train_loss_0.7837_val_acc_0.7628_val_loss_0.7775 epoch time 13.1270 seconds
# total time1.0 : 6.091825723648071
# loss: 0.6830, accuracy: 0.7700: 100%|██████████| 1000/1000 [00:11<00:00, 84.50it/s]
# loss: 0.6075, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 139.12it/s]
# loss: 0.6775, accuracy: 0.7900:   2%|▏         | 17/1000 [00:00<00:10, 94.29it/s]
# Epoch 5: train_acc_0.7692_train_loss_0.7475_val_acc_0.7820_val_loss_0.7040 epoch time 13.1068 seconds
# total time1.0 : 19.198625564575195
# loss: 0.8248, accuracy: 0.7200: 100%|██████████| 1000/1000 [00:11<00:00, 84.17it/s]
# loss: 0.6753, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 154.13it/s]
# loss: 0.6813, accuracy: 0.7600:   2%|▏         | 17/1000 [00:00<00:10, 92.25it/s]
# Epoch 6: train_acc_0.7767_train_loss_0.7161_val_acc_0.7841_val_loss_0.6962 epoch time 13.1025 seconds
# total time1.0 : 32.30117440223694
# loss: 0.7082, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:11<00:00, 85.34it/s]
# loss: 0.5477, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 138.30it/s]
# loss: 0.7166, accuracy: 0.7400:   2%|▏         | 17/1000 [00:00<00:10, 91.23it/s]
# Epoch 7: train_acc_0.7852_train_loss_0.6885_val_acc_0.7849_val_loss_0.6841 epoch time 13.0000 seconds
# total time1.0 : 45.30122208595276
# loss: 1.0156, accuracy: 0.7400: 100%|██████████| 1000/1000 [00:11<00:00, 84.65it/s]
# loss: 0.7434, accuracy: 0.7300: 100%|██████████| 158/158 [00:01<00:00, 140.70it/s]
# loss: 0.6721, accuracy: 0.7800:   2%|▏         | 17/1000 [00:00<00:10, 90.93it/s]
# Epoch 8: train_acc_0.7915_train_loss_0.6649_val_acc_0.8009_val_loss_0.6344 epoch time 13.0726 seconds
# total time1.0 : 58.373796701431274
# loss: 0.8382, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:11<00:00, 85.00it/s]
# loss: 0.6575, accuracy: 0.7700: 100%|██████████| 158/158 [00:01<00:00, 141.02it/s]
# loss: 0.5244, accuracy: 0.8100:   2%|▏         | 17/1000 [00:00<00:10, 91.41it/s]
# Epoch 9: train_acc_0.7974_train_loss_0.6418_val_acc_0.8005_val_loss_0.6366 epoch time 13.0268 seconds
# total time2.0 : 11.40062928199768
# loss: 0.5431, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 84.90it/s]
# loss: 0.5425, accuracy: 0.8200: 100%|██████████| 158/158 [00:01<00:00, 141.25it/s]
# loss: 0.4402, accuracy: 0.8700:   2%|▏         | 17/1000 [00:00<00:10, 89.96it/s]
# Epoch 10: train_acc_0.8037_train_loss_0.6207_val_acc_0.8121_val_loss_0.5929 epoch time 13.0320 seconds
# total time2.0 : 24.432621955871582
# loss: 0.6244, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 84.59it/s]
# loss: 0.5651, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 141.63it/s]
# loss: 0.6586, accuracy: 0.7300:   2%|▏         | 17/1000 [00:00<00:10, 89.99it/s]
# Epoch 11: train_acc_0.8083_train_loss_0.6046_val_acc_0.8095_val_loss_0.5920 epoch time 13.0710 seconds
# total time2.0 : 37.50357508659363
# loss: 0.4778, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:11<00:00, 84.61it/s]
# loss: 0.5911, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 140.74it/s]
# loss: 0.5254, accuracy: 0.8600:   2%|▏         | 16/1000 [00:00<00:11, 87.30it/s]
# Epoch 12: train_acc_0.8108_train_loss_0.5897_val_acc_0.8168_val_loss_0.5688 epoch time 13.0807 seconds
# total time2.0 : 50.58429217338562
# loss: 0.6098, accuracy: 0.7800: 100%|██████████| 1000/1000 [00:11<00:00, 84.34it/s]
# loss: 0.5718, accuracy: 0.7800: 100%|██████████| 158/158 [00:01<00:00, 139.37it/s]
# loss: 0.7144, accuracy: 0.7500:   2%|▏         | 17/1000 [00:00<00:10, 91.56it/s]
# Epoch 13: train_acc_0.8166_train_loss_0.5742_val_acc_0.8165_val_loss_0.5614 epoch time 13.1299 seconds
# total time3.0 : 3.714228868484497
# loss: 0.6201, accuracy: 0.8400: 100%|██████████| 1000/1000 [00:11<00:00, 84.74it/s]
# loss: 0.3586, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 137.26it/s]
# loss: 0.5855, accuracy: 0.8100:   2%|▏         | 17/1000 [00:00<00:11, 88.52it/s]
# Epoch 14: train_acc_0.8190_train_loss_0.5621_val_acc_0.8251_val_loss_0.5385 epoch time 13.0900 seconds
# total time3.0 : 16.804213762283325
# loss: 0.5034, accuracy: 0.8100: 100%|██████████| 1000/1000 [00:11<00:00, 84.41it/s]
# loss: 0.4709, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 138.03it/s]
# loss: 0.4496, accuracy: 0.8800:   2%|▏         | 17/1000 [00:00<00:11, 88.49it/s]
# Epoch 15: train_acc_0.8228_train_loss_0.5515_val_acc_0.8272_val_loss_0.5387 epoch time 13.1317 seconds
# total time3.0 : 29.935906410217285
# loss: 0.6373, accuracy: 0.7900: 100%|██████████| 1000/1000 [00:11<00:00, 85.96it/s]
# loss: 0.6657, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 138.19it/s]
# loss: 0.3022, accuracy: 0.9000:   2%|▏         | 16/1000 [00:00<00:11, 88.93it/s]
# Epoch 16: train_acc_0.8246_train_loss_0.5442_val_acc_0.8316_val_loss_0.5197 epoch time 12.9162 seconds
# total time3.0 : 42.852104902267456
# loss: 0.4783, accuracy: 0.8200: 100%|██████████| 1000/1000 [00:11<00:00, 84.53it/s]
# loss: 0.4856, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 139.52it/s]
# loss: 0.6351, accuracy: 0.7400:   2%|▏         | 17/1000 [00:00<00:11, 88.48it/s]
# Epoch 17: train_acc_0.8276_train_loss_0.5332_val_acc_0.8235_val_loss_0.5341 epoch time 13.1025 seconds
# total time3.0 : 55.954596281051636
# loss: 0.3845, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:11<00:00, 84.51it/s]
# loss: 0.5511, accuracy: 0.8100: 100%|██████████| 158/158 [00:01<00:00, 139.21it/s]
# loss: 0.4050, accuracy: 0.8900:   2%|▏         | 17/1000 [00:00<00:11, 88.85it/s]
# Epoch 18: train_acc_0.8290_train_loss_0.5247_val_acc_0.8359_val_loss_0.5068 epoch time 13.1091 seconds
# total time4.0 : 9.063687324523926
# loss: 0.4109, accuracy: 0.8500: 100%|██████████| 1000/1000 [00:11<00:00, 84.36it/s]
# ...
# loss: 0.5030, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 130.43it/s]
# loss: 0.2090, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:12, 78.19it/s]
# Epoch 59: train_acc_0.9045_train_loss_0.2475_val_acc_0.8817_val_loss_0.3413 epoch time 15.1108 seconds
# total time15.0 : 5.043890476226807
# loss: 0.3593, accuracy: 0.8300: 100%|██████████| 1000/1000 [00:13<00:00, 73.29it/s]
# loss: 0.3281, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 128.95it/s]
# loss: 0.1599, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 76.03it/s]
# Epoch 60: train_acc_0.9054_train_loss_0.2466_val_acc_0.8810_val_loss_0.3411 epoch time 15.1033 seconds
# total time15.0 : 20.147173166275024
# loss: 0.2655, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 73.52it/s]
# loss: 0.2457, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 128.92it/s]
# loss: 0.1673, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 75.46it/s]
# Epoch 61: train_acc_0.9056_train_loss_0.2447_val_acc_0.8859_val_loss_0.3375 epoch time 15.0651 seconds
# total time15.0 : 35.21229267120361
# loss: 0.2013, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 72.81it/s]
# loss: 0.3711, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 135.38it/s]
# loss: 0.2873, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:12, 76.80it/s]
# Epoch 62: train_acc_0.9062_train_loss_0.2437_val_acc_0.8837_val_loss_0.3434 epoch time 15.0404 seconds
# total time15.0 : 50.252657890319824
# loss: 0.2183, accuracy: 0.8800: 100%|██████████| 1000/1000 [00:13<00:00, 75.33it/s]
# loss: 0.1462, accuracy: 0.9400: 100%|██████████| 158/158 [00:01<00:00, 130.13it/s]
# loss: 0.2103, accuracy: 0.9300:   2%|▏         | 15/1000 [00:00<00:12, 78.48it/s]
# Epoch 63: train_acc_0.9065_train_loss_0.2423_val_acc_0.8839_val_loss_0.3483 epoch time 15.0883 seconds
# total time16.0 : 5.340940713882446
# loss: 0.2708, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 75.02it/s]
# loss: 0.3347, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 126.72it/s]
# loss: 0.2007, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 75.43it/s]
# Epoch 64: train_acc_0.9076_train_loss_0.2413_val_acc_0.8834_val_loss_0.3395 epoch time 14.7139 seconds
# total time16.0 : 20.054844617843628
# loss: 0.2644, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 75.59it/s]
# loss: 0.3025, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 142.09it/s]
# loss: 0.2820, accuracy: 0.9100:   2%|▏         | 15/1000 [00:00<00:12, 78.80it/s]
# Epoch 65: train_acc_0.9077_train_loss_0.2398_val_acc_0.8847_val_loss_0.3395 epoch time 14.4745 seconds
# total time16.0 : 34.52937030792236
# loss: 0.1671, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 75.28it/s]
# loss: 0.2607, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 129.68it/s]
# loss: 0.1880, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:13, 74.68it/s]
# Epoch 66: train_acc_0.9066_train_loss_0.2403_val_acc_0.8821_val_loss_0.3371 epoch time 14.6381 seconds
# total time16.0 : 49.16750931739807
# loss: 0.3537, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 73.59it/s]
# loss: 0.2742, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 132.67it/s]
# loss: 0.1432, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:13, 75.59it/s]
# Epoch 67: train_acc_0.9085_train_loss_0.2371_val_acc_0.8783_val_loss_0.3425 epoch time 14.9124 seconds
# total time17.0 : 4.079875946044922
# loss: 0.2439, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 73.63it/s]
# loss: 0.4885, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 129.67it/s]
# loss: 0.1676, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:13, 75.63it/s]
# Epoch 68: train_acc_0.9084_train_loss_0.2358_val_acc_0.8780_val_loss_0.3491 epoch time 14.9365 seconds
# total time17.0 : 19.016332387924194
# loss: 0.2842, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.75it/s]
# loss: 0.4887, accuracy: 0.8700: 100%|██████████| 158/158 [00:01<00:00, 130.09it/s]
# loss: 0.3048, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 77.55it/s]
# Epoch 69: train_acc_0.9100_train_loss_0.2352_val_acc_0.8753_val_loss_0.3581 epoch time 15.0955 seconds
# total time17.0 : 34.111825942993164
# loss: 0.3032, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 74.04it/s]
# loss: 0.4232, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 141.10it/s]
# loss: 0.1749, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:12, 79.44it/s]
# Epoch 70: train_acc_0.9088_train_loss_0.2344_val_acc_0.8785_val_loss_0.3526 epoch time 14.8197 seconds
# total time17.0 : 48.93154978752136
# loss: 0.1530, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 76.30it/s]
# loss: 0.5681, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 131.48it/s]
# loss: 0.1604, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:13, 75.34it/s]
# Epoch 71: train_acc_0.9096_train_loss_0.2337_val_acc_0.8798_val_loss_0.3466 epoch time 14.7871 seconds
# total time18.0 : 3.718630075454712
# loss: 0.2869, accuracy: 0.8700: 100%|██████████| 1000/1000 [00:13<00:00, 73.67it/s]
# loss: 0.2230, accuracy: 0.9300: 100%|██████████| 158/158 [00:01<00:00, 128.02it/s]
# loss: 0.3653, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 78.97it/s]
# Epoch 72: train_acc_0.9107_train_loss_0.2321_val_acc_0.8845_val_loss_0.3461 epoch time 15.0223 seconds
# total time18.0 : 18.74097752571106
# loss: 0.3666, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 72.07it/s]
# loss: 0.2364, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 127.89it/s]
# loss: 0.2363, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 72.98it/s]
# Epoch 73: train_acc_0.9098_train_loss_0.2321_val_acc_0.8813_val_loss_0.3486 epoch time 15.2478 seconds
# total time18.0 : 33.988805055618286
# loss: 0.1667, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 72.70it/s]
# loss: 0.3706, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 127.84it/s]
# loss: 0.2160, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:12, 76.71it/s]
# Epoch 74: train_acc_0.9115_train_loss_0.2297_val_acc_0.8789_val_loss_0.3638 epoch time 15.1282 seconds
# total time18.0 : 49.1170380115509
# loss: 0.1668, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 73.26it/s]
# loss: 0.4636, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 130.12it/s]
# loss: 0.2580, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:13, 75.29it/s]
# Epoch 75: train_acc_0.9108_train_loss_0.2295_val_acc_0.8829_val_loss_0.3520 epoch time 15.1542 seconds
# total time19.0 : 4.27128267288208
# loss: 0.1462, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 72.59it/s]
# loss: 0.4987, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 128.99it/s]
# loss: 0.2223, accuracy: 0.8800:   2%|▏         | 15/1000 [00:00<00:12, 76.13it/s]
# Epoch 76: train_acc_0.9113_train_loss_0.2276_val_acc_0.8808_val_loss_0.3580 epoch time 15.2028 seconds
# total time19.0 : 19.474035024642944
# loss: 0.2002, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.76it/s]
# loss: 0.3077, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 129.19it/s]
# loss: 0.2295, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 76.72it/s]
# Epoch 77: train_acc_0.9117_train_loss_0.2265_val_acc_0.8804_val_loss_0.3630 epoch time 15.1943 seconds
# total time19.0 : 34.66831922531128
# loss: 0.2481, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.95it/s]
# loss: 0.2358, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 139.22it/s]
# loss: 0.1910, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:12, 76.11it/s]
# Epoch 78: train_acc_0.9122_train_loss_0.2253_val_acc_0.8847_val_loss_0.3485 epoch time 15.0352 seconds
# total time19.0 : 49.703492403030396
# loss: 0.2214, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.62it/s]
# loss: 0.4548, accuracy: 0.8300: 100%|██████████| 158/158 [00:01<00:00, 128.39it/s]
# loss: 0.1195, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 77.83it/s]
# Epoch 79: train_acc_0.9126_train_loss_0.2241_val_acc_0.8803_val_loss_0.3584 epoch time 15.1366 seconds
# total time20.0 : 4.840123891830444
# loss: 0.2477, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 73.02it/s]
# loss: 0.4879, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 132.68it/s]
# loss: 0.1499, accuracy: 0.9400:   2%|▏         | 15/1000 [00:00<00:13, 75.44it/s]
# Epoch 80: train_acc_0.9127_train_loss_0.2235_val_acc_0.8821_val_loss_0.3523 epoch time 15.0203 seconds
# total time20.0 : 19.860430479049683
# loss: 0.2967, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 73.25it/s]
# loss: 0.3184, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 131.38it/s]
# loss: 0.1881, accuracy: 0.9300:   1%|▏         | 14/1000 [00:00<00:12, 77.46it/s]
# Epoch 81: train_acc_0.9130_train_loss_0.2219_val_acc_0.8801_val_loss_0.3643 epoch time 14.9899 seconds
# total time20.0 : 34.8503155708313
# loss: 0.1955, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 72.98it/s]
# loss: 0.2608, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 127.63it/s]
# loss: 0.2389, accuracy: 0.8800:   1%|▏         | 14/1000 [00:00<00:13, 73.57it/s]
# Epoch 82: train_acc_0.9129_train_loss_0.2220_val_acc_0.8785_val_loss_0.3713 epoch time 15.0796 seconds
# total time20.0 : 49.9299259185791
# loss: 0.2479, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.31it/s]
# loss: 0.3930, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 128.47it/s]
# loss: 0.1734, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 78.14it/s]
# Epoch 83: train_acc_0.9147_train_loss_0.2206_val_acc_0.8835_val_loss_0.3578 epoch time 15.1994 seconds
# total time21.0 : 5.129361629486084
# loss: 0.1687, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 73.85it/s]
# loss: 0.5418, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 141.03it/s]
# loss: 0.1370, accuracy: 0.9500:   2%|▏         | 15/1000 [00:00<00:12, 80.20it/s]
# Epoch 84: train_acc_0.9143_train_loss_0.2191_val_acc_0.8789_val_loss_0.3581 epoch time 14.7978 seconds
# total time21.0 : 19.92713165283203
# loss: 0.3277, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 72.59it/s]
# loss: 0.3315, accuracy: 0.9000: 100%|██████████| 158/158 [00:01<00:00, 131.20it/s]
# loss: 0.1605, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 76.36it/s]
# Epoch 85: train_acc_0.9145_train_loss_0.2182_val_acc_0.8846_val_loss_0.3533 epoch time 15.1210 seconds
# total time21.0 : 35.04815125465393
# loss: 0.2482, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 75.93it/s]
# loss: 0.2746, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 139.60it/s]
# loss: 0.1305, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 78.37it/s]
# Epoch 86: train_acc_0.9154_train_loss_0.2181_val_acc_0.8791_val_loss_0.3675 epoch time 14.5029 seconds
# total time21.0 : 49.551042795181274
# loss: 0.3333, accuracy: 0.8900: 100%|██████████| 1000/1000 [00:13<00:00, 72.26it/s]
# loss: 0.5901, accuracy: 0.8400: 100%|██████████| 158/158 [00:01<00:00, 129.24it/s]
# loss: 0.1251, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 77.00it/s]
# Epoch 87: train_acc_0.9146_train_loss_0.2173_val_acc_0.8829_val_loss_0.3539 epoch time 15.1996 seconds
# total time22.0 : 4.750596523284912
# loss: 0.2518, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 74.08it/s]
# loss: 0.4224, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 129.04it/s]
# loss: 0.2035, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:12, 76.36it/s]
# Epoch 88: train_acc_0.9152_train_loss_0.2157_val_acc_0.8818_val_loss_0.3591 epoch time 15.1724 seconds
# total time22.0 : 19.92296600341797
# loss: 0.1779, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 75.58it/s]
# loss: 0.4123, accuracy: 0.9200: 100%|██████████| 158/158 [00:01<00:00, 127.53it/s]
# loss: 0.2316, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:13, 74.85it/s]
# Epoch 89: train_acc_0.9151_train_loss_0.2161_val_acc_0.8841_val_loss_0.3570 epoch time 15.0492 seconds
# total time22.0 : 34.97212100028992
# loss: 0.2390, accuracy: 0.9000: 100%|██████████| 1000/1000 [00:13<00:00, 72.73it/s]
# loss: 0.3982, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 127.22it/s]
# loss: 0.1614, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:13, 75.53it/s]
# Epoch 90: train_acc_0.9156_train_loss_0.2135_val_acc_0.8784_val_loss_0.3736 epoch time 15.1311 seconds
# total time22.0 : 50.10320258140564
# loss: 0.2079, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 75.82it/s]
# loss: 0.4864, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 128.40it/s]
# loss: 0.1849, accuracy: 0.9400:   1%|▏         | 14/1000 [00:00<00:12, 77.15it/s]
# Epoch 91: train_acc_0.9161_train_loss_0.2124_val_acc_0.8795_val_loss_0.3782 epoch time 15.2051 seconds
# total time23.0 : 5.308328628540039
# loss: 0.1715, accuracy: 0.9400: 100%|██████████| 1000/1000 [00:13<00:00, 73.88it/s]
# loss: 0.2240, accuracy: 0.8600: 100%|██████████| 158/158 [00:01<00:00, 129.31it/s]
# loss: 0.1221, accuracy: 0.9600:   1%|▏         | 14/1000 [00:00<00:12, 76.69it/s]
# Epoch 92: train_acc_0.9156_train_loss_0.2131_val_acc_0.8795_val_loss_0.3740 epoch time 15.1611 seconds
# total time23.0 : 20.469406366348267
# loss: 0.1950, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 74.58it/s]
# loss: 0.3652, accuracy: 0.8800: 100%|██████████| 158/158 [00:01<00:00, 128.41it/s]
# loss: 0.2939, accuracy: 0.9000:   1%|▏         | 14/1000 [00:00<00:12, 76.63it/s]
# Epoch 93: train_acc_0.9156_train_loss_0.2125_val_acc_0.8825_val_loss_0.3586 epoch time 15.2012 seconds
# total time23.0 : 35.670644998550415
# loss: 0.2252, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 73.00it/s]
# loss: 0.2759, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 131.20it/s]
# loss: 0.1940, accuracy: 0.9000:   2%|▏         | 15/1000 [00:00<00:12, 80.70it/s]
# Epoch 94: train_acc_0.9178_train_loss_0.2095_val_acc_0.8822_val_loss_0.3596 epoch time 15.0404 seconds
# total time23.0 : 50.71108865737915
# loss: 0.3053, accuracy: 0.8600: 100%|██████████| 1000/1000 [00:13<00:00, 71.99it/s]
# loss: 0.3824, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 129.04it/s]
# loss: 0.1982, accuracy: 0.9500:   1%|▏         | 14/1000 [00:00<00:12, 75.97it/s]
# Epoch 95: train_acc_0.9173_train_loss_0.2096_val_acc_0.8810_val_loss_0.3687 epoch time 15.2552 seconds
# total time24.0 : 5.966317892074585
# loss: 0.2574, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 72.28it/s]
# loss: 0.3400, accuracy: 0.8900: 100%|██████████| 158/158 [00:01<00:00, 128.22it/s]
# loss: 0.2317, accuracy: 0.8900:   1%|▏         | 14/1000 [00:00<00:12, 76.27it/s]
# Epoch 96: train_acc_0.9179_train_loss_0.2096_val_acc_0.8795_val_loss_0.3730 epoch time 15.2067 seconds
# total time24.0 : 21.17304039001465
# loss: 0.3073, accuracy: 0.9100: 100%|██████████| 1000/1000 [00:13<00:00, 75.19it/s]
# loss: 0.2320, accuracy: 0.9400: 100%|██████████| 158/158 [00:01<00:00, 131.37it/s]
# loss: 0.1773, accuracy: 0.9100:   1%|▏         | 14/1000 [00:00<00:12, 76.39it/s]
# Epoch 97: train_acc_0.9173_train_loss_0.2092_val_acc_0.8811_val_loss_0.3672 epoch time 14.9990 seconds
# total time24.0 : 36.17206025123596
# loss: 0.3102, accuracy: 0.9200: 100%|██████████| 1000/1000 [00:13<00:00, 73.21it/s]
# loss: 0.4197, accuracy: 0.9100: 100%|██████████| 158/158 [00:01<00:00, 130.37it/s]
# loss: 0.2292, accuracy: 0.9200:   1%|▏         | 14/1000 [00:00<00:12, 77.04it/s]
# Epoch 98: train_acc_0.9177_train_loss_0.2073_val_acc_0.8822_val_loss_0.3689 epoch time 15.0331 seconds
# total time24.0 : 51.205172538757324
# loss: 0.1651, accuracy: 0.9300: 100%|██████████| 1000/1000 [00:13<00:00, 72.16it/s]
# loss: 0.6615, accuracy: 0.8000: 100%|██████████| 158/158 [00:01<00:00, 127.59it/s]
# loss: 0.4612, accuracy: 0.8600:  19%|█▉        | 30/158 [00:00<00:00, 165.89it/s]
# Epoch 99: train_acc_0.9179_train_loss_0.2071_val_acc_0.8751_val_loss_0.3781 epoch time 15.2365 seconds
# total time25.0 : 6.4416663646698
# Generating test set evaluation metrics
# loss: 0.7885, accuracy: 0.8500: 100%|██████████| 158/158 [00:01<00:00, 131.40it/s]
# finish
